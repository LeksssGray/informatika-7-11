# %% [markdown]
# # 11 класс. Алгоритмы, базы данных, сети и подготовка к ЕГЭ
#
# Выпускной год. Разбираем эффективные алгоритмы и графы, осваиваем SQL и анализ данных, изучаем сети и защиту информации. Каждая четверть включает практикум по заданиям ЕГЭ, а полный тренажёр вынесен в отдельный необязательный раздел.
#
# [🏠 Ко всем классам](https://colab.research.google.com/github/LeksssGray/informatika-7-11/blob/main/index.ipynb)
#
# ---
#
# ### К концу года ты сможешь
#
# - писать эффективные программы и оценивать их сложность
# - решать задачи на графах и деревьях
# - составлять SQL-запросы к реляционной базе данных
# - анализировать и визуализировать наборы данных средствами Python
# - решать задачи ЕГЭ, включая программные задания 24–27
#
# ### Как устроен год
#
# 34 учебные недели, один урок в неделю по 40 минут. Каждый урок — отдельный ноутбук: теория, разобранные примеры, задачи в классе и домашнее задание с автоматической проверкой.
#
# ---
#
# ## I четверть · уроки 1–8
#
# | № | Тема | Содержание | Домашнее задание |
# |:--:|---|---|---|
# | 1 | **[Повторение 10 класса. План выпускного года](https://colab.research.google.com/github/LeksssGray/informatika-7-11/blob/main/klass-11/urok-01.ipynb)** | Диагностическая работа. Карта года: что нужно освоить и в какие сроки. Как устроен экзамен и как встроить подготовку в обычные уроки. | Диагностическая работа и составление личного плана подготовки. |
# | 2 | **[Эффективность алгоритмов](https://colab.research.google.com/github/LeksssGray/informatika-7-11/blob/main/klass-11/urok-02.ipynb)** | Асимптотика на практике. Ограничения по времени и памяти. Как оценить, уложится ли решение. Оптимизация: замена структуры данных. | Ускорить три медленные программы и подтвердить результат замерами. |
# | 3 | **[Обработка целых чисел: цифры и делители](https://colab.research.google.com/github/LeksssGray/informatika-7-11/blob/main/klass-11/urok-03.ipynb)** | Разбор числа на цифры. Делители и их поиск за корень из N. Признаки делимости. НОД и НОК, алгоритм Евклида. | Пять задач на цифры и делители, включая поиск чисел с заданным числом делителей. |
# | 4 | **[Простые числа и решето Эратосфена](https://colab.research.google.com/github/LeksssGray/informatika-7-11/blob/main/klass-11/urok-04.ipynb)** | Проверка числа на простоту. Решето Эратосфена. Разложение на множители. Оценка времени работы на больших диапазонах. | Реализовать решето и решить задачи на простые множители. |
# | 5 | **[Динамическое программирование: знакомство](https://colab.research.google.com/github/LeksssGray/informatika-7-11/blob/main/klass-11/urok-05.ipynb)** | Задачи с накоплением ответа: числа Фибоначчи, лестница, маршруты в таблице. Таблица подзадач вместо рекурсии. | Решить три задачи о маршрутах и накоплениях табличным методом. |
# | 6 | **[Системы счисления в задачах ЕГЭ](https://colab.research.google.com/github/LeksssGray/informatika-7-11/blob/main/klass-11/urok-06.ipynb)** | Задачи с переменным основанием, поиск оснований по условию, сумма цифр и остатки. Решение перебором в коде как способ проверки. | Шесть задач формата ЕГЭ на системы счисления. |
# | 7 | **[Практикум ЕГЭ: исполнители и анализ программ](https://colab.research.google.com/github/LeksssGray/informatika-7-11/blob/main/klass-11/urok-07.ipynb)** | Задания на формальных исполнителей и анализ готовых программ. Обратный ход и перебор. Автоматная модель исполнителя. | Решить восемь задач формата ЕГЭ на исполнителей. |
# | 8 | **[Контрольная работа № 1](https://colab.research.google.com/github/LeksssGray/informatika-7-11/blob/main/klass-11/urok-08.ipynb)** | Разбор ошибок. Самостоятельная работа: алгоритмы и обработка чисел. | Итоговые задачи четверти с автопроверкой. |
#
# ## II четверть · уроки 9–16
#
# | № | Тема | Содержание | Домашнее задание |
# |:--:|---|---|---|
# | 9 | Графы: представление и обход <br><sub>готовится</sub> | Список смежности и матрица смежности. Обход в глубину и в ширину. Связность и компоненты. Подсчёт путей в ориентированном графе. | Реализовать оба обхода и решить задачи на связность. |
# | 10 | Кратчайшие пути <br><sub>готовится</sub> | Задача о кратчайшем пути во взвешенном графе. Алгоритм Дейкстры на понятном уровне. Классические задачи про дороги и стоимость маршрута. | Найти кратчайшие пути в трёх графах программой и вручную. |
# | 11 | Деревья и иерархические структуры <br><sub>готовится</sub> | Дерево, корень, поддеревья, высота. Обходы дерева. Дерево решений и дерево игры. Иерархии в реальных данных. | Обойти дерево рекурсивно и посчитать его характеристики. |
# | 12 | Базы данных: реляционная модель <br><sub>готовится</sub> | Таблицы, поля, типы, ключи. Первичный и внешний ключ. Связи один-ко-многим. Нормализация на практическом уровне. Проектирование схемы. | Спроектировать схему базы данных для реальной задачи и обосновать её. |
# | 13 | SQL: выборка данных <br><sub>готовится</sub> | SELECT, FROM, WHERE. Условия и логические операторы. DISTINCT. Сортировка ORDER BY и ограничение LIMIT. Практика в sqlite прямо в ноутбуке. | Составить десять запросов к учебной базе данных. |
# | 14 | SQL: группировка и соединения <br><sub>готовится</sub> | Агрегатные функции COUNT, SUM, AVG, MIN, MAX. GROUP BY и HAVING. Соединение таблиц JOIN. Запросы по нескольким таблицам. | Составить восемь аналитических запросов с группировкой и соединением. |
# | 15 | Практикум: база данных под задачу <br><sub>готовится</sub> | Сквозная работа: создать базу, наполнить данными, ответить запросами на содержательные вопросы, оформить выводы. | Реализовать свою базу данных из трёх связанных таблиц и десяти запросов. |
# | 16 | Контрольная работа № 2 <br><sub>готовится</sub> | Разбор ошибок. Самостоятельная работа: графы и базы данных. | Итоговые задачи четверти с автопроверкой. |
#
# ## III четверть · уроки 17–26
#
# | № | Тема | Содержание | Домашнее задание |
# |:--:|---|---|---|
# | 17 | Компьютерные сети и протоколы <br><sub>готовится</sub> | Модель уровней, стек TCP/IP. Коммутация пакетов. Основные протоколы. Расчёт времени передачи и пропускной способности. | Задачи на расчёт передачи данных и разбор работы протоколов. |
# | 18 | IP-адресация и маски подсети <br><sub>готовится</sub> | Структура IP-адреса. Маска подсети, адрес сети и адрес узла. Разбор классических задач ЕГЭ на маски. Проверка ответа кодом. | Решить шесть задач формата ЕГЭ на адресацию и проверить их программой. |
# | 19 | Веб-технологии: HTML и CSS <br><sub>готовится</sub> | Структура документа, семантические теги, ссылки, таблицы, формы. Основы CSS: селекторы и свойства. Как работает браузер. | Собрать страницу-портфолио из готовых блоков с оформлением. |
# | 20 | Защита информации и шифрование <br><sub>готовится</sub> | Симметричное и асимметричное шифрование на понятном уровне. Хеширование и электронная подпись. Практика: реализация простых шифров. | Реализовать шифр Цезаря и Виженера, посчитать хеши файлов. |
# | 21 | Обработка табличных данных в Python <br><sub>готовится</sub> | Загрузка CSV, структура таблицы, отбор строк и столбцов, новые вычисляемые поля. Пропуски и грязные данные. | Загрузить набор данных, очистить его и посчитать базовую статистику. |
# | 22 | Анализ данных: группировка и агрегация <br><sub>готовится</sub> | Группировка по признаку, сводные показатели, сравнение групп. Сортировка результатов. Формулировка выводов по числам. | Ответить на пять содержательных вопросов к набору данных. |
# | 23 | Визуализация и представление результатов <br><sub>готовится</sub> | Выбор графика под вопрос. Оформление и подписи. Ошибки визуализации. Сборка отчёта из текста, кода и графиков. | Собрать мини-отчёт по данным: четыре графика и текстовые выводы. |
# | 24 | Моделирование и численные методы <br><sub>готовится</sub> | Численное решение задач: приближённые вычисления, метод половинного деления, метод Монте-Карло. Оценка погрешности. | Найти корень уравнения численно и оценить площадь методом Монте-Карло. |
# | 25 | Практикум ЕГЭ: обработка файлов данных <br><sub>готовится</sub> | Задания 17, 22, 23 и 26: чтение больших файлов, подсчёты по условию, оптимальный выбор. Надёжные шаблоны решения. | Решить шесть задач формата ЕГЭ на обработку файлов. |
# | 26 | Контрольная работа № 3 <br><sub>готовится</sub> | Разбор ошибок. Самостоятельная работа: сети, данные, моделирование. | Итоговые задачи четверти с автопроверкой. |
#
# ## IV четверть · уроки 27–34
#
# | № | Тема | Содержание | Домашнее задание |
# |:--:|---|---|---|
# | 27 | Электронные таблицы: продвинутые приёмы <br><sub>готовится</sub> | Сводные таблицы, функции подстановки, массивы значений, сценарии и подбор параметра. Таблица против кода: осознанный выбор. | Решить аналитическую задачу таблицей и кодом, сравнить подходы. |
# | 28 | Логика в задачах ЕГЭ <br><sub>готовится</sub> | Логические выражения с переменными, таблицы с пропусками, логические уравнения и подсчёт числа решений. Проверка перебором. | Решить восемь задач формата ЕГЭ на логику. |
# | 29 | Выигрышные стратегии в играх <br><sub>готовится</sub> | Игры с двумя игроками и полной информацией. Дерево игры, выигрышные и проигрышные позиции. Разбор классических задач. | Проанализировать три игры и построить дерево выигрышной стратегии. |
# | 30 | Практикум ЕГЭ: программирование <br><sub>готовится</sub> | Задания 24–27: обработка строк большого объёма, поиск оптимума, задачи с двумя проходами по данным. Разбор эталонных решений. | Решить пять задач формата ЕГЭ на программирование. |
# | 31 | Итоговый проект <br><sub>готовится</sub> | Финальный проект: содержательная задача, реализация, результат, защита. Требования и критерии. | Реализовать и оформить итоговый проект. |
# | 32 | Защита проектов <br><sub>готовится</sub> | Представление и обсуждение работ. Рецензирование. Как объяснять техническое решение неподготовленному слушателю. | Подготовить выступление и рецензию на чужой проект. |
# | 33 | Повторение перед экзаменом <br><sub>готовится</sub> | Разбор полного варианта ЕГЭ. Стратегия распределения времени, порядок решения, проверка ответов, типичные потери баллов. | Прорешать полный вариант ЕГЭ с самопроверкой. |
# | 34 | Итоговая контрольная работа <br><sub>готовится</sub> | Итоговая работа за курс старшей школы. | Итоговая работа за 11 класс с автопроверкой. |
#
# ---
#
# ### Условные обозначения
#
# 📖 — теория  🐍 — Python  🧠 — логика  📊 — электронные таблицы  🗄️ — базы данных  🌐 — сети  📈 — анализ данных  🛠️ — проект  📝 — контрольная  🎓 — ОГЭ  🎓 — ЕГЭ
#
# [🏠 Ко всем классам](https://colab.research.google.com/github/LeksssGray/informatika-7-11/blob/main/index.ipynb)
