# %% [markdown]
# # 11 класс. Алгоритмы, базы данных и подготовка к ЕГЭ
#
# Выпускной год. Разбираем эффективные алгоритмы и графы, осваиваем SQL и анализ данных, изучаем сети и защиту информации. Каждая четверть включает практикум по заданиям ЕГЭ, а полный тренажёр вынесен в отдельный необязательный раздел.
#
# [🏠 Ко всем классам](https://colab.research.google.com/github/LeksssGray/informatika-7-11/blob/main/index.ipynb)
#
# ---
#
# ### К июню будешь уметь
#
# - писать эффективные программы и оценивать их сложность
# - решать задачи на графах и деревьях
# - составлять SQL-запросы к реляционной базе данных
# - анализировать и визуализировать наборы данных средствами Python
# - решать задачи ЕГЭ, включая программные задания 24–27
#
# Уроки идут по порядку и опираются друг на друга — перепрыгивать через них не стоит.
#
# ---
#
# ## I четверть · уроки 1–8
#
# | № | Тема | Содержание | Домашнее задание |
# |:--:|---|---|---|
# | 1 | **[Учебник, Colab и план выпускного года](https://colab.research.google.com/github/LeksssGray/informatika-7-11/blob/main/klass-11/urok-01.ipynb)** | Диагностическая работа. Карта года: что нужно освоить и в какие сроки. Как устроен экзамен и как встроить подготовку в обычные уроки. | Диагностическая работа и составление личного плана подготовки. |
# | 2 | **[Вспоминаем 10 класс: кодирование и логика](https://colab.research.google.com/github/LeksssGray/informatika-7-11/blob/main/klass-11/urok-02.ipynb)** | Справочник и проверка: объём текста, графики и звука, системы счисления, алгебра логики и логические уравнения, представление чисел в памяти. | Разминочные задачи по теории за 10 класс. |
# | 3 | **[Вспоминаем 10 класс: структуры данных и алгоритмы](https://colab.research.google.com/github/LeksssGray/informatika-7-11/blob/main/klass-11/urok-03.ipynb)** | Справочник и проверка: списки и матрицы, строки, словари и множества, файлы, поиск и сортировка, оценка сложности. | Разминочные задачи по программированию за 10 класс. |
# | 4 | **[Эффективность алгоритмов](https://colab.research.google.com/github/LeksssGray/informatika-7-11/blob/main/klass-11/urok-04.ipynb)** | Асимптотика на практике. Ограничения по времени и памяти. Как оценить, уложится ли решение. Оптимизация: замена структуры данных. | Ускорить три медленные программы и подтвердить результат замерами. |
# | 5 | **[Обработка целых чисел: цифры и делители](https://colab.research.google.com/github/LeksssGray/informatika-7-11/blob/main/klass-11/urok-05.ipynb)** | Разбор числа на цифры. Делители и их поиск за корень из N. Признаки делимости. НОД и НОК, алгоритм Евклида. | Пять задач на цифры и делители, включая поиск чисел с заданным числом делителей. |
# | 6 | **[Простые числа и решето Эратосфена](https://colab.research.google.com/github/LeksssGray/informatika-7-11/blob/main/klass-11/urok-06.ipynb)** | Проверка числа на простоту. Решето Эратосфена. Разложение на множители. Оценка времени работы на больших диапазонах. | Реализовать решето и решить задачи на простые множители. |
# | 7 | **[Динамическое программирование: знакомство](https://colab.research.google.com/github/LeksssGray/informatika-7-11/blob/main/klass-11/urok-07.ipynb)** | Задачи с накоплением ответа: числа Фибоначчи, лестница, маршруты в таблице. Таблица подзадач вместо рекурсии. | Решить три задачи о маршрутах и накоплениях табличным методом. |
# | 8 | **[Системы счисления в задачах ЕГЭ](https://colab.research.google.com/github/LeksssGray/informatika-7-11/blob/main/klass-11/urok-08.ipynb)** | Задачи с переменным основанием, поиск оснований по условию, сумма цифр и остатки. Решение перебором в коде как способ проверки. | Шесть задач формата ЕГЭ на системы счисления. |
#
# ## II четверть · уроки 9–16
#
# | № | Тема | Содержание | Домашнее задание |
# |:--:|---|---|---|
# | 9 | **[Практикум ЕГЭ: исполнители и анализ программ](https://colab.research.google.com/github/LeksssGray/informatika-7-11/blob/main/klass-11/urok-09.ipynb)** | Задания на формальных исполнителей и анализ готовых программ. Обратный ход и перебор. Автоматная модель исполнителя. | Решить восемь задач формата ЕГЭ на исполнителей. |
# | 10 | **[Контрольная работа № 1](https://colab.research.google.com/github/LeksssGray/informatika-7-11/blob/main/klass-11/urok-10.ipynb)** | Разбор ошибок. Самостоятельная работа: алгоритмы и обработка чисел. | Итоговые задачи четверти с автопроверкой. |
# | 11 | Графы: представление и обход | Список смежности и матрица смежности. Обход в глубину и в ширину. Связность и компоненты. Подсчёт путей в ориентированном графе. | Реализовать оба обхода и решить задачи на связность. |
# | 12 | Кратчайшие пути | Задача о кратчайшем пути во взвешенном графе. Алгоритм Дейкстры на понятном уровне. Классические задачи про дороги и стоимость маршрута. | Найти кратчайшие пути в трёх графах программой и вручную. |
# | 13 | Деревья и иерархические структуры | Дерево, корень, поддеревья, высота. Обходы дерева. Дерево решений и дерево игры. Иерархии в реальных данных. | Обойти дерево рекурсивно и посчитать его характеристики. |
# | 14 | Базы данных: реляционная модель | Таблицы, поля, типы, ключи. Первичный и внешний ключ. Связи один-ко-многим. Нормализация на практическом уровне. Проектирование схемы. | Спроектировать схему базы данных для реальной задачи и обосновать её. |
# | 15 | SQL: выборка данных | SELECT, FROM, WHERE. Условия и логические операторы. DISTINCT. Сортировка ORDER BY и ограничение LIMIT. Практика в sqlite прямо в ноутбуке. | Составить десять запросов к учебной базе данных. |
# | 16 | SQL: группировка и соединения | Агрегатные функции COUNT, SUM, AVG, MIN, MAX. GROUP BY и HAVING. Соединение таблиц JOIN. Запросы по нескольким таблицам. | Составить восемь аналитических запросов с группировкой и соединением. |
#
# ## III четверть · уроки 17–26
#
# | № | Тема | Содержание | Домашнее задание |
# |:--:|---|---|---|
# | 17 | Практикум: база данных под задачу | Сквозная работа: создать базу, наполнить данными, ответить запросами на содержательные вопросы, оформить выводы. | Реализовать свою базу данных из трёх связанных таблиц и десяти запросов. |
# | 18 | Контрольная работа № 2 | Разбор ошибок. Самостоятельная работа: графы и базы данных. | Итоговые задачи четверти с автопроверкой. |
# | 19 | Компьютерные сети и протоколы | Модель уровней, стек TCP/IP. Коммутация пакетов. Основные протоколы. Расчёт времени передачи и пропускной способности. | Задачи на расчёт передачи данных и разбор работы протоколов. |
# | 20 | IP-адресация и маски подсети | Структура IP-адреса. Маска подсети, адрес сети и адрес узла. Разбор классических задач ЕГЭ на маски. Проверка ответа кодом. | Решить шесть задач формата ЕГЭ на адресацию и проверить их программой. |
# | 21 | Веб-технологии: HTML и CSS | Структура документа, семантические теги, ссылки, таблицы, формы. Основы CSS: селекторы и свойства. Как работает браузер. | Собрать страницу-портфолио из готовых блоков с оформлением. |
# | 22 | Защита информации и шифрование | Симметричное и асимметричное шифрование на понятном уровне. Хеширование и электронная подпись. Практика: реализация простых шифров. | Реализовать шифр Цезаря и Виженера, посчитать хеши файлов. |
# | 23 | Обработка табличных данных в Python | Загрузка CSV, структура таблицы, отбор строк и столбцов, новые вычисляемые поля. Пропуски и грязные данные. | Загрузить набор данных, очистить его и посчитать базовую статистику. |
# | 24 | Анализ данных: группировка и агрегация | Группировка по признаку, сводные показатели, сравнение групп. Сортировка результатов. Формулировка выводов по числам. | Ответить на пять содержательных вопросов к набору данных. |
# | 25 | Визуализация и представление результатов | Выбор графика под вопрос. Оформление и подписи. Ошибки визуализации. Сборка отчёта из текста, кода и графиков. | Собрать мини-отчёт по данным: четыре графика и текстовые выводы. |
# | 26 | Моделирование и численные методы | Численное решение задач: приближённые вычисления, метод половинного деления, метод Монте-Карло. Оценка погрешности. | Найти корень уравнения численно и оценить площадь методом Монте-Карло. |
#
# ## IV четверть · уроки 27–34
#
# | № | Тема | Содержание | Домашнее задание |
# |:--:|---|---|---|
# | 27 | Практикум ЕГЭ: обработка файлов данных | Задания 17, 22, 23 и 26: чтение больших файлов, подсчёты по условию, оптимальный выбор. Надёжные шаблоны решения. | Решить шесть задач формата ЕГЭ на обработку файлов. |
# | 28 | Контрольная работа № 3 | Разбор ошибок. Самостоятельная работа: сети, данные, моделирование. | Итоговые задачи четверти с автопроверкой. |
# | 29 | Электронные таблицы: продвинутые приёмы | Сводные таблицы, функции подстановки, массивы значений, сценарии и подбор параметра. Таблица против кода: осознанный выбор. | Решить аналитическую задачу таблицей и кодом, сравнить подходы. |
# | 30 | Логика в задачах ЕГЭ | Логические выражения с переменными, таблицы с пропусками, логические уравнения и подсчёт числа решений. Проверка перебором. | Решить восемь задач формата ЕГЭ на логику. |
# | 31 | Выигрышные стратегии в играх | Игры с двумя игроками и полной информацией. Дерево игры, выигрышные и проигрышные позиции. Разбор классических задач. | Проанализировать три игры и построить дерево выигрышной стратегии. |
# | 32 | Практикум ЕГЭ: программирование | Задания 24–27: обработка строк большого объёма, поиск оптимума, задачи с двумя проходами по данным. Разбор эталонных решений. | Решить пять задач формата ЕГЭ на программирование. |
# | 33 | Итоговый проект и защита | Финальный проект: содержательная задача, реализация, результат. Представление работ и рецензирование. | Реализовать проект и подготовить выступление. |
# | 34 | Повторение перед экзаменом и итоговая работа | Разбор полного варианта ЕГЭ: стратегия, порядок решения, проверка ответов, типичные потери баллов. Итоговая работа за курс старшей школы. | Прорешать полный вариант ЕГЭ и итоговую работу с автопроверкой. |
#
# ---
#
# [🏠 Ко всем классам](https://colab.research.google.com/github/LeksssGray/informatika-7-11/blob/main/index.ipynb)
