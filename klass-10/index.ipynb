# %% [markdown]
# # 10 класс. Теоретические основы информатики и уверенный Python
#
# Первый год старшей школы. Возвращаемся к кодированию, системам счисления и логике на взрослом уровне строгости, разбираем архитектуру компьютера — и параллельно выводим Python на рабочий уровень: словари, множества, файлы, модули, сортировки и оценка сложности алгоритмов.
#
# [🏠 Ко всем классам](https://colab.research.google.com/github/LeksssGray/informatika-7-11/blob/main/index.ipynb)
#
# ---
#
# ### Чему научишься за год
#
# - рассчитывать объём текста, графики и звука при любом способе кодирования
# - решать логические уравнения и преобразовывать выражения
# - свободно пользоваться списками, словарями, множествами и файлами
# - реализовывать и оценивать алгоритмы поиска и сортировки
# - обрабатывать и визуализировать наборы данных
#
# ---
#
# ## I четверть · уроки 1–8
#
# | № | Тема | Содержание | Домашнее задание |
# |:--:|---|---|---|
# | 1 | **[Учебник, Colab и информация](https://colab.research.google.com/github/LeksssGray/informatika-7-11/blob/main/klass-10/urok-01.ipynb)** | Что и зачем изучаем два года. Подходы к определению информации. Свойства информации. Диагностическая работа за основную школу. | Диагностическая работа и разбор своих пробелов. |
# | 2 | **[Кодирование текстовой информации](https://colab.research.google.com/github/LeksssGray/informatika-7-11/blob/main/klass-10/urok-02.ipynb)** | Однобайтные кодировки и таблица ASCII. Unicode, UTF-8 и переменная длина символа. Расчёт объёма текста. Мощность алфавита. | Задачи на объём текста в разных кодировках; эксперимент с байтами в коде. |
# | 3 | **[Кодирование графической информации](https://colab.research.google.com/github/LeksssGray/informatika-7-11/blob/main/klass-10/urok-03.ipynb)** | Растровое изображение: разрешение, глубина цвета, палитра. Формула объёма. Сжатие с потерями и без. Векторное представление. | Задачи на объём изображения и подбор параметров под ограничение по размеру. |
# | 4 | **[Кодирование звука](https://colab.research.google.com/github/LeksssGray/informatika-7-11/blob/main/klass-10/urok-04.ipynb)** | Дискретизация: частота и глубина кодирования. Формула объёма аудио. Каналы. Качество и размер файла. Форматы звука. | Задачи на объём аудиофайла и расчёт длительности записи. |
# | 5 | **[Системы счисления: углубление](https://colab.research.google.com/github/LeksssGray/informatika-7-11/blob/main/klass-10/urok-05.ipynb)** | Позиционные системы с произвольным основанием. Быстрые переводы. Числа в системах с основанием, кратным двум. Сравнение чисел в разных системах. | Задачи повышенной сложности на переводы и сравнение. |
# | 6 | **[Арифметика в системах счисления](https://colab.research.google.com/github/LeksssGray/informatika-7-11/blob/main/klass-10/urok-06.ipynb)** | Сложение, вычитание, умножение в двоичной и других системах. Уравнения с числами в разных системах. Определение основания по записи. | Решить уравнения и найти основание системы по условию. |
# | 7 | **[Представление чисел в памяти компьютера](https://colab.research.google.com/github/LeksssGray/informatika-7-11/blob/main/klass-10/urok-07.ipynb)** | Разрядность, диапазоны, переполнение. Дополнительный код. Числа с плавающей запятой и потеря точности. Сравнение вещественных чисел. | Исследовать границы типов и точность вычислений экспериментом в коде. |
# | 8 | **[Контрольная работа № 1: кодирование и системы счисления](https://colab.research.google.com/github/LeksssGray/informatika-7-11/blob/main/klass-10/urok-08.ipynb)** | Разбор типовых ошибок. Самостоятельная работа за четверть. | Итоговые задачи четверти с автопроверкой. |
#
# ## II четверть · уроки 9–16
#
# | № | Тема | Содержание | Домашнее задание |
# |:--:|---|---|---|
# | 9 | Алгебра логики: полный набор операций | Конъюнкция, дизъюнкция, инверсия, импликация, эквиваленция, исключающее ИЛИ. Приоритет операций. Таблицы истинности. | Построить таблицы истинности выражений с импликацией и проверить их кодом. |
# | 10 | Преобразование логических выражений | Законы алгебры логики. Правила де Моргана. Раскрытие импликации. Приведение к нормальной форме. Доказательство тождеств. | Упростить шесть выражений и доказать два тождества. |
# | 11 | Логические уравнения | Решение уравнений и систем логических уравнений. Подсчёт числа решений. Метод отображения и метод перебора. Проверка перебором в коде. | Решить три логических уравнения и подтвердить ответ перебором. |
# | 12 | Логические схемы и элементы | Базовые логические элементы. Составление схем по выражениям. Полусумматор и сумматор. Триггер как элемент памяти. | Построить схему по выражению и смоделировать её работу функциями Python. |
# | 13 | Архитектура компьютера | Принципы фон Неймана. Процессор: АЛУ, регистры, устройство управления. Иерархия памяти и кэш. Шина. Что реально влияет на скорость. | Сравнить конфигурации компьютеров под три сценария использования. |
# | 14 | Программное обеспечение и операционные системы | Задачи операционной системы: процессы, память, файлы, устройства. Виды ПО. Виртуализация и облако. Colab как пример облачной среды. | Исследовать характеристики виртуальной машины Colab командами системы. |
# | 15 | Файловые системы и хранение данных | Организация файловой системы. Пути, маски, права доступа. Объём и фрагментация. Резервное копирование. Форматы хранения данных. | Задачи на маски и пути; практическая работа с файлами в Colab. |
# | 16 | Контрольная работа № 2: логика и архитектура | Разбор ошибок. Самостоятельная работа за четверть. | Итоговые задачи четверти с автопроверкой. |
#
# ## III четверть · уроки 17–26
#
# | № | Тема | Содержание | Домашнее задание |
# |:--:|---|---|---|
# | 17 | Python: типы, операции, ввод-вывод | Систематическое повторение: типы данных и их операции, приведение типов, ввод нескольких значений, форматирование вывода. | Разминочный блок из восьми задач на базовый синтаксис. |
# | 18 | Ветвления и циклы: сложные задачи | Разбор задач, где условие и цикл переплетены. Досрочный выход, else у цикла, флаги. Инвариант цикла как способ рассуждать о правильности. | Шесть задач на сочетание ветвлений и циклов. |
# | 19 | Функции и области видимости | Аргументы позиционные и именованные, значения по умолчанию, произвольное число аргументов. Локальные и глобальные имена. Чистые функции. | Написать библиотеку функций и покрыть её тестами через assert. |
# | 20 | Списки и их методы | Методы списка, срезы, копирование и подводные камни ссылок. Генераторы списков. Сортировка с ключом. Распаковка. | Задачи на генераторы списков и сортировку по нестандартному ключу. |
# | 21 | Двумерные списки и матрицы | Создание матрицы, обход, обработка строк и столбцов. Диагонали. Транспонирование. Типичные ошибки при создании матрицы. | Пять задач на обработку матриц, включая поворот и подсчёт по областям. |
# | 22 | Строки: срезы, методы, форматирование | Неизменяемость строк. Срезы с шагом. Методы поиска и замены. split и join. Форматирование и выравнивание вывода. | Задачи на разбор и сборку текста, шифрование и проверку формата. |
# | 23 | Словари и множества | Словарь: структура, методы, перебор, значения по умолчанию. Множество и операции над множествами. Выбор структуры данных под задачу. | Задачи: частотный анализ, поиск уникальных элементов, пересечение наборов. |
# | 24 | Файлы и обработка данных | Чтение и запись текстовых файлов, форматы CSV и JSON. Разбор строк в записи. Накопление статистики по файлу. | Обработать CSV-файл и сформировать отчёт с расчётами. |
# | 25 | Стандартные модули: math, random, itertools | Импорт модулей. Математические функции. Случайные числа и воспроизводимость. Комбинаторные генераторы и перебор вариантов. | Решить задачи перебором с помощью itertools и провести статистический опыт. |
# | 26 | Контрольная работа № 3: программирование | Разбор ошибок. Самостоятельная работа по структурам данных и обработке файлов. | Итоговые задачи четверти с автопроверкой. |
#
# ## IV четверть · уроки 27–34
#
# | № | Тема | Содержание | Домашнее задание |
# |:--:|---|---|---|
# | 27 | Алгоритмы поиска и сортировки | Линейный и двоичный поиск. Сортировки выбором, вставками, пузырьком. Быстрая сортировка в общих чертах. Устойчивость сортировки. | Реализовать три сортировки и сравнить их на данных разного размера. |
# | 28 | Оценка сложности алгоритмов | Число операций как функция размера входа. Классы O(1), O(log n), O(n), O(n log n), O(n²). Как выбрать алгоритм под ограничения задачи. | Определить сложность шести алгоритмов и подтвердить замерами времени. |
# | 29 | Рекурсия и перебор вариантов | Рекурсивные определения. Дерево вызовов. Полный перебор с возвратом. Мемоизация как способ ускорить рекурсию. | Решить задачи перебором с возвратом и ускорить рекурсию мемоизацией. |
# | 30 | Обработка последовательностей: типовые задачи | Классические задачи: подпоследовательности, скользящее окно, накопленные суммы, поиск серий. Шаблоны решений, которые работают всегда. | Шесть типовых задач на последовательности с автопроверкой. |
# | 31 | Электронные таблицы: анализ данных | Сводные таблицы. Функции поиска и подстановки. Многокритериальный отбор. Когда таблица перестаёт справляться и нужен код. | Проанализировать набор данных сводной таблицей и повторить расчёт в коде. |
# | 32 | Визуализация данных в Python | Построение графиков: линия, столбцы, точечная диаграмма, гистограмма. Подписи и оформление. Как выбрать график, который не врёт. | Построить четыре графика по своему набору данных и описать выводы. |
# | 33 | Годовой проект | Проект по обработке данных или моделированию: постановка, реализация, выводы. Требования к коду и оформлению. | Реализовать и оформить проект в отдельном ноутбуке. |
# | 34 | Итоговая контрольная работа | Годовое повторение: кодирование, логика, структуры данных, алгоритмы. Итоговая работа. | Итоговая работа за 10 класс с автопроверкой. |
#
# ---
#
# [🏠 Ко всем классам](https://colab.research.google.com/github/LeksssGray/informatika-7-11/blob/main/index.ipynb)
