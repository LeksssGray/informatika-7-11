# %% [markdown]
# # Урок 1. Учебник, Colab и информация
#
# 10 класс · I четверть
#
# [⬆ Все уроки](https://colab.research.google.com/github/LeksssGray/informatika-7-11/blob/main/klass-10/index.ipynb) · [Урок 2 →](https://colab.research.google.com/github/LeksssGray/informatika-7-11/blob/main/klass-10/urok-02.ipynb)
#
# ---
#
# Что и зачем изучаем два года. Подходы к определению информации. Свойства информации. Диагностическая работа за основную школу.

# %%
#@title 🚀 Шаг 1. Регистрация и подготовка урока { display-mode: "form" }
#@markdown Впиши свои данные и запусти ячейку (Shift+Enter).
ФИО = "" #@param {type:"string"}
Класс = "10А" #@param {type:"string"}

import importlib, urllib.request
urllib.request.urlretrieve("https://raw.githubusercontent.com/LeksssGray/informatika-7-11/main/lib/schoolinf.py", "schoolinf.py")
import schoolinf as si
importlib.reload(si)
si.start(lesson="10-01", name=ФИО, klass=Класс)

# %% [markdown]
# ## Как работать с учебником
#
# Учебник живой: это не текст, который читают, а страница, на которой
# нажимают кнопки. Если ты уже работал с ней в прошлом году — пролистай
# этот раздел и иди дальше. Если нет, разберёмся за пару минут.
#
# ### Страница собрана из ячеек
#
# **Текстовые** — объяснения, таблицы, формулы. Вот эта, например.
#
# **Кодовые** — программы. Слева у них кнопка ▶. Нажали — выполнилось,
# результат появился внизу.
#
# Запускать можно кнопкой или клавишами **Shift + Enter**.
#
# > Ячейки выполняются в том порядке, в котором вы нажимаете кнопку,
# > а не в том, в котором они на странице. Пропустите ячейку — следующая
# > может не заработать. Идите сверху вниз.
#
# ### Первым делом — своя копия
#
# Файл общий на весь класс, ваши правки в нём не сохранятся.
# **Файл → Сохранить копию на Диске**, и дальше работайте в копии.
#
# Заведите папку для предмета: за год наберётся тридцать четыре файла.
#
# ### Как устроен урок
#
# Сначала разбираем тему. Потом примеры — их можно и нужно менять,
# ломать и запускать заново, на то они и живые. Потом задачи с проверкой
# прямо на месте. В конце домашнее задание.
#
# ### Проверка и журнал
#
# Ячейки проверки показывают, что именно не сошлось: какой тест упал
# и с какими данными. Попыток сколько угодно.
#
# Результат уходит учителю: видно, какие задачи решены, с какой попытки
# и каким кодом. Списанное решение заметно сразу — оно не похоже
# на всё остальное, что вы пишете.
#
# ### Если что-то сломалось
#
# Сломать нельзя ничего. В крайнем случае — **Среда выполнения →
# Перезапустить сеанс**, и всё начнётся с чистого листа.
#
# Красное сообщение об ошибке — не катастрофа. Главное в нём —
# последняя строка, там написано, что именно не понравилось.

# %% [markdown]
# ## Разбираемся
#
# ### Два года до финиша
#
# Старшая школа — не повторение основной, а другой уровень строгости.
# То, что в 8 классе выглядело набором приёмов, здесь становится системой
# с определениями, формулами и доказательствами.
#
# **10 класс — теоретический фундамент.** Кодирование всех видов информации,
# алгебра логики с уравнениями, архитектура компьютера, структуры данных
# и алгоритмы с оценкой сложности.
#
# **11 класс — применение.** Эффективные алгоритмы, графы, базы данных
# и SQL, сети, анализ данных, подготовка к экзамену.
#
# ### Что такое информация: три подхода
#
# В 7 классе мы обошлись рабочим описанием. Теперь стоит знать,
# что единого определения нет, и разные науки понимают информацию по-своему.
#
# **Обыденный подход.** Информация — сведения, знания, сообщения.
# Годится для разговора, но не для расчётов: как измерить «сведения»?
#
# **Кибернетический подход** (Норберт Винер). Информация — то, что
# уменьшает неопределённость. Именно он даёт формулу $N = 2^i$
# и позволяет измерять информацию в битах.
#
# **Вероятностный подход** (Клод Шеннон, 1948). Обобщение
# кибернетического на случай **неравновероятных** событий.
#
# Если у события вероятность p, то количество информации в сообщении
# о нём равно
#
# $$i = \log_2 \frac{1}{p} = -\log_2 p$$
#
# Смысл прозрачен: **чем неожиданнее событие, тем больше информации
# в сообщении о нём**. Сообщение «завтра в Сахаре не будет дождя» почти
# не несёт информации — это и так известно. Сообщение «завтра в Сахаре
# снег» несёт огромную информацию.
#
# Проверим согласованность с прежней формулой. Если исходов N
# и они равновероятны, то $p = 1/N$, и
#
# $$i = \log_2 N$$
#
# что в точности равносильно $N = 2^i$. Новая формула не отменяет старую,
# а включает её как частный случай.
#
# ### Свойства информации
#
# | Свойство | Что означает | Пример нарушения |
# |---|---|---|
# | **достоверность** | соответствует реальности | слух, фейк |
# | **полнота** | достаточна для решения | прогноз без указания города |
# | **актуальность** | своевременна | вчерашнее расписание |
# | **понятность** | доступна получателю | текст на незнакомом языке |
# | **ценность** | полезна для задачи | точное время на необитаемом острове |
#
# Обратите внимание: почти все свойства **относительны**. Информация
# ценна или бесполезна не сама по себе, а для конкретного получателя
# и конкретной задачи. Единственное безусловное свойство — достоверность.
#
# ### Как мы будем работать
#
# 1. Каждый урок сохраняйте копию на свой Диск — за два года наберётся
#    полный конспект, с которым удобно готовиться к экзамену.
# 2. Домашние задания проверяются автоматически, но учитель видит
#    и ваш код, и число попыток.
# 3. Отдельный раздел **тренажёра ЕГЭ** идёт параллельно курсу
#    и не обязателен — он для тех, кто сдаёт экзамен.

# %% [markdown]
# ## Смотрим, как это работает
#
# ### Пример 1. Формула Шеннона в действии
#
# Посчитаем количество информации для событий разной вероятности.

# %%
import math

события = [
    ("монета — орёл", 0.5),
    ("кубик — шестёрка", 1 / 6),
    ("карта — туз пик", 1 / 36),
    ("выигрыш в лотерею", 1 / 1000000),
    ("завтра будет день", 0.999999),
]

print(f"{'событие':<24} {'вероятность':>12} {'информация, бит':>18}")
for название, p in события:
    i = -math.log2(p)
    print(f"{название:<24} {p:>12.6f} {i:>18.2f}")

# %% [markdown]
# Крайние строки показывают суть формулы. Почти достоверное событие
# несёт около нуля бит информации — мы и так это знали. Невероятное
# событие несёт двадцать бит: узнав о выигрыше, мы получили много нового.
#
# Функция `math.log2` вычисляет логарифм по основанию 2 — то самое,
# что отвечает на вопрос «в какую степень возвести двойку».

# %% [markdown]
# ### Пример 2. Согласованность с формулой N = 2ⁱ
#
# Убедимся, что вероятностный подход не противоречит алфавитному.

# %%
print(f"{'исходов N':>10} {'через N = 2^i':>15} {'через Шеннона':>15}")
for N in [2, 4, 8, 16, 32, 256]:
    через_степень = math.log2(N)
    через_шеннона = -math.log2(1 / N)
    print(f"{N:>10} {через_степень:>15.1f} {через_шеннона:>15.1f}")

# %% [markdown]
# Столбцы совпали полностью: для равновероятных исходов обе формулы
# дают один и тот же ответ. Это и означает, что подход Шеннона
# обобщает, а не заменяет уже известное.

# %% [markdown]
# ### Пример 3. Информация в реальном тексте
#
# В русском языке буквы встречаются с разной частотой. Посчитаем,
# сколько информации несёт каждая, и сравним с наивной оценкой.

# %%
# Приблизительные частоты некоторых букв русского языка
частоты = {"о": 0.110, "е": 0.085, "а": 0.080, "и": 0.074,
           "н": 0.067, "ъ": 0.0004, "ф": 0.002, "э": 0.003}

print("Наивная оценка (33 равновероятные буквы):",
      f"{math.log2(33):.2f} бит на букву")
print()
print(f"{'буква':>6} {'частота':>10} {'информация':>12}")
for буква, p in частоты.items():
    print(f"{буква:>6} {p:>10.4f} {-math.log2(p):>12.2f}")

# %% [markdown]
# Частая буква «о» несёт около 3,2 бита, а редчайший «ъ» — почти 11.
# Средняя информация на букву в русском тексте получается примерно
# 4,35 бита вместо наивных 5,04.
#
# Разница в 0,7 бита на букву кажется мелочью, но именно на ней
# работают **архиваторы**: чем неравномернее частоты, тем сильнее
# можно сжать текст. К алгоритмам сжатия мы вернёмся позже.

# %% [markdown]
# ## Проверяем, что помним
#
# Задачи на повторение основной школы и на сегодняшнюю тему.

# %% [markdown]
# ### Задача 1. Количество информации по Шеннону
#
# По вероятности события верните количество информации в битах,
# округлённое до двух знаков.
#
# Понадобится `math.log2`. Модуль уже импортирован выше.

# %%
def информация(вероятность):
    return ...

# %%
si.check("1", информация, [
    (0.5, 1.0),
    (0.25, 2.0),
    (1.0, 0.0),
    (0.125, 3.0),
])

# %% [markdown]
# ### Задача 2. Объём текста
#
# Мощность алфавита `N`, количество символов `количество`.
# Верните объём в **байтах**, округлив вверх до целого числа байт.
#
# Округление вверх: `(биты + 7) // 8`.

# %%
def объём(N, количество):
    return ...

# %%
si.check("2", объём, [
    ((32, 100), 63),
    ((256, 10), 10),
    ((16, 200), 100),
    ((2, 8), 1),
])

# %% [markdown]
# ### Задача 3. Повторение: системы счисления
#
# Переведите число из одной системы в другую.

# %%
def перевести(запись, откуда, куда):
    return ...

# %%
si.check("3", перевести, [
    (("1011", 2, 16), "B"),
    (("FF", 16, 8), "377"),
    (("100", 10, 2), "1100100"),
])

# %% [markdown]
# ### Задача 4. Повторение: обработка массива
#
# Верните индекс первого элемента, который больше всех предыдущих.
# Первый элемент не считается (перед ним ничего нет).
# Если такого нет — верните `-1`.
#
# `[3, 1, 5, 2]` → `2`, потому что 5 больше и 3, и 1.

# %%
def первый_рекорд(массив):
    return ...

# %%
si.check("4", первый_рекорд, [
    ([3, 1, 5, 2], 2),
    ([5, 4, 3], -1),
    ([1, 2], 1),
    ([7], -1),
])

# %% [markdown]
# ### Задача 5. Повторение: двумерный массив
#
# Верните список сумм по строкам таблицы.

# %%
def суммы_строк(таблица):
    return ...

# %%
si.check("5", суммы_строк, [
    ([[1, 2], [3, 4]], [3, 7]),
    ([[5]], [5]),
    ([[0, 0], [0, 0]], [0, 0]),
])

# %% [markdown]
# ### Задача 6. Свойства информации
#
# Напишите функцию, которая по описанию ситуации возвращает нарушенное
# свойство информации: `"достоверность"`, `"актуальность"`,
# `"полнота"` или `"понятность"`.
#
# | Ситуация | Нарушено |
# |---|---|
# | `"прогноз погоды за прошлый год"` | актуальность |
# | `"текст на неизвестном языке"` | понятность |
# | `"слух из непроверенного источника"` | достоверность |
# | `"расписание без указания кабинетов"` | полнота |

# %%
def нарушено(ситуация):
    return ...

# %%
si.check("6", нарушено, [
    ("прогноз погоды за прошлый год", "актуальность"),
    ("текст на неизвестном языке", "понятность"),
    ("слух из непроверенного источника", "достоверность"),
    ("расписание без указания кабинетов", "полнота"),
])

# %% [markdown]
# ## Домашнее задание

# %% [markdown]
# ### Домашнее задание 1. Средняя информация на символ
#
# Дан список вероятностей символов алфавита. Верните среднее количество
# информации на символ по формуле Шеннона:
#
# $$H = -\sum p_i \log_2 p_i$$
#
# Округлите до трёх знаков. Вероятности, равные нулю, пропускайте —
# логарифм нуля не определён.

# %%
def энтропия(вероятности):
    return ...

# %%
si.check("дз1", энтропия, [
    ([0.5, 0.5], 1.0),
    ([0.25, 0.25, 0.25, 0.25], 2.0),
    ([1.0], 0.0),
    ([0.5, 0.25, 0.25], 1.5),
])

# %% [markdown]
# ### Домашнее задание 2. Выигрыш от сжатия
#
# Наивное кодирование отводит на символ $\lceil\log_2 N\rceil$ бит,
# где N — мощность алфавита. Оптимальное — столько бит, сколько даёт
# энтропия.
#
# Напишите функцию, которая по списку вероятностей возвращает,
# **на сколько процентов** можно сжать текст, округлив до целого.
#
# Формула: (наивное − энтропия) ÷ наивное × 100 %.

# %%
def выигрыш(вероятности):
    return ...

# %%
si.check("дз2", выигрыш, [
    ([0.5, 0.5], 0),
    ([0.9, 0.1], 53),
    ([0.25, 0.25, 0.25, 0.25], 0),
])

# %% [markdown]
# ### Домашнее задание 3. Двадцать вопросов
#
# Классическая игра: загадано слово из словаря, за сколько вопросов
# «да/нет» его гарантированно можно угадать?
#
# Напишите функцию, которая по размеру словаря возвращает минимальное
# число вопросов. Ответ — округление логарифма **вверх**.
#
# И заодно ответьте себе: почему игра называется «двадцать вопросов»
# и сколько слов различают двадцать вопросов?

# %%
def вопросов(слов):
    return ...

# %%
si.check("дз3", вопросов, [
    (2, 1),
    (4, 2),
    (5, 3),
    (1000, 10),
    (1000000, 20),
])

# %% [markdown]
# ---
#
# ### Ответ на вопрос из задания
#
# Двадцать вопросов различают $2^{20}$, то есть более миллиона вариантов —
# больше, чем слов в любом словаре. Игра названа так не случайно:
# двадцати вопросов гарантированно хватает на любое существительное
# русского языка.
#
# На следующем уроке мы применим ту же математику к конкретной задаче —
# кодированию текста, и разберём, почему одна и та же буква занимает
# один байт в одной кодировке и два в другой.

# %% [markdown]
# ---
#
# ## Отчёт по уроку
#
# Запусти ячейку ниже, когда решишь задачи. Результат уйдёт учителю автоматически.

# %%
si.report()

# %% [markdown]
# ---
#
# [⬆ Все уроки](https://colab.research.google.com/github/LeksssGray/informatika-7-11/blob/main/klass-10/index.ipynb) · [🏠 Ко всем классам](https://colab.research.google.com/github/LeksssGray/informatika-7-11/blob/main/index.ipynb) · [Урок 2 →](https://colab.research.google.com/github/LeksssGray/informatika-7-11/blob/main/klass-10/urok-02.ipynb)
