# %% [markdown]
# # Урок 3. Измерение информации: бит и байт
#
# 7 класс · I четверть
#
# [⬆ Все уроки](https://colab.research.google.com/github/LeksssGray/informatika-7-11/blob/main/klass-07/index.ipynb) · [← Урок 2](https://colab.research.google.com/github/LeksssGray/informatika-7-11/blob/main/klass-07/urok-02.ipynb) · [Урок 4 →](https://colab.research.google.com/github/LeksssGray/informatika-7-11/blob/main/klass-07/urok-04.ipynb)
#
# ---
#
# Алфавитный подход к измерению информации. Бит как ответ на вопрос «да или нет». Байт, килобайт, мегабайт, гигабайт. Формула N = 2^i. Расчёт информационного объёма сообщения.

# %%
#@title 🚀 Шаг 1. Регистрация и подготовка урока { display-mode: "form" }
#@markdown Впиши свои данные и запусти ячейку (Shift+Enter).
ФИО = "" #@param {type:"string"}
Класс = "7А" #@param {type:"string"}

import importlib, urllib.request
urllib.request.urlretrieve("https://raw.githubusercontent.com/LeksssGray/informatika-7-11/main/lib/schoolinf.py", "schoolinf.py")
import schoolinf as si
importlib.reload(si)
si.start(lesson="07-03", name=ФИО, klass=Класс)

# %% [markdown]
# ## Разбираемся
#
# ### Как измерить то, чего не видно
#
# В прошлый раз договорились: информация уменьшает незнание. Значит
# и мерить её можно тем, насколько сильно это незнание уменьшилось.
#
# Самый простой случай. Я загадал: орёл или решка. Вариантов два, оба
# одинаково вероятны. Ты спросил, я ответил — и незнания больше нет.
#
# > Количество информации в сообщении, которое выбирает **один вариант
# > из двух равновозможных**, приняли за единицу. Она называется **бит**.
#
# Слово от английского *binary digit* — «двоичная цифра». Один бит это
# ответ «да» или «нет». Ноль или единица. Есть сигнал или нет сигнала.
#
# ### Вариантов больше — информации больше
#
# А если вариантов четыре? Скажем, я загадал масть карты. Одним вопросом
# не обойтись, но двумя — легко:
#
# ```
# Красная?  ──да──→  Черви?   ──да──→  ЧЕРВИ
#                             ──нет─→  БУБНЫ
#           ──нет─→  Пики?    ──да──→  ПИКИ
#                             ──нет─→  ТРЕФЫ
# ```
#
# Два вопроса — два бита. Видишь закономерность? 2 варианта — 1 бит,
# 4 варианта — 2 бита, 8 вариантов — 3 бита. Каждый новый бит **удваивает**
# число вариантов, которые можно различить.
#
# ### Главная формула
#
# $$N = 2^i$$
#
# **N** — сколько равновозможных вариантов, **i** — сколько бит информации.
#
# | N вариантов | 2 | 4 | 8 | 16 | 32 | 64 | 128 | 256 |
# |---|---|---|---|---|---|---|---|---|
# | i бит | 1 | 2 | 3 | 4 | 5 | 6 | 7 | 8 |
#
# Эту табличку стоит выучить. Она будет нужна почти в каждой задаче
# до конца школы.
#
# ### Байт и всё, что больше
#
# Одним битом много не скажешь, поэтому их объединили по восемь:
#
# > **1 байт = 8 бит**
#
# Восемь бит дают 256 вариантов — как раз хватает на все буквы, цифры
# и знаки препинания. Поэтому один символ текста исторически весил
# ровно байт.
#
# Дальше единицы растут **не по тысяче, а по 1024**, потому что 1024 —
# это два в десятой степени, круглое число в двоичном мире:
#
# | Единица | Это сколько | В байтах |
# |---|---|---|
# | 1 килобайт | 1024 байта | 1 024 |
# | 1 мегабайт | 1024 Кбайт | 1 048 576 |
# | 1 гигабайт | 1024 Мбайт | 1 073 741 824 |
#
# ### Сколько весит текст
#
# Порядок такой:
#
# 1. считаем **мощность алфавита** N — сколько разных символов может
#    встретиться, включая пробелы и запятые;
# 2. по формуле находим i — сколько бит на **один** символ;
# 3. умножаем i на количество символов в тексте.
#
# Например: алфавит из 32 символов, текст из 100 символов. Раз 32 это два
# в пятой, символ весит 5 бит. Весь текст — 500 бит, то есть 62,5 байта.

# %% [markdown]
# ## Смотрим, как это работает
#
# ### Степени двойки
#
# Проверим таблицу из теории — пусть компьютер её напечатает.

# %%
бит = 1
while бит <= 8:
    print(f"{бит} бит различает {2 ** бит} вариантов")
    бит = бит + 1

# %% [markdown]
# Цикл повторяет одно и то же, увеличивая счётчик. Мы разберём циклы
# подробно во второй четверти, пока просто посмотри на числа: каждая
# строчка вдвое больше предыдущей.

# %% [markdown]
# ### Переводим единицы
#
# Три мегабайта в биты — по шагам, чтобы видеть каждое действие.

# %%
мегабайты = 3
килобайты = мегабайты * 1024
байты = килобайты * 1024
биты = байты * 8

print(мегабайты, "Мбайт =", килобайты, "Кбайт")
print(килобайты, "Кбайт =", байты, "байт")
print(байты, "байт =", биты, "бит")

# %% [markdown]
# Правило простое: **вниз по таблице умножаем, вверх — делим**.
# Из мегабайтов в байты — дважды умножить на 1024. Обратно — дважды
# разделить.

# %% [markdown]
# ### Считаем объём текста

# %%
символов = 100
бит_на_символ = 5        # потому что алфавит из 32 символов, а 32 = 2⁵

объём_бит = бит_на_символ * символов
объём_байт = объём_бит / 8

print("Один символ весит", бит_на_символ, "бит")
print("Весь текст:", объём_бит, "бит =", объём_байт, "байт")

# %% [markdown]
# Получилось 62,5 байта — дробное число, и это нормально. Байт нужен
# для хранения, а символ вовсе не обязан занимать целое их количество.

# %% [markdown]
# ## Пробуем сами

# %% [markdown]
# ### Задача 1. Килобайт в битах
#
# Сколько бит в одном килобайте? Пусть считает компьютер.

# %%
бит_в_килобайте = ...

print(бит_в_килобайте)

# %%
si.ответ("1", бит_в_килобайте, "864a936a35324151",
         hint="Сначала в байты, потом каждый байт — это восемь бит.")

# %% [markdown]
# ### Задача 2. Бит на символ
#
# В алфавите 32 символа. Сколько бит нужно на один символ?
#
# Загляни в таблицу из теории или подбери: какая степень двойки даёт 32?

# %%
бит = ...

si.ответ("2", бит, "ef2d127de37b942b",
         hint="2·2·2·2·2 — сколько тут двоек?")

# %% [markdown]
# ### Задача 3. Объём сообщения
#
# Алфавит из 32 символов, в сообщении 100 символов.
# Сколько это **байт**?
#
# Один символ весит 5 бит — это ты уже выяснил. Осталось умножить
# и перевести в байты.

# %%
объём = ...

print(объём)

# %%
si.ответ("3", объём, "bff1c57ce1058197",
         hint="Бит на символ умножить на количество символов, потом разделить на 8.")

# %% [markdown]
# ## Домашнее задание

# %% [markdown]
# ### 1. Мегабайт в байтах
#
# Сколько байт в двух мегабайтах?

# %%
байт_в_двух_мегабайтах = ...

print(байт_в_двух_мегабайтах)

# %%
si.ответ("дз1", байт_в_двух_мегабайтах, "107f41ed92e01eb5",
         hint="Мегабайты в килобайты, килобайты в байты. Оба раза по 1024.")

# %% [markdown]
# ### 2. Задача наоборот
#
# > Сообщение весит 1,5 Кбайта и содержит 3072 символа.
# > Сколько символов в алфавите, которым оно записано?
#
# Ход мысли: переведи объём в биты, раздели на количество символов —
# получишь биты на один символ. Дальше по формуле $N = 2^i$.
#
# Считать можно и в ячейке, и на бумаге — как удобнее.

# %%
мощность_алфавита = ...

si.ответ("дз2", мощность_алфавита, "b17ef6d19c7a5b1e",
         hint="1,5 Кбайт это 1536 байт, то есть 12288 бит. Раздели на 3072.")

# %% [markdown]
# ### 3. Влезет ли на флешку
#
# Фильм весит 500 Мбайт, на флешке свободен 1 Гбайт.
# Поместится? Впиши `"да"` или `"нет"`.
#
# Чтобы сравнивать, приведи обе величины к одной единице.

# %%
поместится = "???"

si.ответ("дз3", поместится, "2b81d6a2f0b615c6",
         hint="Сколько мегабайт в гигабайте? Точно не тысяча.")

# %% [markdown]
# ---
#
# ### Кстати
#
# Продавцы дисков считают гигабайт как ровно миллиард байт, а компьютер —
# как 1 073 741 824. Поэтому диск «на 500 Гбайт» показывается в системе
# как 465. Байты одни и те же, единицы разные. Теперь ты знаешь,
# где спрятана разница, и тебя этим не обманешь.

# %% [markdown]
# ---
#
# ## Отчёт по уроку
#
# Запусти ячейку ниже, когда решишь задачи. Результат уйдёт учителю автоматически.

# %%
si.report()

# %% [markdown]
# ---
#
# [← Урок 2](https://colab.research.google.com/github/LeksssGray/informatika-7-11/blob/main/klass-07/urok-02.ipynb) · [⬆ Все уроки](https://colab.research.google.com/github/LeksssGray/informatika-7-11/blob/main/klass-07/index.ipynb) · [🏠 Ко всем классам](https://colab.research.google.com/github/LeksssGray/informatika-7-11/blob/main/index.ipynb) · [Урок 4 →](https://colab.research.google.com/github/LeksssGray/informatika-7-11/blob/main/klass-07/urok-04.ipynb)
