# %% [markdown]
# # 7 класс. Информация, компьютер и первые программы
#
# Стартовый год курса. Разбираемся, что такое информация и как она кодируется, как устроен компьютер — и уже с первого месяца пишем настоящий код на Python: вывод, переменные, ветвления, циклы, списки. Параллельно осваиваем логику, компьютерную графику и электронные таблицы.
#
# [🏠 Ко всем классам](https://colab.research.google.com/github/LeksssGray/informatika-7-11/blob/main/index.ipynb)
#
# ---
#
# ### Чему научишься за год
#
# - переводить единицы измерения информации и считать объём текста и картинки
# - переводить числа между двоичной и десятичной системами
# - писать программы с ветвлениями, циклами и списками
# - строить таблицы истинности и проверять их кодом
# - работать с формулами и диаграммами в электронных таблицах
#
# ---
#
# ## I четверть · уроки 1–8
#
# | № | Тема | Содержание | Домашнее задание |
# |:--:|---|---|---|
# | 1 | **[Как устроен этот учебник](https://colab.research.google.com/github/LeksssGray/informatika-7-11/blob/main/klass-07/urok-01.ipynb)** | Знакомимся с Colab: ячейки, запуск, своя копия на Диске. Пробуем первые команды и учимся не бояться красных сообщений об ошибках. | Сохранить копию на свой Диск и посчитать несколько величин про себя. |
# | 2 | **[Разминка: что нужно помнить](https://colab.research.google.com/github/LeksssGray/informatika-7-11/blob/main/klass-07/urok-02.ipynb)** | Справочник и проверка перед стартом: доли и проценты, степени двойки, чтение схем и таблиц, что уже знаем про компьютер. Смотрим, где пробелы. | Разминочные задачи по каждому разделу справочника. |
# | 3 | **[Информация и информационные процессы](https://colab.research.google.com/github/LeksssGray/informatika-7-11/blob/main/klass-07/urok-03.ipynb)** | Что такое информация. Виды информации по способу восприятия и по форме представления. Три информационных процесса: хранение, передача, обработка. Источник, канал, приёмник, шум. | Разобрать шесть бытовых ситуаций и определить в каждой тип информационного процесса. |
# | 4 | **[Измерение информации: бит и байт](https://colab.research.google.com/github/LeksssGray/informatika-7-11/blob/main/klass-07/urok-04.ipynb)** | Алфавитный подход к измерению информации. Бит как ответ на вопрос «да или нет». Байт, килобайт, мегабайт, гигабайт. Формула N = 2^i. Расчёт информационного объёма сообщения. | Задачи на перевод единиц и вычисление объёма текста; проверка своих расчётов кодом. |
# | 5 | **[Двоичное кодирование чисел](https://colab.research.google.com/github/LeksssGray/informatika-7-11/blob/main/klass-07/urok-05.ipynb)** | Почему компьютер считает двойками. Разряды двоичного числа. Перевод из двоичной системы в десятичную и обратно. Двоичное сложение на простых примерах. | Перевести числа вручную и написать программу-переводчик, сверив результаты. |
# | 6 | **[Первая программа: print и комментарии](https://colab.research.google.com/github/LeksssGray/informatika-7-11/blob/main/klass-07/urok-06.ipynb)** | Синтаксис print, строки в кавычках, несколько аргументов, параметры sep и end. Комментарии. Типичные ошибки новичка и как читать сообщение об ошибке. | Написать программу, которая печатает визитку и рисунок из символов. |
# | 7 | **[Переменные и типы данных](https://colab.research.google.com/github/LeksssGray/informatika-7-11/blob/main/klass-07/urok-07.ipynb)** | Имя, значение, присваивание. Типы int, float, str, bool и функция type. Правила именования. Переприсваивание и обмен значений двух переменных. | Задачи на вычисления с переменными: периметр, площадь, обмен значений. |
# | 8 | **[Ввод данных и арифметика](https://colab.research.google.com/github/LeksssGray/informatika-7-11/blob/main/klass-07/urok-08.ipynb)** | Функция input и преобразование типов. Арифметические операции, деление нацело и остаток, степень. Порядок действий. Красивый вывод через f-строки. | Написать четыре программы-калькулятора, включая расчёт сдачи и перевод минут в часы. |
#
# ## II четверть · уроки 9–16
#
# | № | Тема | Содержание | Домашнее задание |
# |:--:|---|---|---|
# | 9 | **[Практикум и контрольная работа № 1](https://colab.research.google.com/github/LeksssGray/informatika-7-11/blob/main/klass-07/urok-09.ipynb)** | Разбор типовых ошибок первой четверти. Самостоятельная работа: кодирование информации и линейные программы. | Итоговый набор задач за четверть с автопроверкой. |
# | 10 | Условный оператор if | Ветвление в жизни и в программе. Операции сравнения. Отступы как часть синтаксиса Python. Ветка else и полная форма ветвления. | Задачи: чётность числа, допуск по возрасту, определение знака числа. |
# | 11 | Сложные условия: elif, and, or, not | Множественный выбор через elif. Логические операторы в условиях. Вложенные условия и когда их лучше заменить одним выражением. | Задачи: время года по номеру месяца, оценка по баллам, високосный год. |
# | 12 | Основы логики: таблицы истинности | Высказывание и его истинность. Операции И, ИЛИ, НЕ. Построение таблиц истинности. Связь логических операций с условиями в программе. | Заполнить таблицы истинности для трёх выражений и проверить их программой. |
# | 13 | Устройство компьютера | Процессор, оперативная и постоянная память, устройства ввода и вывода. Магистральная схема. Что означают характеристики в описании компьютера. | Разобрать характеристики трёх компьютеров и обосновать выбор под конкретную задачу. |
# | 14 | Файлы и файловая система | Файл, имя, расширение, размер. Каталоги и дерево папок. Полный путь к файлу. Поиск файлов и маски имён. | Задачи на пути и маски файлов; практика с файловой системой Colab. |
# | 15 | Программное обеспечение | Системное и прикладное ПО. Задачи операционной системы. Лицензии: проприетарное и свободное ПО. Вредоносные программы и защита от них. | Классифицировать двенадцать программ по типам и описать назначение трёх из них. |
# | 16 | Цикл for и range | Повторение как третья базовая конструкция. Цикл for по range. Три формы range. Накопление суммы в цикле. | Задачи: таблица умножения, сумма чисел от 1 до N, обратный отсчёт. |
#
# ## III четверть · уроки 17–26
#
# | № | Тема | Содержание | Домашнее задание |
# |:--:|---|---|---|
# | 17 | Практикум по циклам. Контрольная работа № 2 | Комбинация цикла и условия, счётчики. Самостоятельная работа за вторую четверть. | Итоговые задачи четверти на ветвления и циклы с автопроверкой. |
# | 18 | Цикл while | Цикл с условием. Когда нужен while, а когда for. Бесконечный цикл и как его прервать. Накопление значений и счётчики. | Задачи: сумма цифр числа, игра «угадай число», деление отрезка пополам. |
# | 19 | Кодирование текста: ASCII и Unicode | Символ как число. Кодовая таблица ASCII, кириллица, Unicode и UTF-8. Функции ord и chr. Расчёт объёма текстового файла. | Задачи на объём текста и шифр сдвига через ord и chr. |
# | 20 | Строки в Python | Строка как последовательность символов. Длина, индексы, срезы. Склейка и повторение строк. Методы upper, lower, replace, count. | Задачи: строка наоборот, подсчёт гласных, проверка палиндрома. |
# | 21 | Текстовые документы | Структура документа: заголовки, абзацы, списки. Правила набора текста. Форматирование и стили. Markdown в Colab как современный способ разметки. | Оформить конспект урока в Markdown-ячейке по заданным требованиям. |
# | 22 | Компьютерная графика: растр и вектор | Пиксель и растровое изображение. Разрешение. Векторная графика и её преимущества. Графические форматы и сжатие. | Сравнить растр и вектор на примерах, рассчитать размеры изображений. |
# | 23 | Кодирование цвета: RGB и глубина цвета | Цветовая модель RGB. Глубина цвета и количество оттенков. Расчёт объёма растрового изображения. Палитра и её размер. | Задачи на объём изображения; собрать свой цвет по коду RGB. |
# | 24 | Рисуем изображение программой | Пиксельная картинка как список списков. Вывод изображения средствами Python. Простые фигуры, заливка и градиент. | Нарисовать кодом флаг, шахматную доску и собственный рисунок 16 на 16. |
# | 25 | Списки в Python | Список как набор значений под одним именем. Создание, индексы, изменение элементов. Метод append и функция len. Перебор списка циклом for. | Задачи: средний балл, поиск элемента, список в обратном порядке. |
# | 26 | Обработка списков: сумма, максимум, счётчик | Типовые алгоритмы обработки последовательности: сумма и произведение, максимум и минимум, подсчёт подходящих элементов, поиск индекса. | Пять классических задач обработки числового списка. |
#
# ## IV четверть · уроки 27–34
#
# | № | Тема | Содержание | Домашнее задание |
# |:--:|---|---|---|
# | 27 | Практикум. Контрольная работа № 3 | Строки, списки и графика в одной задаче. Самостоятельная работа за третью четверть. | Итоговые задачи четверти с автопроверкой. |
# | 28 | Электронные таблицы: адреса и формулы | Ячейка, строка, столбец, диапазон. Ввод формулы. Относительные и абсолютные ссылки. Что происходит при копировании формулы. | Собрать таблицу расчёта расходов и предсказать результат копирования формул. |
# | 29 | Встроенные функции и диаграммы | Функции СУММ, СРЗНАЧ, МИН, МАКС, СЧЁТ, ЕСЛИ. Построение диаграмм и выбор подходящего типа диаграммы под данные. | Обработать таблицу успеваемости функциями и построить две диаграммы. |
# | 30 | Таблицы и Python: одна задача, два инструмента | Одна и та же задача в электронной таблице и в коде. Когда удобнее таблица, а когда программа. Табличные данные как список списков. | Решить одну задачу обоими способами и сравнить трудоёмкость. |
# | 31 | Свои функции: def | Зачем нужны функции. Определение и вызов, параметры, return. Локальные имена. Разбиение большой задачи на части. | Оформить три ранее решённые задачи в виде функций с автопроверкой. |
# | 32 | Случайные числа и моделирование | Модуль random: randint, choice, shuffle. Псевдослучайность и seed. Простые игры и вычислительные опыты со случайностью. | Написать игру «угадай число» и смоделировать тысячу бросков кубика. |
# | 33 | Интернет, поиск и безопасность | Как устроена сеть и из чего состоит адрес сайта. Приёмы поиска. Достоверность источников. Пароли, фишинг и защита личных данных. | Проверить три утверждения по источникам и оценить надёжность паролей программой. |
# | 34 | Годовой проект и итоговая работа | Сборка мини-проекта из изученного, показ работ и итоговая контрольная за год: кодирование, логика, ветвления, циклы, списки, таблицы. | Доделать проект и решить итоговую работу с автопроверкой. |
#
# ---
#
# [🏠 Ко всем классам](https://colab.research.google.com/github/LeksssGray/informatika-7-11/blob/main/index.ipynb)
