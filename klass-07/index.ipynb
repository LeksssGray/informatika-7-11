# %% [markdown]
# # 7 класс. Информация, компьютер и первые программы
#
# Стартовый год курса. Разбираемся, что такое информация и как она кодируется, как устроен компьютер — и уже с первого месяца пишем настоящий код на Python: вывод, переменные, ветвления, циклы, списки. Параллельно осваиваем логику, компьютерную графику и электронные таблицы.
#
# [🏠 Ко всем классам](https://colab.research.google.com/github/LeksssGray/informatika-7-11/blob/main/index.ipynb)
#
# ---
#
# ### К концу года ты сможешь
#
# - переводить единицы измерения информации и считать объём текста и картинки
# - переводить числа между двоичной и десятичной системами
# - писать программы с ветвлениями, циклами и списками
# - строить таблицы истинности и проверять их кодом
# - работать с формулами и диаграммами в электронных таблицах
#
# ### Как устроен год
#
# 34 учебные недели, один урок в неделю по 40 минут. Каждый урок — отдельный ноутбук: теория, разобранные примеры, задачи в классе и домашнее задание с автоматической проверкой.
#
# ---
#
# ## I четверть · уроки 1–8
#
# | № | Тема | Содержание | Домашнее задание |
# |:--:|---|---|---|
# | 1 | **[Информатика и Google Colab](https://colab.research.google.com/github/LeksssGray/informatika-7-11/blob/main/klass-07/urok-01.ipynb)** | Что изучает информатика и зачем она нужна. Устройство ноутбука Colab: текстовые и кодовые ячейки, запуск, сохранение копии на свой Диск. Первый запуск готового кода. | Освоить интерфейс Colab, выполнить пять готовых ячеек и объяснить, что делает каждая. |
# | 2 | **[Информация и информационные процессы](https://colab.research.google.com/github/LeksssGray/informatika-7-11/blob/main/klass-07/urok-02.ipynb)** | Что такое информация. Виды информации по способу восприятия и по форме представления. Три информационных процесса: хранение, передача, обработка. Источник, канал, приёмник, шум. | Разобрать шесть бытовых ситуаций и определить в каждой тип информационного процесса. |
# | 3 | **[Измерение информации: бит и байт](https://colab.research.google.com/github/LeksssGray/informatika-7-11/blob/main/klass-07/urok-03.ipynb)** | Алфавитный подход к измерению информации. Бит как ответ на вопрос «да или нет». Байт, килобайт, мегабайт, гигабайт. Формула N = 2^i. Расчёт информационного объёма сообщения. | Задачи на перевод единиц и вычисление объёма текста; проверка своих расчётов кодом. |
# | 4 | **[Двоичное кодирование чисел](https://colab.research.google.com/github/LeksssGray/informatika-7-11/blob/main/klass-07/urok-04.ipynb)** | Почему компьютер считает двойками. Разряды двоичного числа. Перевод из двоичной системы в десятичную и обратно. Двоичное сложение на простых примерах. | Перевести числа вручную и написать программу-переводчик, сверив результаты. |
# | 5 | **[Первая программа: print и комментарии](https://colab.research.google.com/github/LeksssGray/informatika-7-11/blob/main/klass-07/urok-05.ipynb)** | Синтаксис print, строки в кавычках, несколько аргументов, параметры sep и end. Комментарии. Типичные ошибки новичка и как читать сообщение об ошибке. | Написать программу, которая печатает визитку и рисунок из символов. |
# | 6 | **[Переменные и типы данных](https://colab.research.google.com/github/LeksssGray/informatika-7-11/blob/main/klass-07/urok-06.ipynb)** | Имя, значение, присваивание. Типы int, float, str, bool и функция type. Правила именования. Переприсваивание и обмен значений двух переменных. | Задачи на вычисления с переменными: периметр, площадь, обмен значений. |
# | 7 | **[Ввод данных и арифметика](https://colab.research.google.com/github/LeksssGray/informatika-7-11/blob/main/klass-07/urok-07.ipynb)** | Функция input и преобразование типов. Арифметические операции, деление нацело и остаток, степень. Порядок действий. Красивый вывод через f-строки. | Написать четыре программы-калькулятора, включая расчёт сдачи и перевод минут в часы. |
# | 8 | **[Практикум и контрольная работа № 1](https://colab.research.google.com/github/LeksssGray/informatika-7-11/blob/main/klass-07/urok-08.ipynb)** | Разбор типовых ошибок первой четверти. Самостоятельная работа: кодирование информации и линейные программы. | Итоговый набор задач за четверть с автопроверкой. |
#
# ## II четверть · уроки 9–16
#
# | № | Тема | Содержание | Домашнее задание |
# |:--:|---|---|---|
# | 9 | Условный оператор if <br><sub>готовится</sub> | Ветвление в жизни и в программе. Операции сравнения. Отступы как часть синтаксиса Python. Ветка else и полная форма ветвления. | Задачи: чётность числа, допуск по возрасту, определение знака числа. |
# | 10 | Сложные условия: elif, and, or, not <br><sub>готовится</sub> | Множественный выбор через elif. Логические операторы в условиях. Вложенные условия и когда их лучше заменить одним выражением. | Задачи: время года по номеру месяца, оценка по баллам, високосный год. |
# | 11 | Основы логики: таблицы истинности <br><sub>готовится</sub> | Высказывание и его истинность. Операции И, ИЛИ, НЕ. Построение таблиц истинности. Связь логических операций с условиями в программе. | Заполнить таблицы истинности для трёх выражений и проверить их программой. |
# | 12 | Устройство компьютера <br><sub>готовится</sub> | Процессор, оперативная и постоянная память, устройства ввода и вывода. Магистральная схема. Что означают характеристики в описании компьютера. | Разобрать характеристики трёх компьютеров и обосновать выбор под конкретную задачу. |
# | 13 | Файлы и файловая система <br><sub>готовится</sub> | Файл, имя, расширение, размер. Каталоги и дерево папок. Полный путь к файлу. Поиск файлов и маски имён. | Задачи на пути и маски файлов; практика с файловой системой Colab. |
# | 14 | Программное обеспечение <br><sub>готовится</sub> | Системное и прикладное ПО. Задачи операционной системы. Лицензии: проприетарное и свободное ПО. Вредоносные программы и защита от них. | Классифицировать двенадцать программ по типам и описать назначение трёх из них. |
# | 15 | Цикл for и range <br><sub>готовится</sub> | Повторение как третья базовая конструкция. Цикл for по range. Три формы range. Накопление суммы в цикле. | Задачи: таблица умножения, сумма чисел от 1 до N, обратный отсчёт. |
# | 16 | Практикум по циклам. Контрольная работа № 2 <br><sub>готовится</sub> | Комбинация цикла и условия, счётчики. Самостоятельная работа за вторую четверть. | Итоговые задачи четверти на ветвления и циклы с автопроверкой. |
#
# ## III четверть · уроки 17–26
#
# | № | Тема | Содержание | Домашнее задание |
# |:--:|---|---|---|
# | 17 | Цикл while <br><sub>готовится</sub> | Цикл с условием. Когда нужен while, а когда for. Бесконечный цикл и как его прервать. Накопление значений и счётчики. | Задачи: сумма цифр числа, игра «угадай число», деление отрезка пополам. |
# | 18 | Кодирование текста: ASCII и Unicode <br><sub>готовится</sub> | Символ как число. Кодовая таблица ASCII, кириллица, Unicode и UTF-8. Функции ord и chr. Расчёт объёма текстового файла. | Задачи на объём текста и шифр сдвига через ord и chr. |
# | 19 | Строки в Python <br><sub>готовится</sub> | Строка как последовательность символов. Длина, индексы, срезы. Склейка и повторение строк. Методы upper, lower, replace, count. | Задачи: строка наоборот, подсчёт гласных, проверка палиндрома. |
# | 20 | Текстовые документы <br><sub>готовится</sub> | Структура документа: заголовки, абзацы, списки. Правила набора текста. Форматирование и стили. Markdown в Colab как современный способ разметки. | Оформить конспект урока в Markdown-ячейке по заданным требованиям. |
# | 21 | Компьютерная графика: растр и вектор <br><sub>готовится</sub> | Пиксель и растровое изображение. Разрешение. Векторная графика и её преимущества. Графические форматы и сжатие. | Сравнить растр и вектор на примерах, рассчитать размеры изображений. |
# | 22 | Кодирование цвета: RGB и глубина цвета <br><sub>готовится</sub> | Цветовая модель RGB. Глубина цвета и количество оттенков. Расчёт объёма растрового изображения. Палитра и её размер. | Задачи на объём изображения; собрать свой цвет по коду RGB. |
# | 23 | Рисуем изображение программой <br><sub>готовится</sub> | Пиксельная картинка как список списков. Вывод изображения средствами Python. Простые фигуры, заливка и градиент. | Нарисовать кодом флаг, шахматную доску и собственный рисунок 16 на 16. |
# | 24 | Списки в Python <br><sub>готовится</sub> | Список как набор значений под одним именем. Создание, индексы, изменение элементов. Метод append и функция len. Перебор списка циклом for. | Задачи: средний балл, поиск элемента, список в обратном порядке. |
# | 25 | Обработка списков: сумма, максимум, счётчик <br><sub>готовится</sub> | Типовые алгоритмы обработки последовательности: сумма и произведение, максимум и минимум, подсчёт подходящих элементов, поиск индекса. | Пять классических задач обработки числового списка. |
# | 26 | Практикум. Контрольная работа № 3 <br><sub>готовится</sub> | Строки, списки и графика в одной задаче. Самостоятельная работа за третью четверть. | Итоговые задачи четверти с автопроверкой. |
#
# ## IV четверть · уроки 27–34
#
# | № | Тема | Содержание | Домашнее задание |
# |:--:|---|---|---|
# | 27 | Электронные таблицы: адреса и формулы <br><sub>готовится</sub> | Ячейка, строка, столбец, диапазон. Ввод формулы. Относительные и абсолютные ссылки. Что происходит при копировании формулы. | Собрать таблицу расчёта расходов и предсказать результат копирования формул. |
# | 28 | Встроенные функции и диаграммы <br><sub>готовится</sub> | Функции СУММ, СРЗНАЧ, МИН, МАКС, СЧЁТ, ЕСЛИ. Построение диаграмм и выбор подходящего типа диаграммы под данные. | Обработать таблицу успеваемости функциями и построить две диаграммы. |
# | 29 | Таблицы и Python: одна задача, два инструмента <br><sub>готовится</sub> | Одна и та же задача в электронной таблице и в коде. Когда удобнее таблица, а когда программа. Табличные данные как список списков. | Решить одну задачу обоими способами и сравнить трудоёмкость. |
# | 30 | Свои функции: def <br><sub>готовится</sub> | Зачем нужны функции. Определение и вызов, параметры, return. Локальные имена. Разбиение большой задачи на части. | Оформить три ранее решённые задачи в виде функций с автопроверкой. |
# | 31 | Случайные числа и моделирование <br><sub>готовится</sub> | Модуль random: randint, choice, shuffle. Псевдослучайность и seed. Простые игры и вычислительные опыты со случайностью. | Написать игру «угадай число» и смоделировать тысячу бросков кубика. |
# | 32 | Интернет, поиск и безопасность <br><sub>готовится</sub> | Как устроена сеть и из чего состоит адрес сайта. Приёмы поиска. Достоверность источников. Пароли, фишинг и защита личных данных. | Проверить три утверждения по источникам и оценить надёжность паролей программой. |
# | 33 | Годовой проект <br><sub>готовится</sub> | Сборка мини-проекта из изученного: данные, обработка, вывод результата. Требования к проекту и критерии оценивания. | Доделать и оформить свой проект в отдельном ноутбуке. |
# | 34 | Итоговая контрольная работа <br><sub>готовится</sub> | Годовое повторение: кодирование, логика, ветвления, циклы, списки, таблицы. Итоговая работа. | Итоговая работа за 7 класс с автопроверкой. |
#
# ---
#
# ### Условные обозначения
#
# 📖 — теория  🐍 — Python  🧠 — логика  📊 — электронные таблицы  🗄️ — базы данных  🌐 — сети  📈 — анализ данных  🛠️ — проект  📝 — контрольная  🎓 — ОГЭ  🎓 — ЕГЭ
#
# [🏠 Ко всем классам](https://colab.research.google.com/github/LeksssGray/informatika-7-11/blob/main/index.ipynb)
