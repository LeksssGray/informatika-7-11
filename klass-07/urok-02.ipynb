# %% [markdown]
# # Урок 2. Разминка: что нужно помнить
#
# 7 класс · I четверть
#
# [⬆ Все уроки](https://colab.research.google.com/github/LeksssGray/informatika-7-11/blob/main/klass-07/index.ipynb) · [← Урок 1](https://colab.research.google.com/github/LeksssGray/informatika-7-11/blob/main/klass-07/urok-01.ipynb) · [Урок 3 →](https://colab.research.google.com/github/LeksssGray/informatika-7-11/blob/main/klass-07/urok-03.ipynb)
#
# ---
#
# Справочник и проверка перед стартом: доли и проценты, степени двойки, чтение схем и таблиц, что уже знаем про компьютер. Смотрим, где пробелы.

# %% [markdown]
# ### Напоминание: как начать урок
#
# **1.** Если заводил секрет `INFORMATIKA`, нажми 🔑 на панели слева и включи переключатель рядом с ним — тогда поля регистрации можно не заполнять. Секрета нет — впиши ФИО, класс и адрес журнала.
#
# **2.** Запусти регистрацию кнопкой ▶. На предупреждение «Google не имеет отношения к созданию этого блокнота» отвечай **«Выполнить»**, на запрос доступа к аккаунту — **«Разрешить»**.
#
# **3.** Дальше — сверху вниз.
#
# Подробно, с картинками — в [первом уроке](https://colab.research.google.com/github/LeksssGray/informatika-7-11/blob/main/klass-07/urok-01.ipynb).
#
# ---

# %%
#@title 🚀 Регистрация { display-mode: "form" }
#@markdown Впиши свои данные и запусти ячейку (Shift+Enter).
#@markdown Если заводил секрет `INFORMATIKA` и включил к нему доступ
#@markdown (🔑 на панели слева) — поля можно оставить пустыми.
#@markdown
#@markdown Colab спросит разрешение на доступ к аккаунту — нажми
#@markdown «Разрешить». Так проверка понимает, чья это работа.
ФИО = "" #@param {type:"string"}
#@markdown Класс — с буквой, например 7А
Класс = "" #@param {type:"string"}
#@markdown
#@markdown Адрес журнала даёт учитель. Пусто — в конце урока
#@markdown получишь квитанцию, её нужно будет отправить ему сам.
Журнал = "" #@param {type:"string"}

import importlib, urllib.request
urllib.request.urlretrieve("https://raw.githubusercontent.com/LeksssGray/informatika-7-11/main/lib/schoolinf.py", "schoolinf.py")
import schoolinf as si
importlib.reload(si)
si.start(lesson="07-02", name=ФИО, klass=Класс,
         journal=Журнал)

# %% [markdown]
# ## Зачем этот урок
#
# Информатика опирается на несколько простых вещей из математики.
# Ничего сложного, но если они «плавают», будешь спотыкаться
# на арифметике вместо того, чтобы думать о самой задаче.
#
# Поэтому сегодня — короткий справочник и проверка. Держи его открытым
# весь год: сюда удобно возвращаться, когда что-то забылось.
#
# ---
#
# ## Справочник
#
# ### Степени двойки
#
# Главные числа информатики. Каждое следующее вдвое больше предыдущего.
#
# | Степень | 2¹ | 2² | 2³ | 2⁴ | 2⁵ | 2⁶ | 2⁷ | 2⁸ | 2¹⁰ |
# |---|---|---|---|---|---|---|---|---|---|
# | Значение | 2 | 4 | 8 | 16 | 32 | 64 | 128 | 256 | 1024 |
#
# Два числа отсюда встретятся особенно часто: **256** и **1024**.
# Первое — сколько разных значений помещается в один байт, второе —
# сколько байт в килобайте.
#
# ### Проценты
#
# Процент — это сотая доля. Чтобы найти процент от числа, умножают
# на десятичную дробь:
#
# | Проценты | Умножить на |
# |---|---|
# | 1 % | 0.01 |
# | 10 % | 0.1 |
# | 25 % | 0.25 |
# | 50 % | 0.5 |
# | 85 % | 0.85 |
#
# 25 % от 80 это 80 × 0,25 = 20.
#
# ### Порядок действий
#
# Как в математике: сначала степень, потом умножение и деление,
# в конце сложение и вычитание. Скобки главнее всего.
#
# ```
#   2 + 3 * 4       =  14      сначала умножили
#   (2 + 3) * 4     =  20      скобки поменяли порядок
# ```
#
# ### Деление нацело и остаток
#
# Деление с остатком вы проходили ещё в пятом классе. В Python у него
# два отдельных знака: один даёт частное, другой — остаток.
#
# | Запись | Что значит | Пример |
# |---|---|---|
# | `//` | сколько целых раз поместилось | `17 // 5` = 3 |
# | `%` | сколько осталось | `17 % 5` = 2 |
#
# 17 конфет на пятерых: каждому по 3, две останутся.
#
# ### Как читать таблицу
#
# Сначала находишь **строку**, потом **столбец**, на пересечении — ответ.
#
# |  | утро | день | вечер |
# |---|---|---|---|
# | **понедельник** | 5 | 12 | 8 |
# | **вторник** | 3 | 15 | 6 |
#
# На пересечении «вторник» и «день» стоит 15.

# %% [markdown]
# ## Смотрим, как это работает
#
# Ниже готовые ячейки. Запускай их и, если хочется, меняй числа —
# сломать ничего нельзя.
#
# ### Степени двойки

# %%
print("2 в 5 степени:", 2 ** 5)
print("2 в 6 степени:", 2 ** 6)
print("2 в 8 степени:", 2 ** 8)
print("2 в 10 степени:", 2 ** 10)

# %% [markdown]
# Обрати внимание, как быстро растут числа: от пятой степени
# до десятой — рост в тридцать два раза.
#
# Две звёздочки `**` означают «возвести в степень».

# %% [markdown]
# ### Проценты

# %%
print("25 % от 80:", 80 * 0.25)
print("50 % от 80:", 80 * 0.5)
print("15 % от 4000:", 4000 * 0.15)

# %% [markdown]
# Ответы получились дробными — `20.0` вместо `20`. Так работает умножение
# на дробь, на правильность это не влияет.

# %% [markdown]
# ### Порядок действий и скобки

# %%
print("2 + 3 * 4     =", 2 + 3 * 4)
print("(2 + 3) * 4   =", (2 + 3) * 4)
print("10 - 2 * 3    =", 10 - 2 * 3)
print("(10 - 2) * 3  =", (10 - 2) * 3)

# %% [markdown]
# Одни и те же числа, разный порядок — разные ответы. Если сомневаешься,
# ставь скобки: лишние не мешают, а забытые портят результат.

# %% [markdown]
# ### Деление с остатком

# %%
print("17 // 5 =", 17 // 5, "  ← сколько целых поместилось")
print("17 % 5  =", 17 % 5, "  ← сколько осталось")
print("100 // 7 =", 100 // 7)
print("100 % 7  =", 100 % 7)

# %% [markdown]
# ### Ячейка-калькулятор
#
# Эта ячейка пригодится в задачах. Меняй в ней пример и запускай.

# %%
# калькулятор: замени пример на свой и нажми ▶
print(2 ** 6)

# %% [markdown]
# ## Проверь себя
#
# По задаче на каждый раздел справочника. Ответ вписывается в поле,
# писать код не нужно. Не получилось — вернись к нужной таблице выше.

# %% [markdown]
# ### Задача 1. Степень двойки
#
# Чему равно 2 в шестой степени?

# %%
#@title 🧮 Задача 1. Степень двойки { display-mode: "form" }
#@markdown Впиши ответ числом
ответ_1 = 0 #@param {type:"integer"}

si.ответ("1", ответ_1, "a68b412c4282555f",
         hint="Загляни в таблицу степеней или посчитай: 2·2·2·2·2·2.")

# %% [markdown]
# ### Задача 2. Проценты
#
# Сколько будет 25 % от 80?

# %%
#@title 🧮 Задача 2. Проценты { display-mode: "form" }
#@markdown Впиши ответ числом
ответ_2 = 0 #@param {type:"integer"}

si.ответ("2", ответ_2, "f5ca38f748a1d6ea",
         hint="Умножь на 0.25. Или подумай: 25 % — это четверть.")

# %% [markdown]
# ### Задача 3. Порядок действий
#
# Посчитай в уме, не запуская код:
#
# ```
# 2 + 3 * 4
# ```

# %%
#@title 🧮 Задача 3. Порядок действий { display-mode: "form" }
#@markdown Впиши ответ числом
ответ_3 = 0 #@param {type:"integer"}

si.ответ("3", ответ_3, "8527a891e2241369",
         hint="Умножение считается раньше сложения.")

# %% [markdown]
# ### Задача 4. Остаток
#
# 100 конфет раздают 7 детям поровну. Сколько конфет останется лишними?

# %%
#@title 🧮 Задача 4. Остаток { display-mode: "form" }
#@markdown Впиши ответ числом
ответ_4 = 0 #@param {type:"integer"}

si.ответ("4", ответ_4, "d4735e3a265e16ee",
         hint="Каждому достанется по 14, а дальше посмотри, сколько не хватает до ста.")

# %% [markdown]
# ### Задача 5. Читаем таблицу
#
# |  | утро | день | вечер |
# |---|---|---|---|
# | **понедельник** | 5 | 12 | 8 |
# | **вторник** | 3 | 15 | 6 |
#
# Какое число стоит на пересечении строки «вторник» и столбца «вечер»?

# %%
#@title 🧮 Задача 5. Читаем таблицу { display-mode: "form" }
#@markdown Впиши число из нужной клетки
ответ_5 = 0 #@param {type:"integer"}

si.ответ("5", ответ_5, "e7f6c011776e8db7",
         hint="Найди строку «вторник» и проведи пальцем до столбца «вечер».")

# %% [markdown]
# ## Домашнее задание

# %% [markdown]
# ### 1. Килобайт
#
# Сколько байт в килобайте? Это два в какой-то степени —
# загляни в справочник.

# %%
#@title 🏠 Домашнее 1. Килобайт { display-mode: "form" }
#@markdown Впиши ответ числом
дз_1 = 0 #@param {type:"integer"}

si.ответ("дз1", дз_1, "e39eef82f61b21e2",
         hint="Два в десятой степени.")

# %% [markdown]
# ### 2. Скидка
#
# Куртка стоила 4000 рублей, скидка 15 %. Сколько рублей скидка?
#
# Посчитать можно в ячейке-калькуляторе выше.

# %%
#@title 🏠 Домашнее 2. Скидка { display-mode: "form" }
#@markdown Впиши ответ числом
дз_2 = 0 #@param {type:"integer"}

si.ответ("дз2", дз_2, "284b7e6d788f363f",
         hint="Умножь цену на 0.15.")

# %% [markdown]
# ### 3. Скобки решают
#
# Посчитай в уме:
#
# ```
# (10 - 2) * 3
# ```

# %%
#@title 🏠 Домашнее 3. Скобки { display-mode: "form" }
#@markdown Впиши ответ числом
дз_3 = 0 #@param {type:"integer"}

si.ответ("дз3", дз_3, "c2356069e9d1e79c",
         hint="Скобки считаются первыми.")

# %% [markdown]
# ---
#
# ### Что делать, если не получилось
#
# Это нормально в начале года. Вернись к нужному разделу справочника,
# разбери пример и попробуй снова.
#
# Держи этот урок под рукой: когда в декабре забудешь, чем `//`
# отличается от `%`, ответ будет здесь.

# %% [markdown]
# ---
#
# ## Отчёт по уроку
#
# Запусти ячейку ниже, когда решишь задачи. Результат уйдёт учителю автоматически.

# %%
si.report()

# %% [markdown]
# ---
#
# ### Всё ещё вписываешь данные вручную?
#
# Настрой автовход — одна минута, и больше вводить ничего не придётся. Запусти ячейку ниже и сделай шаг 5 из [первого урока](https://colab.research.google.com/github/LeksssGray/informatika-7-11/blob/main/klass-07/urok-01.ipynb).

# %%
si.запомнить()

# %% [markdown]
# ---
#
# [← Урок 1](https://colab.research.google.com/github/LeksssGray/informatika-7-11/blob/main/klass-07/urok-01.ipynb) · [⬆ Все уроки](https://colab.research.google.com/github/LeksssGray/informatika-7-11/blob/main/klass-07/index.ipynb) · [🏠 Ко всем классам](https://colab.research.google.com/github/LeksssGray/informatika-7-11/blob/main/index.ipynb) · [Урок 3 →](https://colab.research.google.com/github/LeksssGray/informatika-7-11/blob/main/klass-07/urok-03.ipynb)
