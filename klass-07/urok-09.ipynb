# %% [markdown]
# # Урок 9. Практикум и контрольная работа № 1
#
# 7 класс · II четверть
#
# [⬆ Все уроки](https://colab.research.google.com/github/LeksssGray/informatika-7-11/blob/main/klass-07/index.ipynb) · [← Урок 8](https://colab.research.google.com/github/LeksssGray/informatika-7-11/blob/main/klass-07/urok-08.ipynb) · [Урок 10 →](https://colab.research.google.com/github/LeksssGray/informatika-7-11/blob/main/klass-07/urok-10.ipynb)
#
# ---
#
# Разбор типовых ошибок первой четверти. Самостоятельная работа: кодирование информации и линейные программы.

# %%
#@title 🚀 Шаг 1. Регистрация и подготовка урока { display-mode: "form" }
#@markdown Впиши свои данные и запусти ячейку (Shift+Enter).
#@markdown Если заводил секрет `ИНФОРМАТИКА` — оставь поля
#@markdown пустыми, они заполнятся сами.
#@markdown
#@markdown Colab спросит разрешение на доступ к аккаунту — нажми
#@markdown «Разрешить». Так проверка понимает, чья это работа.
ФИО = "" #@param {type:"string"}
#@markdown Класс — с буквой, например 7А
Класс = "" #@param {type:"string"}
#@markdown
#@markdown Адрес журнала даёт учитель. Пусто — в конце урока
#@markdown получишь квитанцию, её нужно будет отправить ему сам.
Журнал = "" #@param {type:"string"}

import importlib, urllib.request
urllib.request.urlretrieve("https://raw.githubusercontent.com/LeksssGray/informatika-7-11/main/lib/schoolinf.py", "schoolinf.py")
import schoolinf as si
importlib.reload(si)
si.start(lesson="07-09", name=ФИО, klass=Класс,
         journal=Журнал)

# %% [markdown]
# ## Где обычно ошибаются
#
# Четверть позади. Разберём ошибки, которые встречаются у всех
# и стоят баллов на любой работе.
#
# ### Забыли, что input даёт строку
#
# ```python
# n = input("Число: ")
# print(n * 2)          # ввели 5, а вышло 55
# ```
#
# Строка, умноженная на 2, повторилась дважды. Лечится так:
# `n = int(input("Число: "))`.
#
# ### Перепутали `/` и `//`
#
# `7 / 2` даёт `3.5`, а `7 // 2` даёт `3`. Если в ответе должно быть целое
# число купюр, коробок или страниц — нужно `//`. Если средний балл
# или скорость — обычное деление.
#
# И наоборот: `10 / 2` даёт `5.0`, а не `5`.
#
# ### Перепутали местами N и i
#
# В формуле $N = 2^i$ путают, что где. Запомни по смыслу:
# **вариантов всегда больше, чем бит**. 256 вариантов — 8 бит,
# никак не наоборот.
#
# ### Килобайт посчитали как тысячу
#
# Все переводы между байтовыми единицами идут через 1024. Тысяча
# появляется только в рекламе жёстких дисков.
#
# ### Потеряли разряд при переводе в двоичную
#
# Остатки читаются **снизу вверх**. Прочтёшь сверху вниз — получишь
# число задом наперёд: вместо `11010` выйдет `01011`.
#
# Всегда проверяй себя обратным переводом, это двадцать секунд.
#
# ### Что проверить перед сдачей
#
# 1. Результат того типа, который ждут: число, а не строка?
# 2. Единицы переведены правильно — везде 1024, а не 1000?
# 3. Проверил обратным действием?

# %% [markdown]
# ## Ищем чужие ошибки
#
# ### Что здесь не так
#
# Программа должна посчитать площадь квадрата со стороной 5.
# Найди ошибку до запуска.

# %%
сторона = 5
площадь = сторона * 2

print("Площадь:", площадь)

# %% [markdown]
# `сторона * 2` — это не площадь, а сумма двух сторон. Площадь квадрата —
# сторона, умноженная **сама на себя**, то есть `сторона ** 2`
# или `сторона * сторона`.
#
# Ошибка тем и коварна, что программа не падает: она честно печатает
# число, просто не то.

# %%
сторона = 5
площадь = сторона ** 2

print("Площадь:", площадь)

# %% [markdown]
# ### Коробки, которых не хватило
#
# Считаем, сколько нужно коробок, чтобы уложить 10 предметов по 3 штуки.

# %%
предметов = 10
вместимость = 3

коробок = предметов // вместимость
print("Коробок:", коробок)

# %% [markdown]
# Получилось 3 — но в трёх коробках поместится только девять предметов!
# Десятому нужна четвёртая.
#
# Деление нацело отбрасывает остаток, а нам надо **округлить вверх**.
# Есть классический приём: добавить «почти целую» порцию перед делением.

# %%
предметов = 10
вместимость = 3

коробок = (предметов + вместимость - 1) // вместимость
print("Коробок:", коробок)

# %% [markdown]
# Если остаток был — добавка дотягивает до следующего целого.
# Если не было — ничего не меняется. Приём встретится тебе ещё много раз,
# запомни его.

# %% [markdown]
# ## Контрольная работа
#
# Шесть задач по материалу четверти. Конспектом пользоваться можно,
# соседом — нет.

# %% [markdown]
# ### Задача 1. Объём текста
#
# В алфавите 64 символа, в сообщении 200 символов.
# Сколько бит занимает всё сообщение?
#
# Сначала найди, сколько бит на один символ.

# %%
объём = ...

print(объём)

# %%
si.ответ("1", объём, "15197cf7214b58e6",
         hint="64 — это два в шестой степени. Значит на символ уходит 6 бит.")

# %% [markdown]
# ### Задача 2. В двоичную
#
# Переведи число 100 в двоичную систему. Ответ впиши строкой.
#
# Проверить себя можно, набрав в ячейке `bin(100)`.

# %%
двоичное = "???"

si.ответ("2", двоичное, "e920d250928fa7b8",
         hint="Семь разрядов. Веса: 64 + 32 + 4.")

# %% [markdown]
# ### Задача 3. Сколько коробок
#
# 25 предметов раскладывают по 4 штуки в коробку.
# Сколько нужно коробок?
#
# Помни про округление вверх — разбирали только что.

# %%
коробок = ...

print(коробок)

# %%
si.ответ("3", коробок, "7902699be42c8a8e",
         hint="Шесть коробок вместят 24 предмета. А двадцать пятый куда?")

# %% [markdown]
# ### Задача 4. Время в пути
#
# 135 минут — это сколько часов и минут? Собери строку вида `2 ч 15 мин`.

# %%
в_пути = ...

print(в_пути)

# %%
si.ответ("4", в_пути, "65bd90165d51e145",
         hint="Деление нацело даёт часы, остаток — минуты.")

# %% [markdown]
# ### Задача 5. Влезет ли фильм
#
# Фильм весит 700 Мбайт, на флешке свободен 1 Гбайт.
# Поместится? Впиши `"да"` или `"нет"`.

# %%
влезет = "???"

si.ответ("5", влезет, "2b81d6a2f0b615c6",
         hint="В гигабайте 1024 мегабайта.")

# %% [markdown]
# ### Задача 6. Сколько символов в сообщении
#
# Сообщение занимает 40 бит, записано алфавитом из 32 символов.
# Сколько в нём символов?
#
# Найди, сколько бит уходит на один символ, и раздели.

# %%
символов = ...

si.ответ("6", символов, "2c624232cdd22177",
         hint="32 — это два в пятой, значит символ весит 5 бит.")

# %% [markdown]
# ## Домашнее задание на каникулы
#
# Одна задача, зато настоящая.
#
# ### Карточка ученика
#
# Собери строку из трёх строчек:
#
# ```
# Имя: Аня
# Возраст: 13
# Уроков информатики за год: 34
# ```
#
# Строки разделяются `\n`, в конце перевода строки нет.
# Числа вставляй через f-строку.

# %%
имя = "Аня"
возраст = 13
уроков = 34

карточка = ...

print(карточка)

# %%
si.ответ("дз", карточка, "8484c751244bf725",
         hint="Три куска, между ними \\n. Двоеточие и пробел после каждого слова.")

# %% [markdown]
# ---
#
# ### Что дальше
#
# За восемь уроков ты научился измерять информацию, переводить числа
# в двоичную систему, работать с переменными и считать по формулам.
#
# Это фундамент. Со следующей четверти программы станут интереснее,
# потому что научатся **принимать решения**: делать одно, если условие
# выполнено, и другое, если нет.

# %% [markdown]
# ---
#
# ## Отчёт по уроку
#
# Запусти ячейку ниже, когда решишь задачи. Результат уйдёт учителю автоматически.

# %%
si.report()

# %% [markdown]
# ---
#
# [← Урок 8](https://colab.research.google.com/github/LeksssGray/informatika-7-11/blob/main/klass-07/urok-08.ipynb) · [⬆ Все уроки](https://colab.research.google.com/github/LeksssGray/informatika-7-11/blob/main/klass-07/index.ipynb) · [🏠 Ко всем классам](https://colab.research.google.com/github/LeksssGray/informatika-7-11/blob/main/index.ipynb) · [Урок 10 →](https://colab.research.google.com/github/LeksssGray/informatika-7-11/blob/main/klass-07/urok-10.ipynb)
