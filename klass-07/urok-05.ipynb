# %% [markdown]
# # Урок 5. Двоичное кодирование чисел
#
# 7 класс · I четверть
#
# [⬆ Все уроки](https://colab.research.google.com/github/LeksssGray/informatika-7-11/blob/main/klass-07/index.ipynb) · [← Урок 4](https://colab.research.google.com/github/LeksssGray/informatika-7-11/blob/main/klass-07/urok-04.ipynb) · [Урок 6 →](https://colab.research.google.com/github/LeksssGray/informatika-7-11/blob/main/klass-07/urok-06.ipynb)
#
# ---
#
# Почему компьютер считает двойками. Разряды двоичного числа. Перевод из двоичной системы в десятичную и обратно. Двоичное сложение на простых примерах.

# %%
#@title 🚀 Шаг 1. Регистрация и подготовка урока { display-mode: "form" }
#@markdown Впиши свои данные и запусти ячейку (Shift+Enter).
#@markdown
#@markdown Colab спросит разрешение на доступ к аккаунту — нажми
#@markdown «Разрешить». Так проверка понимает, чья это работа.
ФИО = "" #@param {type:"string"}
Класс = "7А" #@param {type:"string"}
#@markdown
#@markdown Адрес журнала даёт учитель. Вписывается один раз
#@markdown в твою копию. Пусто — в конце урока получишь квитанцию.
Журнал = "" #@param {type:"string"}

import importlib, urllib.request
urllib.request.urlretrieve("https://raw.githubusercontent.com/LeksssGray/informatika-7-11/main/lib/schoolinf.py", "schoolinf.py")
import schoolinf as si
importlib.reload(si)
si.start(lesson="07-05", name=ФИО, klass=Класс,
         journal=Журнал)

# %% [markdown]
# ## Разбираемся
#
# ### Почему компьютер считает двойками
#
# Внутри компьютера нет цифр. Там электрические сигналы, и надёжно
# различить можно всего два состояния: **есть напряжение** и **нет
# напряжения**.
#
# Попробуй компьютер различать десять уровней — он бы путался на первой же
# помехе: «пять вольт» легко спутать с «четырьмя с половиной». А вот «есть
# ток» и «нет тока» не спутаешь никак.
#
# Поэтому вся техника работает с двумя цифрами: **0** и **1**. Система
# записи чисел, где кроме них ничего нет, называется **двоичной**.
#
# ### Сначала про привычную запись
#
# Прежде чем лезть в двоичную, разберём знакомую. Что означает `275`?
#
# ```
#   2 сотни  +  7 десятков  +  5 единиц
#   2 · 100  +  7 · 10      +  5 · 1
# ```
#
# Каждая цифра умножается на свой «вес», и веса растут справа налево:
# 1, 10, 100, 1000. Такая запись называется **позиционной**: значение
# цифры зависит от её места. Единица в конце — это один, а в начале — сотня.
#
# ### Двоичная устроена точно так же
#
# Отличие ровно одно: веса растут не десятками, а двойками.
#
# ```
#   веса:     16   8   4   2   1
#   число:     1   1   0   1   0
#              ↓   ↓       ↓
#             16 + 8  +    2  = 26
# ```
#
# Складываешь веса там, где стоит единица. Всё.
#
# Веса стоит помнить наизусть, они будут нужны постоянно:
#
# | 1 | 2 | 4 | 8 | 16 | 32 | 64 | 128 | 256 |
# |---|---|---|---|---|---|---|---|---|
#
# Чтобы `1011` не приняли за тысячу одиннадцать, внизу приписывают
# основание: `1011₂`.
#
# ### Из двоичной в обычную
#
# Надпиши веса справа налево и сложи те, где единица.
#
# ```
#   веса:     8   4   2   1
#   число:    1   0   1   1     →   8 + 2 + 1 = 11
# ```
#
# ### Из обычной в двоичную
#
# Обратный ход — деление на 2 с остатком. Делим, пока не дойдём до нуля,
# и **читаем остатки снизу вверх**:
#
# ```
#   26 : 2 = 13,  остаток 0   ↑
#   13 : 2 =  6,  остаток 1   │
#    6 : 2 =  3,  остаток 0   │  читаем
#    3 : 2 =  1,  остаток 1   │  сюда
#    1 : 2 =  0,  остаток 1   │
#
#   Ответ: 11010₂
# ```
#
# Проверяем обратно: 16 + 8 + 2 = 26. Сошлось.
#
# > Читать остатки снизу вверх — то место, где ошибаются чаще всего.
# > Прочтёшь сверху вниз — получишь число задом наперёд.
#
# ### Сложение
#
# Правила почти как в столбик, только перенос случается раньше:
#
# ```
#   0 + 0 = 0        1 + 1 = 10   (ноль пишем, единицу в уме)
#   0 + 1 = 1        1 + 1 + 1 = 11
# ```
#
# Пример:
#
# ```
#     1 0 1 1        (11)
#   +   1 1 0         (6)
#   ─────────
#   1 0 0 0 1        (17)
# ```

# %% [markdown]
# ## Смотрим, как это работает
#
# ### Складываем веса
#
# Разберём `11010` так же, как в теории. Нули можно вообще не считать —
# они ничего не добавляют.

# %%
print("единица на весе 2  даёт", 2)
print("ноль    на весе 4  даёт", 0)
print("единица на весе 8  даёт", 8)
print("единица на весе 16 даёт", 16)
print()
print("Итого:", 2 + 8 + 16)

# %% [markdown]
# ### Компьютер умеет переводить сам
#
# Считать всё равно надо уметь руками — на контрольной калькулятора
# не будет. Но проверять себя удобно машиной.

# %%
# int(строка, 2) читает строку как двоичное число
print("1011 в двоичной это", int("1011", 2))
print("11010 в двоичной это", int("11010", 2))

# bin(число) выдаёт двоичную запись
print("26 в двоичной это", bin(26))

# %% [markdown]
# Заметил приставку `0b`? Так Python помечает, что число двоичное.
# Сама запись — это то, что после неё.

# %% [markdown]
# ### Деление с остатком
#
# Для обратного перевода нужны две операции:
#
# * `//` — деление нацело: `26 // 2` даёт `13`;
# * `%` — остаток: `26 % 2` даёт `0`.

# %%
print("26 // 2 =", 26 // 2, "  остаток", 26 % 2)
print("13 // 2 =", 13 // 2, "  остаток", 13 % 2)
print(" 6 // 2 =", 6 // 2, "  остаток", 6 % 2)
print(" 3 // 2 =", 3 // 2, "  остаток", 3 % 2)
print(" 1 // 2 =", 1 // 2, "  остаток", 1 % 2)
print()
print("Остатки снизу вверх: 1 1 0 1 0")
print("Проверяем:", bin(26))

# %% [markdown]
# Эта пара операций — `//` и `%` — будет попадаться тебе постоянно.
# Деление нацело отвечает «сколько целых раз поместилось»,
# остаток — «сколько не поместилось».

# %% [markdown]
# ### Ячейка-калькулятор

# %%
# калькулятор: замени пример на свой и нажми ▶
print(128 + 64 + 32 + 16 + 8 + 4 + 2 + 1)

# %% [markdown]
# ## Проверь себя

# %% [markdown]
# ### Задача 1. В обычную систему
#
# Переведи `1101₂` в десятичную. Надпиши веса на черновике
# и сложи те, где стоит единица.

# %%
#@title 🧮 Задача 1. Из двоичной в обычную { display-mode: "form" }
#@markdown Впиши ответ числом
ответ_1 = 0 #@param {type:"integer"}

si.ответ("1", ответ_1, "3fdba35f04dc8c46",
         hint="Веса справа налево: 1, 2, 4, 8. Единицы стоят на 1, 4 и 8.")

# %% [markdown]
# ### Задача 2. Из обычной в двоичную
#
# Переведи число 26 делением с остатком. Все вычисления есть
# в примере выше — но лучше сделай сам на черновике.

# %%
#@title 🧮 Задача 2. Из обычной в двоичную { display-mode: "form" }
#@markdown Впиши двоичную запись, например 1010
двоичное = "" #@param {type:"string"}

si.ответ("2", двоичное, "17e4193d35b00571",
         hint="Пять разрядов. Не забудь читать остатки снизу вверх.")

# %% [markdown]
# ### Задача 3. Сколько единиц
#
# Сколько единиц в двоичной записи числа 26?
#
# Запись ты только что получил — посчитай их глазами.

# %%
#@title 🧮 Задача 3. Сколько единиц { display-mode: "form" }
#@markdown Впиши ответ числом
единиц = 0 #@param {type:"integer"}

si.ответ("3", единиц, "4e07408562bedb8b",
         hint="Посмотри на 11010 и посчитай единички.")

# %% [markdown]
# ## Домашнее задание

# %% [markdown]
# ### 1. Восемь единиц подряд
#
# Какое число записывается как `11111111₂`?
#
# Сложи все веса: 128, 64, 32, 16, 8, 4, 2, 1. Калькулятор выше.

# %%
#@title 🏠 Домашнее 1. Восемь единиц { display-mode: "form" }
#@markdown Впиши ответ числом
дз_1 = 0 #@param {type:"integer"}

si.ответ("дз1", дз_1, "9556b82499cc0aaf",
         hint="Это ровно на единицу меньше, чем 256.")

# %% [markdown]
# ### 2. Самое большое из десяти разрядов
#
# Какое самое большое число поместится в десять двоичных разрядов?
#
# Подсказка из прошлой задачи: восемь единиц дали 255, а это на один
# меньше, чем 256 — то есть на один меньше, чем два в восьмой степени.
# Примени ту же мысль к десяти разрядам.

# %%
#@title 🏠 Домашнее 2. Максимум из десяти разрядов { display-mode: "form" }
#@markdown Впиши ответ числом
дз_2 = 0 #@param {type:"integer"}

si.ответ("дз2", дз_2, "6629ddae3736e894",
         hint="Два в десятой степени это 1024. А нужно на единицу меньше.")

# %% [markdown]
# ### 3. Сложение столбиком
#
# Сложи `1011₂` и `110₂` в двоичной системе — столбиком, с переносами,
# как в теории.
#
# Проверить себя легко: 11 + 6 = 17, переведи 17 в двоичную и сравни.

# %%
#@title 🏠 Домашнее 3. Двоичное сложение { display-mode: "form" }
#@markdown Впиши двоичную запись суммы
дз_3 = "" #@param {type:"string"}

si.ответ("дз3", дз_3, "d3ec5eee0b83fc66",
         hint="Ответ пятизначный и начинается с единицы.")

# %% [markdown]
# ---
#
# ### Проверь себя
#
# Сложи столбиком на бумаге, а потом набери в калькуляторе `bin(11 + 6)`
# и сравни. Если сошлось — двоичное сложение ты понял, и понял лучше
# компьютера: он просто выполняет правила, а ты знаешь, откуда они взялись.

# %% [markdown]
# ---
#
# ## Отчёт по уроку
#
# Запусти ячейку ниже, когда решишь задачи. Результат уйдёт учителю автоматически.

# %%
si.report()

# %% [markdown]
# ---
#
# [← Урок 4](https://colab.research.google.com/github/LeksssGray/informatika-7-11/blob/main/klass-07/urok-04.ipynb) · [⬆ Все уроки](https://colab.research.google.com/github/LeksssGray/informatika-7-11/blob/main/klass-07/index.ipynb) · [🏠 Ко всем классам](https://colab.research.google.com/github/LeksssGray/informatika-7-11/blob/main/index.ipynb) · [Урок 6 →](https://colab.research.google.com/github/LeksssGray/informatika-7-11/blob/main/klass-07/urok-06.ipynb)
