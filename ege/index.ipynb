# %% [markdown]
# # Тренажёр ЕГЭ
#
# Необязательный раздел. Здесь собраны уроки курса, в которых разбираются задания ЕГЭ, — чтобы готовиться точечно, не перечитывая весь год.
#
# [🏠 Ко всем классам](https://colab.research.google.com/github/LeksssGray/informatika-7-11/blob/main/index.ipynb)
#
# ---
#
# ## 10 класс
#
# | Урок | Тема | Что разбираем |
# |:--:|---|---|
# | 2 | Кодирование текстовой информации <sub>(готовится)</sub> | Однобайтные кодировки и таблица ASCII. Unicode, UTF-8 и переменная длина символа. Расчёт объёма текста. Мощность алфавита. |
# | 3 | Кодирование графической информации <sub>(готовится)</sub> | Растровое изображение: разрешение, глубина цвета, палитра. Формула объёма. Сжатие с потерями и без. Векторное представление. |
# | 4 | Кодирование звука <sub>(готовится)</sub> | Дискретизация: частота и глубина кодирования. Формула объёма аудио. Каналы. Качество и размер файла. Форматы звука. |
# | 5 | Системы счисления: углубление <sub>(готовится)</sub> | Позиционные системы с произвольным основанием. Быстрые переводы. Числа в системах с основанием, кратным двум. Сравнение чисел в разных системах. |
# | 6 | Арифметика в системах счисления <sub>(готовится)</sub> | Сложение, вычитание, умножение в двоичной и других системах. Уравнения с числами в разных системах. Определение основания по записи. |
# | 9 | Алгебра логики: полный набор операций <sub>(готовится)</sub> | Конъюнкция, дизъюнкция, инверсия, импликация, эквиваленция, исключающее ИЛИ. Приоритет операций. Таблицы истинности. |
# | 10 | Преобразование логических выражений <sub>(готовится)</sub> | Законы алгебры логики. Правила де Моргана. Раскрытие импликации. Приведение к нормальной форме. Доказательство тождеств. |
# | 11 | Логические уравнения <sub>(готовится)</sub> | Решение уравнений и систем логических уравнений. Подсчёт числа решений. Метод отображения и метод перебора. Проверка перебором в коде. |
# | 15 | Файловые системы и хранение данных <sub>(готовится)</sub> | Организация файловой системы. Пути, маски, права доступа. Объём и фрагментация. Резервное копирование. Форматы хранения данных. |
# | 21 | Двумерные списки и матрицы <sub>(готовится)</sub> | Создание матрицы, обход, обработка строк и столбцов. Диагонали. Транспонирование. Типичные ошибки при создании матрицы. |
# | 22 | Строки: срезы, методы, форматирование <sub>(готовится)</sub> | Неизменяемость строк. Срезы с шагом. Методы поиска и замены. split и join. Форматирование и выравнивание вывода. |
# | 24 | Файлы и обработка данных <sub>(готовится)</sub> | Чтение и запись текстовых файлов, форматы CSV и JSON. Разбор строк в записи. Накопление статистики по файлу. |
# | 29 | Рекурсия и перебор вариантов <sub>(готовится)</sub> | Рекурсивные определения. Дерево вызовов. Полный перебор с возвратом. Мемоизация как способ ускорить рекурсию. |
# | 30 | Обработка последовательностей: типовые задачи <sub>(готовится)</sub> | Классические задачи: подпоследовательности, скользящее окно, накопленные суммы, поиск серий. Шаблоны решений, которые работают всегда. |
#
# ## 11 класс
#
# | Урок | Тема | Что разбираем |
# |:--:|---|---|
# | 1 | Повторение 10 класса. План выпускного года <sub>(готовится)</sub> | Диагностическая работа. Карта года: что нужно освоить и в какие сроки. Как устроен экзамен и как встроить подготовку в обычные уроки. |
# | 2 | Эффективность алгоритмов <sub>(готовится)</sub> | Асимптотика на практике. Ограничения по времени и памяти. Как оценить, уложится ли решение. Оптимизация: замена структуры данных. |
# | 3 | Обработка целых чисел: цифры и делители <sub>(готовится)</sub> | Разбор числа на цифры. Делители и их поиск за корень из N. Признаки делимости. НОД и НОК, алгоритм Евклида. |
# | 4 | Простые числа и решето Эратосфена <sub>(готовится)</sub> | Проверка числа на простоту. Решето Эратосфена. Разложение на множители. Оценка времени работы на больших диапазонах. |
# | 5 | Динамическое программирование: знакомство <sub>(готовится)</sub> | Задачи с накоплением ответа: числа Фибоначчи, лестница, маршруты в таблице. Таблица подзадач вместо рекурсии. |
# | 6 | Системы счисления в задачах ЕГЭ <sub>(готовится)</sub> | Задачи с переменным основанием, поиск оснований по условию, сумма цифр и остатки. Решение перебором в коде как способ проверки. |
# | 7 | Практикум ЕГЭ: исполнители и анализ программ <sub>(готовится)</sub> | Задания на формальных исполнителей и анализ готовых программ. Обратный ход и перебор. Автоматная модель исполнителя. |
# | 10 | Кратчайшие пути <sub>(готовится)</sub> | Задача о кратчайшем пути во взвешенном графе. Алгоритм Дейкстры на понятном уровне. Классические задачи про дороги и стоимость маршрута. |
# | 17 | Компьютерные сети и протоколы <sub>(готовится)</sub> | Модель уровней, стек TCP/IP. Коммутация пакетов. Основные протоколы. Расчёт времени передачи и пропускной способности. |
# | 18 | IP-адресация и маски подсети <sub>(готовится)</sub> | Структура IP-адреса. Маска подсети, адрес сети и адрес узла. Разбор классических задач ЕГЭ на маски. Проверка ответа кодом. |
# | 25 | Практикум ЕГЭ: обработка файлов данных <sub>(готовится)</sub> | Задания 17, 22, 23 и 26: чтение больших файлов, подсчёты по условию, оптимальный выбор. Надёжные шаблоны решения. |
# | 28 | Логика в задачах ЕГЭ <sub>(готовится)</sub> | Логические выражения с переменными, таблицы с пропусками, логические уравнения и подсчёт числа решений. Проверка перебором. |
# | 29 | Выигрышные стратегии в играх <sub>(готовится)</sub> | Игры с двумя игроками и полной информацией. Дерево игры, выигрышные и проигрышные позиции. Разбор классических задач. |
# | 30 | Практикум ЕГЭ: программирование <sub>(готовится)</sub> | Задания 24–27: обработка строк большого объёма, поиск оптимума, задачи с двумя проходами по данным. Разбор эталонных решений. |
# | 33 | Повторение перед экзаменом <sub>(готовится)</sub> | Разбор полного варианта ЕГЭ. Стратегия распределения времени, порядок решения, проверка ответов, типичные потери баллов. |
#
# ---
#
# ### Совет по подготовке
#
# Разбирайте задания не по порядку номеров, а по темам: сначала то, что даётся тяжелее всего. Каждое решение проверяйте программой — на экзамене этой возможности не будет, зато сейчас она быстрее всего показывает ошибку в рассуждении.
#
# [🏠 Ко всем классам](https://colab.research.google.com/github/LeksssGray/informatika-7-11/blob/main/index.ipynb)
