# %% [markdown]
# # Урок 6. Компьютер считает
#
# 5–6 класс · I четверть
#
# [⬆ Все уроки](https://colab.research.google.com/github/LeksssGray/informatika-7-11/blob/main/klass-05-06/index.ipynb) · [← Урок 5](https://colab.research.google.com/github/LeksssGray/informatika-7-11/blob/main/klass-05-06/urok-05.ipynb) · [Урок 7 →](https://colab.research.google.com/github/LeksssGray/informatika-7-11/blob/main/klass-05-06/urok-07.ipynb)
#
# ---
#
# Складываем, умножаем, делим. Считаем то, что вручную считать лень: сколько минут в году, сколько дней ты уже прожил.

# %%
#@title 🚀 Регистрация { display-mode: "form" }
#@markdown Впиши свои данные и запусти ячейку (Shift+Enter).
#@markdown Если заводил секрет `INFORMATIKA` и включил к нему доступ
#@markdown (🔑 на панели слева) — поля можно оставить пустыми.
#@markdown
#@markdown Colab спросит разрешение на доступ к аккаунту — нажми
#@markdown «Разрешить». Так проверка понимает, чья это работа.
ФИО = "" #@param {type:"string"}
#@markdown Класс — с буквой, например 5А
Класс = "" #@param {type:"string"}
#@markdown
#@markdown Адрес журнала даёт учитель. Пусто — в конце урока
#@markdown получишь квитанцию, её нужно будет отправить ему сам.
Журнал = "" #@param {type:"string"}

import importlib, urllib.request
urllib.request.urlretrieve("https://raw.githubusercontent.com/LeksssGray/informatika-7-11/main/lib/schoolinf.py", "schoolinf.py")
import schoolinf as si
importlib.reload(si)
si.start(lesson="05-06", name=ФИО, klass=Класс,
         journal=Журнал)

# %% [markdown]
# ## Начнём с соревнования
#
# Учитель считает на калькуляторе, класс — в уме или на бумаге.
# Кто быстрее?
#
# 1. 7 × 8
# 2. 125 × 8
# 3. 365 × 24
# 4. 3600 × 24 × 365
#
# На первых примерах класс обычно успевает. На последнем калькулятор
# побеждает с большим отрывом — и не ошибается. Люди веками придумывали
# приспособления, чтобы считать быстрее и без ошибок. Посмотрим какие.

# %% [markdown]
# ## Как это было: от счётов до компьютера
#
# ### Счёты
#
# <img src="https://raw.githubusercontent.com/LeksssGray/informatika-7-11/main/img/g56/schety.jpg" width="300" alt="Русские счёты">
#
# *Русские счёты*
#
# <sub>автор неизвестен · общественное достояние · Wikimedia Commons</sub>
#
# Русские счёты появились больше четырёхсот лет назад. Каждая проволока —
# один разряд: единицы, десятки, сотни. На проволоке десять костяшек,
# две средние покрашены в другой цвет, чтобы быстрее отсчитывать пятёрки.
# Опытный продавец складывал на счётах быстрее, чем покупатель
# на калькуляторе. Их можно было встретить в магазинах ещё
# в конце XX века.
#
# ### Машина Паскаля
#
# <img src="https://raw.githubusercontent.com/LeksssGray/informatika-7-11/main/img/g56/paskalina.jpg" width="460" alt="Паскалина — суммирующая машина Блеза Паскаля, старинная гравюра">
#
# *Паскалина — суммирующая машина Блеза Паскаля, старинная гравюра*
#
# <sub>гравюра XVIII века · общественное достояние · Wikimedia Commons</sub>
#
# В 1642 году девятнадцатилетний француз Блез Паскаль собрал
# механическую суммирующую машину, чтобы помочь отцу: тот собирал налоги
# и целыми днями складывал столбики чисел. Внутри — шестерёнки. Одно
# колёсико провернулось на полный круг — и зацепило соседнее, как
# одометр в машине. Так машина сама переносила единицу в следующий
# разряд.
#
# ### Арифмометр «Феликс»
#
# <img src="https://raw.githubusercontent.com/LeksssGray/informatika-7-11/main/img/g56/feliks.jpg" width="460" alt="Арифмометр «Феликс»">
#
# *Арифмометр «Феликс»*
#
# <sub>Радион · CC0 · Wikimedia Commons</sub>
#
# В СССР почти в каждой бухгалтерии стоял арифмометр «Феликс». Число
# набирали рычажками, потом крутили ручку: вперёд — сложение, назад —
# вычитание. Умножение — несколько оборотов подряд. Его выпускали
# почти пятьдесят лет, и за это время сделали миллионы штук.
#
# ### Логарифмическая линейка
#
# <img src="https://raw.githubusercontent.com/LeksssGray/informatika-7-11/main/img/g56/lineyka.jpg" width="520" alt="Логарифмическая линейка">
#
# *Логарифмическая линейка*
#
# <sub>Jacek Halicki · CC BY-SA 4.0 · Wikimedia Commons</sub>
#
# Инженеры до 1970-х годов носили в кармане логарифмическую линейку.
# Сдвигаешь среднюю планку — и сразу видишь результат умножения
# или деления, пусть и примерно. На таких линейках считали самолёты,
# мосты и ракеты.
#
# ### А потом появились калькуляторы
#
# В 1970-х карманные электронные калькуляторы подешевели, и линейки,
# счёты и арифмометры за несколько лет ушли в музеи. Сегодня
# калькулятор есть в каждом телефоне. А компьютер умеет больше
# калькулятора: он не только считает, но и помнит, что посчитал,
# и может повторить расчёт хоть миллион раз.

# %% [markdown]
# ## Разбираемся
#
# ### Зачем считать на компьютере, если есть калькулятор
#
# Калькулятор решает один пример за раз, и промежуточный ответ приходится
# держать в голове. Компьютер решит тысячу примеров подряд и все
# промежуточные результаты запомнит сам. Сегодня научимся поручать ему
# то, что вручную считать лень.
#
# ### Все действия
#
# | Что делает | Знак | Пример | Ответ |
# |---|---|---|---|
# | сложение | `+` | `7 + 3` | `10` |
# | вычитание | `-` | `7 - 3` | `4` |
# | умножение | `*` | `7 * 3` | `21` |
# | деление | `/` | `7 / 2` | `3.5` |
# | деление без остатка | `//` | `7 // 2` | `3` |
# | остаток | `%` | `7 % 2` | `1` |
#
# Первые четыре знакомы по математике. Последние два стоит разобрать
# отдельно — они пригодятся много раз.
#
# ### Деление нацело и остаток
#
# Представь: 7 конфет надо разделить на двоих поровну.
#
# Каждому достанется по 3 конфеты — это `7 // 2`, деление нацело.
# Одна конфета останется лишней — это `7 % 2`, остаток.
#
# ```
#   7 // 2 = 3      сколько целых поместилось
#   7 % 2  = 1      сколько осталось
# ```
#
# Этой парой решается куча бытовых задач: перевести минуты в часы,
# копейки в рубли, разложить предметы по коробкам.
#
# ### Переменные — коробки для чисел
#
# Результат можно запомнить, положив его в **переменную**:
#
# ```python
# конфет = 7
# друзей = 2
# каждому = конфет // друзей
# ```
#
# Слева имя, справа значение. Знак `=` тут не «равно», а «положи».
#
# Имя придумываешь сам, но лучше понятное: через неделю `x` не скажет
# тебе ничего, а `конфет` скажет.
#
# ### Порядок действий
#
# Такой же, как в математике: сначала умножение и деление, потом
# сложение и вычитание. Скобки всё меняют:
#
# ```python
# 2 + 3 * 4      →  14
# (2 + 3) * 4    →  20
# ```
#
# Сомневаешься — ставь скобки. Лишняя не помешает.

# %% [markdown]
# ## Смотрим, как это работает
#
# ### Сколько ты уже прожил

# %%
возраст = 12

дней = возраст * 365
часов = дней * 24
минут = часов * 60

print("Дней прожито примерно:", дней)
print("Часов:", часов)
print("Минут:", минут)

# %% [markdown]
# Меняй возраст на свой и запускай снова. Числа получаются такие,
# что в уме их не посчитаешь, а компьютеру всё равно.

# %% [markdown]
# ### Конфеты и остаток

# %%
конфет = 17
друзей = 5

каждому = конфет // друзей
останется = конфет % друзей

print("Конфет:", конфет, "друзей:", друзей)
print("Каждому достанется:", каждому)
print("Останется лишних:", останется)

# %% [markdown]
# Три конфеты каждому, две останутся. Проверь в уме: 5 умножить на 3
# это 15, плюс 2 лишние — как раз 17.

# %% [markdown]
# ### Минуты в часы

# %%
всего_минут = 250

часов = всего_минут // 60
минут = всего_минут % 60

print(всего_минут, "минут — это", часов, "ч", минут, "мин")

# %% [markdown]
# Тот же приём, только вместо конфет минуты, а вместо друзей — 60.
# Схема одна и та же, меняются только числа.

# %% [markdown]
# ### Карманные деньги

# %%
в_неделю = 500
недель_в_году = 52

за_год = в_неделю * недель_в_году
велосипед = 15000

print("За год накопится:", за_год)
print("Велосипед стоит: ", велосипед)
print("Хватит ли:       ", за_год >= велосипед)

# %% [markdown]
# Последняя строка сравнивает два числа и печатает `True` или `False` —
# «правда» или «неправда». Про сравнения подробно поговорим позже,
# пока просто посмотри, что так тоже можно.

# %% [markdown]
# ## Пробуем сами

# %% [markdown]
# ### Задача 1. Минуты в году
#
# Сколько минут в году? В году 365 дней, в дне 24 часа,
# в часе 60 минут.
#
# Считай в одну строку или по шагам — как удобнее.

# %%
минут_в_году = ...

print(минут_в_году)

# %%
si.ответ("1", минут_в_году, "93ab8ae3b94476bd",
         hint="Дни умножить на часы, потом на минуты.")

# %% [markdown]
# ### Задача 2. Раздать поровну
#
# 100 конфет надо раздать 7 друзьям поровну.
# Сколько достанется каждому?
#
# Нужно деление **без остатка** — половину конфеты никто не оценит.

# %%
каждому = ...

print(каждому)

# %%
si.ответ("2", каждому, "8527a891e2241369",
         hint="Знак // отбрасывает остаток.")

# %% [markdown]
# ### Задача 3. А сколько останется
#
# Те же 100 конфет и 7 друзей. Сколько конфет останется лишними?

# %%
останется = ...

print(останется)

# %%
si.ответ("3", останется, "d4735e3a265e16ee",
         hint="Знак % даёт остаток.")

# %% [markdown]
# ### Задача 4. Кто придумал суммирующую машину
#
# Кто в 1642 году собрал механическую машину из шестерёнок, чтобы помочь
# отцу считать налоги?

# %%
#@title 🧩 Задача 4. Изобретатель { display-mode: "form" }
#@markdown Выбери ответ
изобретатель = "выбери ответ" #@param ["выбери ответ", "Паскаль", "Лавлейс", "Бэббидж"]

si.ответ("4", изобретатель, "4d9472ad3ac461ea",
         hint="Французский математик, в честь которого назвали машину.")

# %% [markdown]
# ## Обсудим
#
# 1. Нужно ли сейчас уметь считать в уме, если калькулятор всегда
#    под рукой? Приведи случаи, когда без этого не обойтись.
# 2. Калькулятор ошибается? А человек, который им пользуется?
#    Вспомни марсианский аппарат.
# 3. Какие ещё приспособления для счёта ты знаешь? Пальцы — тоже одно
#    из них.

# %% [markdown]
# ## Домашнее задание

# %% [markdown]
# ### 1. Секунды в сутках
#
# В сутках 24 часа, в часе 60 минут, в минуте 60 секунд.

# %%
секунд = ...

print(секунд)

# %%
si.ответ("дз1", секунд, "b045dd9c18caa8be",
         hint="Три множителя подряд.")

# %% [markdown]
# ### 2. Сколько недель до каникул
#
# До каникул 45 дней. Сколько это полных недель?
#
# В неделе 7 дней, нужно деление нацело.

# %%
недель = ...

print(недель)

# %%
si.ответ("дз2", недель, "e7f6c011776e8db7",
         hint="45 разделить на 7 без остатка.")

# %% [markdown]
# ### 3. Копим на наушники
#
# Наушники стоят 3000 рублей. Тебе дают 250 рублей в неделю.
# Через сколько **полных** недель хватит?
#
# Раздели стоимость на еженедельную сумму. Дели нацело: если получится
# с остатком, значит в последнюю неделю ещё не хватит.

# %%
недель_копить = ...

print(недель_копить)

# %%
si.ответ("дз3", недель_копить, "6b51d431df5d7f14",
         hint="3000 разделить на 250.")

# %% [markdown]
# ---
#
# ### Посчитай про себя
#
# Сколько минут ты тратишь на дорогу в школу за год? Сколько часов
# проводишь в телефоне за месяц? Сколько шагов делаешь до кухни за жизнь?
#
# Возьми ячейку, впиши свои числа и посмотри. Некоторые ответы
# удивляют.

# %% [markdown]
# ---
#
# ## Отчёт по уроку
#
# Запусти ячейку ниже, когда решишь задачи. Результат уйдёт учителю автоматически.

# %%
si.report()

# %% [markdown]
# ---
#
# [← Урок 5](https://colab.research.google.com/github/LeksssGray/informatika-7-11/blob/main/klass-05-06/urok-05.ipynb) · [⬆ Все уроки](https://colab.research.google.com/github/LeksssGray/informatika-7-11/blob/main/klass-05-06/index.ipynb) · [🏠 Ко всем классам](https://colab.research.google.com/github/LeksssGray/informatika-7-11/blob/main/index.ipynb) · [Урок 7 →](https://colab.research.google.com/github/LeksssGray/informatika-7-11/blob/main/klass-05-06/urok-07.ipynb)
