# %% [markdown]
# # Урок 5. Первые команды
#
# 5–6 класс · I четверть
#
# [⬆ Все уроки](https://colab.research.google.com/github/LeksssGray/informatika-7-11/blob/main/klass-05-06/index.ipynb) · [← Урок 4](https://colab.research.google.com/github/LeksssGray/informatika-7-11/blob/main/klass-05-06/urok-04.ipynb) · [Урок 6 →](https://colab.research.google.com/github/LeksssGray/informatika-7-11/blob/main/klass-05-06/urok-06.ipynb)
#
# ---
#
# Заставляем компьютер напечатать то, что мы хотим. Кавычки, ошибки и почему красный текст — это не страшно.

# %%
#@title 🚀 Регистрация { display-mode: "form" }
#@markdown Впиши свои данные и запусти ячейку (Shift+Enter).
#@markdown Если заводил секрет `INFORMATIKA` и включил к нему доступ
#@markdown (🔑 на панели слева) — поля можно оставить пустыми.
#@markdown
#@markdown Colab спросит разрешение на доступ к аккаунту — нажми
#@markdown «Разрешить». Так проверка понимает, чья это работа.
ФИО = "" #@param {type:"string"}
#@markdown Класс — с буквой, например 5А
Класс = "" #@param {type:"string"}
#@markdown
#@markdown Адрес журнала даёт учитель. Пусто — в конце урока
#@markdown получишь квитанцию, её нужно будет отправить ему сам.
Журнал = "" #@param {type:"string"}

import importlib, urllib.request
urllib.request.urlretrieve("https://raw.githubusercontent.com/LeksssGray/informatika-7-11/main/lib/schoolinf.py", "schoolinf.py")
import schoolinf as si
importlib.reload(si)
si.start(lesson="05-05", name=ФИО, klass=Класс,
         journal=Журнал)

# %% [markdown]
# ## Начнём с вопроса
#
# На каком языке люди разговаривают с компьютером? По-русски?
# По-английски? Цифрами? Прежде чем читать дальше, выскажите в классе
# свои версии.
#
# Правильный ответ — на **языках программирования**. Их придумали люди,
# и их тысячи. Каждый похож на очень строгий английский: мало слов
# и жёсткие правила, где стоит каждая скобка. Мы будем говорить
# на языке **Python**.

# %% [markdown]
# ## Как это было: программы на бумаге
#
# ### Первая программа
#
# <img src="https://raw.githubusercontent.com/LeksssGray/informatika-7-11/main/img/g56/ada.jpg" width="300" alt="Ада Лавлейс, портрет 1840 года">
#
# *Ада Лавлейс, портрет 1840 года*
#
# <sub>Alfred Edward Chalon · общественное достояние · Wikimedia Commons</sub>
#
# Первую программу написала англичанка Ада Лавлейс в 1843 году — когда
# компьютеров ещё не было. Её друг Чарльз Бэббидж придумал
# механическую вычислительную машину из шестерёнок, а Ада расписала,
# в каком порядке эта машина должна считать особые числа. Машину так
# и не достроили, но программа Ады сохранилась. Её считают первым
# программистом в истории.
#
# ### Программа в коробке
#
# <img src="https://raw.githubusercontent.com/LeksssGray/informatika-7-11/main/img/g56/perfokarty.jpg" width="520" alt="Хранилище перфокарт, 1950-е годы">
#
# *Хранилище перфокарт, 1950-е годы*
#
# <sub>Национальный архив США · общественное достояние · Wikimedia Commons</sub>
#
# Лет шестьдесят назад программы не печатали на экране. Каждую строчку
# пробивали дырочками на картонной **перфокарте**. Программа в тысячу
# строк — это тысяча карточек, толстая стопка в коробке. Уронил коробку
# и рассыпал — полдня собираешь по порядку. Поэтому на краю стопки
# программисты рисовали наискосок линию фломастером: по ней рассыпанные
# карточки было проще сложить обратно.
#
# Отдал коробку оператору, а результат получаешь назавтра. Ошибся
# в одной букве — ещё день ждать. Сейчас ты исправляешь ошибку
# и видишь результат за секунду.
#
# ### «Hello, world!»
#
# Почти каждый программист в мире начинал с одной и той же программы:
# она печатает на экране «Hello, world!» — «Привет, мир!». Эту традицию
# завели в 1970-х годах авторы учебника по языку C. С тех пор первая
# программа на любом новом языке — это приветствие миру.
#
# ### Почему Python
#
# Python придумал голландский программист Гвидо ван Россум, первая
# версия вышла в 1991 году. Назван язык не в честь змеи, а в честь
# английской комедийной передачи «Летающий цирк Монти Пайтона».
#
# Python выбирают для первого знакомства, потому что он короткий
# и понятный: команда `print("Привет")` делает ровно то, что написано.
# При этом на нём работают серьёзные вещи — Instagram, программы
# учёных NASA, нейросети.

# %% [markdown]
# ## Разбираемся
#
# ### Одна команда, которую ты уже знаешь
#
# `print` — «напечатай». Мы её пробовали, теперь разберём как следует.
#
# ```python
# print("Привет")
# ```
#
# Внутри скобок кладут то, что надо вывести. В кавычках — текст,
# без кавычек — числа и вычисления.
#
# ### Несколько кусков сразу
#
# Через запятую можно перечислить что угодно, компьютер сам расставит
# пробелы:
#
# ```python
# print("Мне", 12, "лет")     →  Мне 12 лет
# ```
#
# ### Строки складываются
#
# Текст тоже можно складывать:
#
# ```python
# "при" + "вет"     →  привет
# ```
#
# Плюс склеивает два текста в один. Только имей в виду: пробел сам
# не появится. Нужен пробел — добавь его вручную:
#
# ```python
# "при" + " " + "вет"     →  при вет
# ```
#
# ### Строки умножаются
#
# И даже умножать на число:
#
# ```python
# "-" * 20     →  --------------------
# "ха" * 3     →  хахаха
# ```
#
# Звёздочка повторяет текст заданное число раз. Из плюса и звёздочки
# собирается почти любая картинка из символов.
#
# ### Перевод строки
#
# Чтобы текст пошёл с новой строки, внутрь кавычек ставят `\n`:
#
# ```python
# print("первая\nвторая")
# ```
#
# напечатает две строки. Обратный слеш с буквой n на экран не попадает:
# для компьютера это команда «перейди на новую строку».
#
# ### Комментарии
#
# Всё, что после знака `#`, компьютер пропускает. Это заметки для людей:
#
# ```python
# # тут рисуем рамку
# print("+-----+")
# ```

# %% [markdown]
# ## Смотрим, как это работает
#
# ### Склеиваем и повторяем
#
# Запусти ячейку, потом поменяй в ней что-нибудь и запусти снова.

# %%
print("ха" * 5)
print("=" * 30)
print("при" + "вет")
print("при" + " " + "вет")

# %% [markdown]
# В двух последних строках слова слиплись: пробела в кавычках нет,
# а сам компьютер его не добавит.

# %% [markdown]
# ### Рамка

# %%
print("+" + "-" * 18 + "+")
print("|" + " " * 18 + "|")
print("|" + " Привет, 5 класс! " + "|")
print("|" + " " * 18 + "|")
print("+" + "-" * 18 + "+")

# %% [markdown]
# Посмотри, как собрана верхняя строка: плюсик, восемнадцать дефисов,
# ещё плюсик. Меняй число 18 и смотри, как рамка растягивается.

# %% [markdown]
# ### Смайлик

# %%
print("^_^")
print("^_^" * 3)
print(("^_^" + " ") * 5)

# %% [markdown]
# Скобки в последней строке нужны, чтобы сначала склеить смайлик
# с пробелом, а уже потом повторить всё вместе пять раз.
# Убери скобки и посмотри, что изменится.

# %% [markdown]
# ### Рисунки из символов
#
# Рисовать буквами и значками придумали задолго до компьютеров:
# машинистки на пишущих машинках складывали из букв портреты
# и открытки. А в 1982 году американский учёный Скотт Фалман предложил
# в переписке обозначать шутку значком `:-)` — если наклонить голову
# влево, видно улыбающееся лицо. Так появился первый смайлик.
#
# Сегодня мы тоже порисуем символами — рамки, полоски, ёлочки.

# %% [markdown]
# ## Обсудим
#
# 1. Почему программы пишут на особых языках, а не просто по-русски?
#    Вспомни робота-бутерброд с прошлых уроков.
# 2. Как ты думаешь, какие программы на твоём телефоне самые большие —
#    на тысячи строк или на миллионы?
# 3. Что было бы, если бы компьютер «догадывался», что ты имел в виду?
#    Удобно это или опасно?

# %% [markdown]
# ## Пробуем сами
#
# Здесь ты впервые пишешь код сам. Пока это одна строчка: выражение
# из кавычек, плюсов и звёздочек.
#
# В ячейках ниже замени многоточие `...` на своё выражение и запусти.
# Проверка сразу скажет, что получилось.

# %% [markdown]
# ### Задача 1. Полоска
#
# Собери строку из тридцати звёздочек.
#
# Подсказка: звёздочка в кавычках, знак умножения, число.

# %%
# песочница: пробуй здесь, пока не получится
print("*" * 5)

# %%
si.ответ("1", ..., "346db64dab683388",
         hint='Тридцать звёздочек: "*" умножить на 30.')

# %% [markdown]
# ### Задача 2. Приветствие
#
# Склей строку `Меня зовут Аня` из двух кусков и пробела между ними.

# %%
# песочница
print("Меня зовут" + " " + "Аня")

# %%
si.ответ("2", ..., "72246da80c934b53",
         hint='Три куска: "Меня зовут", пробел " " и "Аня".')

# %% [markdown]
# ### Задача 3. Три звезды через пробел
#
# Собери строку `* * *` — три звёздочки, между ними пробелы,
# в конце пробела нет.
#
# Можно написать её целиком в кавычках, а можно склеить из кусочков.

# %%
si.ответ("3", ..., "116a686db63f2e71",
         hint="Пять символов подряд: звезда, пробел, звезда, пробел, звезда.")

# %% [markdown]
# ### Задача 4. Первый программист
#
# Кто написал первую программу — ещё до того, как появились компьютеры?

# %%
#@title 🧩 Задача 4. Первый программист { display-mode: "form" }
#@markdown Выбери ответ
кто = "выбери ответ" #@param ["выбери ответ", "Ада Лавлейс", "Гвидо ван Россум", "Скотт Фалман"]

si.ответ("4", кто, "40d2ad9fdade810b",
         hint="Она расписала работу машины из шестерёнок в 1843 году.")

# %% [markdown]
# ## Домашнее задание

# %% [markdown]
# ### 1. Своя рамка
#
# Собери верхнюю строку рамки: плюсик, пять дефисов, плюсик.
# Должно получиться `+-----+`.

# %%
si.ответ("дз1", ..., "de239ef4809ce49c",
         hint='Плюсы по краям отдельно, дефисы посередине: "-" умножить на 5.')

# %% [markdown]
# ### 2. Две строки
#
# Собери строку так, чтобы при печати получилось две строки:
#
# ```
# первая
# вторая
# ```
#
# Между словами поставь `\n` — всё в одних кавычках.

# %%
# песочница
print("раз\nдва")

# %%
si.ответ("дз2", ..., "88ca64739185f80f",
         hint="Всё в одних кавычках, посередине \\n без пробелов.")

# %% [markdown]
# ### 3. Ёлочка
#
# Собери ёлочку. Должно получиться так:
#
# ```
#   *
#  ***
# *****
# ```
#
# Присмотрись: в первой строке два пробела и звёздочка, во второй
# один пробел и три звёздочки, в третьей пробелов нет и пять звёздочек.
#
# Строки соединяются через `\n`.

# %%
# песочница: собирай по строчке
print("  *")
print(" ***")
print("*****")

# %%
si.ответ("дз3", ..., "8ac31a196572daef",
         hint="Пробелы в начале строк тоже считаются, их надо поставить точно.")

# %% [markdown]
# ---
#
# ### Если хочется
#
# Нарисуй символами что-нибудь своё: домик, кота, надпись из звёздочек.
# Сломать нельзя ничего, а получается неожиданно красиво.

# %% [markdown]
# ---
#
# ## Отчёт по уроку
#
# Запусти ячейку ниже, когда решишь задачи. Результат уйдёт учителю автоматически.

# %%
si.report()

# %% [markdown]
# ---
#
# [← Урок 4](https://colab.research.google.com/github/LeksssGray/informatika-7-11/blob/main/klass-05-06/urok-04.ipynb) · [⬆ Все уроки](https://colab.research.google.com/github/LeksssGray/informatika-7-11/blob/main/klass-05-06/index.ipynb) · [🏠 Ко всем классам](https://colab.research.google.com/github/LeksssGray/informatika-7-11/blob/main/index.ipynb) · [Урок 6 →](https://colab.research.google.com/github/LeksssGray/informatika-7-11/blob/main/klass-05-06/urok-06.ipynb)
