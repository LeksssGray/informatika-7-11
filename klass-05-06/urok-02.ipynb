# %% [markdown]
# # Урок 2. Что компьютер умеет, а что нет
#
# 5–6 класс · I четверть
#
# [⬆ Все уроки](https://colab.research.google.com/github/LeksssGray/informatika-7-11/blob/main/klass-05-06/index.ipynb) · [← Урок 1](https://colab.research.google.com/github/LeksssGray/informatika-7-11/blob/main/klass-05-06/urok-01.ipynb) · [Урок 3 →](https://colab.research.google.com/github/LeksssGray/informatika-7-11/blob/main/klass-05-06/urok-03.ipynb)
#
# ---
#
# Компьютер невероятно быстрый и совершенно безмозглый. Почему он делает ровно то, что сказано, и никогда — то, что имелось в виду.

# %% [markdown]
# ### Напоминание: два шага в начале
#
# **1.** Выскочит предупреждение «блокнот создан не в Google» — жми **«Всё равно выполнить»**. Так Colab встречает любой чужой файл.
#
# **2.** Заполни ячейку ниже и запусти её кнопкой ▶ или Shift+Enter. Дальше идёшь по ячейкам сверху вниз.
#
# Если ты заводил секрет `ИНФОРМАТИКА` (как — написано в конце урока), поля можно оставить пустыми: они заполнятся сами.
#
# ---

# %%
#@title 🚀 Шаг 1. Регистрация и подготовка урока { display-mode: "form" }
#@markdown Впиши свои данные и запусти ячейку (Shift+Enter).
#@markdown Если заводил секрет `ИНФОРМАТИКА` — оставь поля
#@markdown пустыми, они заполнятся сами.
#@markdown
#@markdown Colab спросит разрешение на доступ к аккаунту — нажми
#@markdown «Разрешить». Так проверка понимает, чья это работа.
ФИО = "" #@param {type:"string"}
#@markdown Класс — с буквой, например 5А
Класс = "" #@param {type:"string"}
#@markdown
#@markdown Адрес журнала даёт учитель. Пусто — в конце урока
#@markdown получишь квитанцию, её нужно будет отправить ему сам.
Журнал = "" #@param {type:"string"}

import importlib, urllib.request
urllib.request.urlretrieve("https://raw.githubusercontent.com/LeksssGray/informatika-7-11/main/lib/schoolinf.py", "schoolinf.py")
import schoolinf as si
importlib.reload(si)
si.start(lesson="05-02", name=ФИО, klass=Класс,
         journal=Журнал)

# %% [markdown]
# ## Разбираемся
#
# ### Компьютер очень быстрый и очень тупой
#
# Обе половины этой фразы правда, и обе важны.
#
# Обычный компьютер выполняет **несколько миллиардов действий в секунду**.
# Если бы ты складывал числа со скоростью одно в секунду и не спал,
# то работу, которую он делает за секунду, ты бы заканчивал лет через сто.
#
# А теперь вторая половина. Компьютер не понимает **ничего**. Ни одного
# слова. Он не знает, что такое «дом», «мама» или «завтра». Он умеет
# только выполнять инструкции — точно и буквально.
#
# ### Что значит «буквально»
#
# Представь, что ты просишь друга: «Сходи в магазин, купи хлеб.
# Если будут яйца — возьми десяток».
#
# Друг возвращается с десятью батонами хлеба.
#
# Смешно, но компьютер поступил бы именно так. Он выполнил инструкцию
# **буквально**: «если будут яйца — возьми десяток» — яйца были,
# значит десяток. Десяток чего? Того, о чём шла речь. Хлеба.
#
# Человек догадался бы по смыслу. Компьютер смысла не видит.
#
# ### Из этого следует всё остальное
#
# Раз он не понимает, а только выполняет, то:
#
# * **он никогда не ошибается сам** — ошибается тот, кто написал инструкцию;
# * **он не догадается**, что ты имел в виду, если написал не то;
# * **он не устанет и не заскучает** — миллион раз подряд сделает
#   одинаково.
#
# Программист — это человек, который умеет объяснить задачу так, чтобы
# её понял тот, кто вообще ничего не понимает. Это сложнее, чем кажется.
#
# ### Знаменитые случаи
#
# **Марсианский аппарат, 1999 год.** Одна команда инженеров считала
# в километрах, другая в милях. Никто не проверил. Аппарат вошёл
# в атмосферу не под тем углом и сгорел. Компьютер всё посчитал верно —
# по тем данным, что ему дали.
#
# **Ракета Ariane 5, 1996 год.** Число оказалось слишком большим
# для той ячейки, куда его записывали. Ракета развалилась через 37 секунд
# после старта. Стоимость ошибки — больше 300 миллионов долларов.
#
# Обе катастрофы устроил не компьютер. Их устроили люди, написавшие
# инструкции.

# %% [markdown]
# ## Смотрим, как это работает
#
# ### Он буквальный
#
# Попросим компьютер сложить два числа. Сначала обычно, потом —
# те же числа, но в кавычках.

# %%
print(2 + 3)
print("2" + "3")

# %% [markdown]
# В первом случае он сложил числа и получил пять. Во втором — склеил
# два текста и получил «23», потому что в кавычках это уже не числа,
# а просто значки на экране.
#
# Человек бы догадался, что мы хотели пятёрку. Компьютер не догадался.
# Он сделал ровно то, что написано.
#
# Попробуй поменять числа в ячейке и запусти снова.

# %% [markdown]
# ### Он быстрый
#
# Насколько именно — можно прикинуть. Обычный процессор делает около
# трёх миллиардов действий в секунду.

# %%
print("Действий в секунду:", 3000000000)
print("Действий за минуту:", 3000000000 * 60)
print("Действий за час:   ", 3000000000 * 3600)

# %% [markdown]
# Числа такие, что их даже прочитать вслух трудно. Три миллиарда
# в секунду — это больше, чем секунд прошло с рождения динозавров.
#
# И при этом каждое отдельное действие — простейшее: сложить, сравнить,
# переложить. Вся сложность игр и фильмов собрана из таких кирпичиков.

# %% [markdown]
# ### Ячейка-калькулятор
#
# Пригодится в задачах: меняй пример и запускай.

# %%
# калькулятор: замени пример на свой и нажми ▶
print(3000000000 * 60)

# %% [markdown]
# ## Проверь себя
#
# Ответы вписываются в поля, писать код не надо.

# %% [markdown]
# ### Задача 1. Понимает ли он смысл
#
# Понимает ли компьютер, о чём твоя программа?

# %%
#@title 🧩 Задача 1. Понимает ли компьютер { display-mode: "form" }
#@markdown Выбери ответ
понимает = "выбери ответ" #@param ["выбери ответ", "да", "нет"]

si.ответ("1", понимает, "dde7950114f546d0",
         hint="Вспомни друга с десятью батонами хлеба.")

# %% [markdown]
# ### Задача 2. Как он выполняет команды
#
# Компьютер выполняет инструкции… как?

# %%
#@title 🧩 Задача 2. Как он выполняет команды { display-mode: "form" }
#@markdown Выбери ответ
как = "выбери ответ" #@param ["выбери ответ", "буквально", "примерно", "по-своему"]

si.ответ("2", как, "df7fdd55e7dece85",
         hint="Ровно то, что написано, без догадок.")

# %% [markdown]
# ### Задача 3. Сколько за минуту
#
# Компьютер делает 3 000 000 000 действий в секунду.
# Сколько он сделает за минуту?
#
# Посчитать можно в ячейке-калькуляторе выше.

# %%
#@title 🧩 Задача 3. Действий за минуту { display-mode: "form" }
#@markdown Впиши ответ числом
за_минуту = 0 #@param {type:"integer"}

si.ответ("3", за_минуту, "6d02859fa6cf8107",
         hint="Умножь на количество секунд в минуте.")

# %% [markdown]
# ## Домашнее задание

# %% [markdown]
# ### 1. Найди буквальность в жизни
#
# Вспомни три случая, когда техника сделала не то, что от неё хотели:
# автозамена в телефоне, навигатор увёл не туда, автоматические двери
# не открылись.
#
# Записывать никуда не надо — расскажешь на следующем уроке.
# Но подумай честно: в каждом случае техника выполнила инструкцию
# буквально. Какую именно?

# %% [markdown]
# ### 2. Сколько действий за час
#
# Тот же компьютер, 3 000 000 000 действий в секунду.
# Сколько за целый час? В часе 3600 секунд.

# %%
#@title 🏠 Домашнее 2. Действий за час { display-mode: "form" }
#@markdown Впиши ответ числом
за_час = 0 #@param {type:"integer"}

si.ответ("дз2", за_час, "902d40dec6e925e1",
         hint="Действия в секунду умножить на секунды в часе.")

# %% [markdown]
# ### 3. Что напечатает
#
# Не запуская, реши, что выведет эта строка:
#
# ```python
# print("5" + "5")
# ```

# %%
#@title 🏠 Домашнее 3. Что напечатает { display-mode: "form" }
#@markdown Выбери ответ
результат = "выбери ответ" #@param ["выбери ответ", "10", "55", "5 + 5"]

si.ответ("дз3", результат, "c7e05c3805ca65af",
         hint="В кавычках это не числа, а значки. Что происходит с текстом при плюсе?")

# %% [markdown]
# ---
#
# ### Подумай
#
# Если компьютер такой тупой, почему он выигрывает у чемпионов мира
# в шахматы?
#
# Подсказка: он не думает над ходом. Он перебирает миллионы вариантов
# в секунду и выбирает лучший по правилу, которое написал человек.
# Скорость иногда заменяет ум.

# %% [markdown]
# ---
#
# ## Отчёт по уроку
#
# Запусти ячейку ниже, когда решишь задачи. Результат уйдёт учителю автоматически.

# %%
si.report()

# %% [markdown]
# ---
#
# ## Чтобы не вводить всё это заново
#
# Урок закончился, но на следующей неделе будет новый файл — и ФИО с адресом журнала придётся вписывать снова. Так делать не обязательно: Colab умеет хранить их за тебя.
#
# Запусти ячейку ниже — она покажет, что и куда вписать. Одна минута один раз, дальше поля заполняются сами.

# %%
si.запомнить()

# %% [markdown]
# Если возиться с секретами не хочется, есть второй способ — файл на Google Диске: запусти `si.запомнить_на_диске()`, а в следующих уроках `si.диск()`. Он проще, но Colab попросит доступ ко всем файлам твоего Диска — решай сам.
#
# **И про копию урока.** Эта страница общая на весь класс, твои правки в ней не сохранятся. Учителю всё уже ушло, так что для оценки копия не нужна. Но если хочешь оставить решения себе — «Файл → Сохранить копию на Диске».

# %% [markdown]
# ---
#
# [← Урок 1](https://colab.research.google.com/github/LeksssGray/informatika-7-11/blob/main/klass-05-06/urok-01.ipynb) · [⬆ Все уроки](https://colab.research.google.com/github/LeksssGray/informatika-7-11/blob/main/klass-05-06/index.ipynb) · [🏠 Ко всем классам](https://colab.research.google.com/github/LeksssGray/informatika-7-11/blob/main/index.ipynb) · [Урок 3 →](https://colab.research.google.com/github/LeksssGray/informatika-7-11/blob/main/klass-05-06/urok-03.ipynb)
