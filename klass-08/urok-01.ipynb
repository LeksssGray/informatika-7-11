# %% [markdown]
# # Урок 1. Учебник, Colab и план года
#
# 8 класс · I четверть
#
# [⬆ Все уроки](https://colab.research.google.com/github/LeksssGray/informatika-7-11/blob/main/klass-08/index.ipynb) · [Урок 2 →](https://colab.research.google.com/github/LeksssGray/informatika-7-11/blob/main/klass-08/urok-02.ipynb)
#
# ---
#
# Что мы уже умеем: переменные, ветвления, циклы, списки. Диагностическая работа. Настройка личной папки с ноутбуками на Google Диске.

# %% [markdown]
# ### Перед самым первым запуском
#
# Три вещи, о которые все спотыкаются. Прочитай — займёт минуту.
#
# **1. Нужен Google-аккаунт.** Тот же, что для почты. Без него страницу можно только читать: кнопки запуска работать не будут. Если аккаунта нет — заведи, это пара минут.
#
# **2. Сейчас выскочит предупреждение.** Примерно такое:
#
# > ⚠️ *Внимание: этот блокнот создан не в Google.*
# > *Он может запрашивать доступ к вашим данным…*
#
# Пугаться не надо. Так Colab встречает **любой** файл, сделанный не самим Google, — хоть школьный урок, хоть чужую презентацию. Жми **«Всё равно выполнить»** (*Run anyway*).
#
# Что делает этот файл, видно целиком: весь код открыт и лежит в общем хранилище учебника. Он не читает твою почту и не трогает твои файлы.
#
# **3. Дальше всё просто.** Ячейки запускаются сверху вниз кнопкой ▶ слева от ячейки или клавишами Shift+Enter. Первая ячейка (с ФИО) — обязательно, иначе проверка не поймёт, чья это работа. Если что-то сломалось — «Среда выполнения → Перезапустить» и заново с первой ячейки.
#
# Правки в этой странице не сохраняются: она общая на весь класс. Но и не пропадают: каждая проверка уходит учителю сразу, в момент запуска. Если хочешь сохранить урок себе — «Файл → Сохранить копию на Диске», об этом ещё напомню в конце.
#
# ---

# %%
#@title 🚀 Шаг 1. Регистрация и подготовка урока { display-mode: "form" }
#@markdown Впиши свои данные и запусти ячейку (Shift+Enter).
#@markdown Если заводил секрет `ИНФОРМАТИКА` — оставь поля
#@markdown пустыми, они заполнятся сами.
#@markdown
#@markdown Colab спросит разрешение на доступ к аккаунту — нажми
#@markdown «Разрешить». Так проверка понимает, чья это работа.
ФИО = "" #@param {type:"string"}
#@markdown Класс — с буквой, например 8А
Класс = "" #@param {type:"string"}
#@markdown
#@markdown Адрес журнала даёт учитель. Пусто — в конце урока
#@markdown получишь квитанцию, её нужно будет отправить ему сам.
Журнал = "" #@param {type:"string"}

import importlib, urllib.request
urllib.request.urlretrieve("https://raw.githubusercontent.com/LeksssGray/informatika-7-11/main/lib/schoolinf.py", "schoolinf.py")
import schoolinf as si
importlib.reload(si)
si.start(lesson="08-01", name=ФИО, klass=Класс,
         journal=Журнал)

# %% [markdown]
# ## Как работать с учебником
#
# Учебник живой: это не текст, который читают, а страница, на которой
# нажимают кнопки. Если ты уже работал с ней в прошлом году — пролистай
# этот раздел и иди дальше. Если нет, разберёмся за пару минут.
#
# ### Страница собрана из ячеек
#
# **Текстовые** — объяснения, таблицы, формулы. Вот эта, например.
#
# **Кодовые** — программы. Слева у них кнопка ▶. Нажали — выполнилось,
# результат появился внизу.
#
# Запускать можно кнопкой или клавишами **Shift + Enter**.
#
# > Ячейки выполняются в том порядке, в котором вы нажимаете кнопку,
# > а не в том, в котором они на странице. Пропустите ячейку — следующая
# > может не заработать. Идите сверху вниз.
#
# ### Первым делом — своя копия
#
# Файл общий на весь класс, ваши правки в нём не сохранятся.
# **Файл → Сохранить копию на Диске**, и дальше работайте в копии.
#
# Заведите папку для предмета: за год наберётся тридцать четыре файла.
#
# ### Как устроен урок
#
# Сначала разбираем тему. Потом примеры — их можно и нужно менять,
# ломать и запускать заново, на то они и живые. Потом задачи с проверкой
# прямо на месте. В конце домашнее задание.
#
# ### Проверка и журнал
#
# Ячейки проверки показывают, что именно не сошлось: какой тест упал
# и с какими данными. Попыток сколько угодно.
#
# Результат уходит учителю: видно, какие задачи решены, с какой попытки
# и каким кодом. Списанное решение заметно сразу — оно не похоже
# на всё остальное, что вы пишете.
#
# ### Если что-то сломалось
#
# Сломать нельзя ничего. В крайнем случае — **Среда выполнения →
# Перезапустить сеанс**, и всё начнётся с чистого листа.
#
# Красное сообщение об ошибке — не катастрофа. Главное в нём —
# последняя строка, там написано, что именно не понравилось.

# %% [markdown]
# ## Что было и что будет
#
# ### Куда мы пришли
#
# За 7 класс вы освоили довольно много. Проверим по списку — отметьте
# мысленно, что помните твёрдо, а что стоит освежить.
#
# **Информация и кодирование.** Бит и байт, формула $N = 2^i$, объём текста
# и изображения, двоичная система счисления.
#
# **Программирование.** Переменные и типы, ввод и вывод, арифметика,
# ветвления `if / elif / else`, циклы `for` и `while`, списки, строки,
# собственные функции.
#
# ### Куда мы идём
#
# Восьмой класс — год **математического фундамента**. Звучит скучновато,
# но именно здесь информатика перестаёт быть набором приёмов и становится
# наукой.
#
# **Первая четверть — системы счисления.** Двоичную вы уже видели. Теперь
# добавятся восьмеричная и шестнадцатеричная, научимся переводить между
# любыми системами и считать в них. Это язык, на котором компьютер
# разговаривает сам с собой.
#
# **Вторая четверть — алгебра логики.** Формальные правила рассуждений:
# как из условий вывести следствие, как упростить громоздкое условие,
# как устроены логические схемы внутри процессора.
#
# **Третья и четвёртая — программирование всерьёз.** Вложенные циклы, поиск,
# сортировка, обработка строк, тестирование. Появятся алгоритмы, у которых
# есть имена и авторы.
#
# ### Как работать в этом году
#
# Правила простые, но соблюдать их придётся.
#
# 1. **Сохраняйте копию каждого урока на свой Диск** — «Файл → Сохранить
#    копию на Диске». Иначе ваши решения пропадут при закрытии вкладки.
# 2. **Заводите отдельную папку** `Информатика 8` на Google Диске
#    и складывайте всё туда. К концу года там будет 34 ноутбука —
#    готовый личный конспект.
# 3. **Домашнее задание проверяется автоматически**, но учитель видит
#    не только вердикт, а и ваш код, и число попыток. Списанное решение
#    видно сразу — оно не похоже на всё остальное, что вы пишете.
# 4. **Ошибка не наказуема, неисправленная ошибка — да.** Попыток
#    неограниченно, добивайтесь зелёной галочки.
#
# ### Как читать сообщение об ошибке
#
# Напоминание, которое сэкономит вам часы:
#
# | Сообщение | Причина | Что делать |
# |---|---|---|
# | `SyntaxError` | опечатка в записи | проверить скобки, кавычки, двоеточия |
# | `NameError` | имя не существует | опечатка в имени или ячейка не запущена |
# | `TypeError` | несовместимые типы | добавить `int()`, `str()` где нужно |
# | `IndexError` | вышли за границу списка | проверить индексы: нумерация с нуля |
# | `IndentationError` | сбились отступы | выровнять отступы по 4 пробела |

# %% [markdown]
# ## Освежаем навыки
#
# ### Пример 1. Всё, что нужно помнить об операциях

# %%
a, b = 17, 5

print(f"{a} + {b}  = {a + b}")
print(f"{a} / {b}  = {a / b}      ← обычное деление, всегда дробное")
print(f"{a} // {b} = {a // b}        ← деление нацело")
print(f"{a} % {b}  = {a % b}        ← остаток")
print(f"{a} ** 2 = {a ** 2}      ← степень")

# %% [markdown]
# Пара `//` и `%` — рабочая лошадка всей информатики. Деление нацело
# отвечает «сколько целых раз поместилось», остаток — «сколько не поместилось».
# В этом году они понадобятся буквально на каждом уроке.

# %% [markdown]
# ### Пример 2. Цикл, условие и накопление в одной задаче
#
# Найдём сумму всех чётных чисел от 1 до 20.

# %%
сумма = 0
for число in range(1, 21):
    if число % 2 == 0:
        сумма += число

print("Сумма чётных от 1 до 20:", сумма)

# %% [markdown]
# Три элемента, которые встретятся вам сотни раз:
#
# * **накопитель** `сумма = 0` — заводится до цикла;
# * **перебор** `for число in range(1, 21)` — обратите внимание, что 21
#   не входит в диапазон, поэтому пишем на единицу больше;
# * **фильтр** `if число % 2 == 0` — остаток от деления на 2 равен нулю
#   только у чётных.

# %% [markdown]
# ### Пример 3. Строки и списки
#
# Соберём частотную сводку по строке — задача, которая покажет, что вы
# помните о работе с текстом.

# %%
слово = "информатика"

гласные = "аеёиоуыэюя"
счётчик = 0
согласные_список = []

for буква in слово:
    if буква in гласные:
        счётчик += 1
    else:
        согласные_список.append(буква)

print(f"В слове «{слово}» {len(слово)} букв")
print(f"Гласных: {счётчик}")
print(f"Согласные: {согласные_список}")
print(f"Слово наоборот: {слово[::-1]}")

# %% [markdown]
# Здесь стоит вспомнить три вещи: оператор `in` проверяет вхождение,
# метод `append` добавляет элемент в конец списка, а срез `[::-1]`
# переворачивает строку.

# %% [markdown]
# ## Проверяем, что помним
#
# Шесть задач по материалу 7 класса. Работа **не на оценку** — она нужна,
# чтобы вы и учитель увидели, что стоит повторить.

# %% [markdown]
# ### Задача 1. Объём сообщения
#
# В алфавите `мощность` символов, в сообщении `символов` символов.
# Верните объём в **байтах** (может получиться дробное число).

# %%
def объём(мощность, символов):
    return ...

# %%
si.check("1", объём, [
    ((32, 100), 62.5),
    ((256, 10), 10.0),
    ((16, 200), 100.0),
])

# %% [markdown]
# ### Задача 2. Сумма цифр
#
# Верните сумму цифр целого числа. Число может быть любой длины —
# используйте цикл `while`.

# %%
def сумма_цифр(число):
    return ...

# %%
si.check("2", сумма_цифр, [
    (275, 14),
    (9, 9),
    (1000, 1),
    (99999, 45),
    (0, 0),
])

# %% [markdown]
# ### Задача 3. Максимум в списке
#
# Верните наибольший элемент списка **без использования функции `max`** —
# переберите список циклом.

# %%
def максимум(числа):
    return ...

# %%
si.check("3", максимум, [
    ([3, 7, 2], 7),
    ([-5, -1, -9], -1),
    ([42], 42),
    ([1, 1, 1], 1),
])

# %% [markdown]
# ### Задача 4. Оценка по баллам
#
# По набранным баллам (от 0 до 100) верните оценку:
#
# | Баллы | Оценка |
# |---|---|
# | 85 и выше | 5 |
# | от 70 до 84 | 4 |
# | от 50 до 69 | 3 |
# | меньше 50 | 2 |

# %%
def оценка(баллы):
    return ...

# %%
si.check("4", оценка, [
    (90, 5),
    (85, 5),
    (84, 4),
    (70, 4),
    (50, 3),
    (49, 2),
    (0, 2),
])

# %% [markdown]
# ### Задача 5. Подсчёт гласных
#
# Верните количество гласных букв в строке. Считайте только строчные
# русские гласные: `аеёиоуыэюя`.

# %%
def гласных(текст):
    return ...

# %%
si.check("5", гласных, [
    ("информатика", 5),
    ("", 0),
    ("ррр", 0),
    ("ёжик", 2),
])

# %% [markdown]
# ### Задача 6. Двоичная запись
#
# Сколько единиц в двоичной записи числа 27? Посчитайте на бумаге
# и впишите ответ числом.

# %%
единиц = 0

si.check_value("6", единиц, "4b227777d4dd1fc6",
               hint="27 = 16 + 8 + 2 + 1. Запишите это двоичными разрядами.")

# %% [markdown]
# ## Домашнее задание
#
# Одно задание — повторение всего сразу.

# %% [markdown]
# ### Домашнее задание. Статистика по числам
#
# Напишите функцию, которая по списку целых чисел возвращает строку вида:
#
# ```
# Всего: 5, сумма: 21, чётных: 2, максимум: 9
# ```
#
# Всё считайте циклом, без готовых функций `sum` и `max` — это повторение
# базовых алгоритмов, а не соревнование в краткости.

# %%
def статистика(числа):
    return ...

# %%
si.check("дз", статистика, [
    ([1, 2, 4, 5, 9], "Всего: 5, сумма: 21, чётных: 2, максимум: 9"),
    ([7], "Всего: 1, сумма: 7, чётных: 0, максимум: 7"),
    ([2, 4], "Всего: 2, сумма: 6, чётных: 2, максимум: 4"),
])

# %% [markdown]
# ---
#
# ### На следующем уроке
#
# Мы начнём с вопроса, который звучит наивно, а ответ на него оказывается
# неожиданно глубоким: **почему мы считаем десятками?** И что было бы,
# если бы у человека было восемь пальцев.

# %% [markdown]
# ---
#
# ## Отчёт по уроку
#
# Запусти ячейку ниже, когда решишь задачи. Результат уйдёт учителю автоматически.

# %%
si.report()

# %% [markdown]
# ---
#
# ## Чтобы не вводить всё это заново
#
# Урок закончился, но на следующей неделе будет новый файл — и ФИО с адресом журнала придётся вписывать снова. Так делать не обязательно: Colab умеет хранить их за тебя.
#
# Запусти ячейку ниже — она покажет, что и куда вписать. Одна минута один раз, дальше поля заполняются сами.

# %%
si.запомнить()

# %% [markdown]
# Если возиться с секретами не хочется, есть второй способ — файл на Google Диске: запусти `si.запомнить_на_диске()`, а в следующих уроках `si.диск()`. Он проще, но Colab попросит доступ ко всем файлам твоего Диска — решай сам.
#
# **И про копию урока.** Эта страница общая на весь класс, твои правки в ней не сохранятся. Учителю всё уже ушло, так что для оценки копия не нужна. Но если хочешь оставить решения себе — «Файл → Сохранить копию на Диске».

# %% [markdown]
# ---
#
# [⬆ Все уроки](https://colab.research.google.com/github/LeksssGray/informatika-7-11/blob/main/klass-08/index.ipynb) · [🏠 Ко всем классам](https://colab.research.google.com/github/LeksssGray/informatika-7-11/blob/main/index.ipynb) · [Урок 2 →](https://colab.research.google.com/github/LeksssGray/informatika-7-11/blob/main/klass-08/urok-02.ipynb)
