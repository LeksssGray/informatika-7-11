# %% [markdown]
# # 8 класс. Математические основы информатики и алгоритмы
#
# Год математического фундамента. Разбираем системы счисления и алгебру логики — то, на чём стоит вся информатика, — и одновременно поднимаем программирование на новый уровень: вложенные циклы, поиск, сортировка, обработка строк и функции.
#
# [🏠 Ко всем классам](https://colab.research.google.com/github/LeksssGray/informatika-7-11/blob/main/index.ipynb)
#
# ---
#
# ### Чему научишься за год
#
# - переводить числа между двоичной, восьмеричной, шестнадцатеричной и десятичной системами
# - строить и упрощать логические выражения, решать логические задачи
# - записывать алгоритм блок-схемой и переводить его в код
# - программировать вложенные циклы, поиск и сортировку
# - тестировать и отлаживать собственные программы
#
# ---
#
# ## I четверть · уроки 1–8
#
# | № | Тема | Содержание | Домашнее задание |
# |:--:|---|---|---|
# | 1 | **[Учебник, Colab и план года](https://colab.research.google.com/github/LeksssGray/informatika-7-11/blob/main/klass-08/urok-01.ipynb)** | Что мы уже умеем: переменные, ветвления, циклы, списки. Диагностическая работа. Настройка личной папки с ноутбуками на Google Диске. | Диагностическая работа по материалу 7 класса с автопроверкой. |
# | 2 | **[Системы счисления: позиционные и непозиционные](https://colab.research.google.com/github/LeksssGray/informatika-7-11/blob/main/klass-08/urok-02.ipynb)** | Что такое система счисления. Римская система как непозиционная. Основание и алфавит. Развёрнутая запись числа. | Записать числа в развёрнутой форме и перевести римские числа в десятичные. |
# | 3 | **[Двоичная, восьмеричная и шестнадцатеричная системы](https://colab.research.google.com/github/LeksssGray/informatika-7-11/blob/main/klass-08/urok-03.ipynb)** | Три системы, которые использует компьютер. Алфавиты. Почему именно 8 и 16. Таблица соответствия для быстрого перевода. | Заполнить таблицу соответствия чисел 0–20 в четырёх системах. |
# | 4 | **[Перевод между системами счисления](https://colab.research.google.com/github/LeksssGray/informatika-7-11/blob/main/klass-08/urok-04.ipynb)** | Перевод в десятичную через развёрнутую запись. Перевод из десятичной делением на основание. Быстрый перевод через двоичную триадами и тетрадами. | Перевести числа между всеми четырьмя системами и проверить кодом. |
# | 5 | **[Арифметика в разных системах счисления](https://colab.research.google.com/github/LeksssGray/informatika-7-11/blob/main/klass-08/urok-05.ipynb)** | Сложение и вычитание в двоичной системе. Перенос разряда. Умножение на степень основания. Сравнение чисел, записанных в разных системах. | Выполнить арифметические действия в двоичной и восьмеричной системах. |
# | 6 | **[Представление целых чисел в памяти](https://colab.research.google.com/github/LeksssGray/informatika-7-11/blob/main/klass-08/urok-06.ipynb)** | Разрядная сетка. Беззнаковое представление и его диапазон. Знаковый бит. Дополнительный код и отрицательные числа. | Определить диапазоны для 8 и 16 разрядов, записать числа в дополнительном коде. |
# | 7 | **[Представление вещественных чисел](https://colab.research.google.com/github/LeksssGray/informatika-7-11/blob/main/klass-08/urok-07.ipynb)** | Формат с плавающей запятой: мантисса и порядок. Нормализованная запись. Почему 0.1 + 0.2 не равно 0.3 и что с этим делать. | Записать числа в нормализованной форме; исследовать точность вычислений кодом. |
# | 8 | **[Контрольная работа № 1: системы счисления](https://colab.research.google.com/github/LeksssGray/informatika-7-11/blob/main/klass-08/urok-08.ipynb)** | Разбор типовых ошибок. Самостоятельная работа по системам счисления и представлению чисел. | Итоговые задачи четверти с автопроверкой. |
#
# ## II четверть · уроки 9–16
#
# | № | Тема | Содержание | Домашнее задание |
# |:--:|---|---|---|
# | 9 | Алгебра логики: высказывания и операции | Высказывание и его истинность. Конъюнкция, дизъюнкция, инверсия. Обозначения и приоритет операций. Запись логических выражений. | Определить истинность высказываний и записать выражения по описанию. |
# | 10 | Таблицы истинности сложных выражений | Построение таблицы истинности по шагам. Количество строк. Импликация и эквиваленция. Проверка таблицы программой. | Построить таблицы истинности для трёх выражений и проверить их кодом. |
# | 11 | Законы логики и упрощение выражений | Основные законы: коммутативность, дистрибутивность, законы де Моргана, поглощение. Упрощение логических выражений. | Упростить пять выражений и доказать эквивалентность таблицами истинности. |
# | 12 | Логические задачи | Решение содержательных логических задач: таблицы, рассуждения, перебор вариантов. Перебор всех вариантов программой. | Решить три логические задачи вручную и одну — полным перебором в коде. |
# | 13 | Логические элементы и схемы | Элементы И, ИЛИ, НЕ. Чтение логических схем. Составление схемы по выражению и выражения по схеме. Сумматор в общих чертах. | Построить схемы по выражениям и определить выход схемы при заданных входах. |
# | 14 | Алгоритм и его свойства. Исполнители | Определение алгоритма. Дискретность, определённость, результативность, массовость. Исполнитель, его система команд и среда. | Составить алгоритмы для формального исполнителя и найти ошибки в чужих алгоритмах. |
# | 15 | Способы записи алгоритмов: блок-схемы | Словесное описание, блок-схема, программа. Элементы блок-схем. Три базовые конструкции в графическом виде. Перевод блок-схемы в код. | Нарисовать блок-схемы трёх алгоритмов и запрограммировать их. |
# | 16 | Контрольная работа № 2: логика и алгоритмы | Разбор ошибок. Самостоятельная работа по алгебре логики и записи алгоритмов. | Итоговые задачи четверти с автопроверкой. |
#
# ## III четверть · уроки 17–26
#
# | № | Тема | Содержание | Домашнее задание |
# |:--:|---|---|---|
# | 17 | Python: повторение и ввод-вывод данных | Быстрое повторение синтаксиса. Ввод нескольких значений в одной строке. Форматированный вывод. Работа с типами. | Разминочные задачи на ввод-вывод и арифметику. |
# | 18 | Ветвления: разбор сложных задач | Многовариантный выбор. Условия с логическими операторами. Проверка принадлежности диапазону. Классические задачи на ветвления. | Задачи: попадание точки в область, тарифы, определение треугольника по сторонам. |
# | 19 | Цикл for: типовые алгоритмы | Сумма и произведение, счётчик, максимум и минимум в последовательности. Шаблоны, которые встречаются в любой задаче. | Пять типовых задач на обработку последовательности чисел. |
# | 20 | Цикл while и его применение | Задачи, где число повторений заранее неизвестно. Обработка цифр числа. Условие выхода и защита от зацикливания. | Задачи: сумма и количество цифр, переворот числа, алгоритм Евклида. |
# | 21 | Вложенные циклы | Цикл внутри цикла. Таблицы и узоры. Порядок обхода. Как оценить число шагов и не написать слишком медленную программу. | Задачи: таблица умножения, треугольник из символов, поиск пар чисел. |
# | 22 | Списки: алгоритмы обработки | Заполнение списка вводом и генератором. Обход с индексом. Изменение элементов. Фильтрация и накопление результата. | Задачи: отбор элементов по условию, замена элементов, статистика по списку. |
# | 23 | Поиск в списке: линейный и двоичный | Линейный поиск и его стоимость. Двоичный поиск в отсортированном списке. Сравнение числа шагов на большом объёме данных. | Реализовать оба поиска и сравнить количество сравнений на списке из 10 000 чисел. |
# | 24 | Сортировка: пузырьком и выбором | Зачем сортировать данные. Сортировка выбором. Сортировка пузырьком. Встроенная сортировка sorted и почему она быстрее. | Реализовать обе сортировки и сравнить их со встроенной по числу операций. |
# | 25 | Строки: алгоритмы обработки | Перебор символов, срезы, поиск подстроки, замена. Разбиение строки методом split и сборка через join. Разбор текста по словам. | Задачи: частота букв, самое длинное слово, шифрование текста. |
# | 26 | Контрольная работа № 3: программирование | Разбор ошибок. Самостоятельная работа по циклам, спискам, строкам и алгоритмам поиска. | Итоговые задачи четверти с автопроверкой. |
#
# ## IV четверть · уроки 27–34
#
# | № | Тема | Содержание | Домашнее задание |
# |:--:|---|---|---|
# | 27 | Функции: параметры и возвращаемое значение | Определение функции, аргументы, return. Значения по умолчанию. Функция как способ не повторять код. Разбиение задачи на подзадачи. | Собрать библиотеку из пяти собственных функций и покрыть её проверками. |
# | 28 | Тестирование и отладка программ | Почему программа «работает не так». Чтение сообщений об ошибках. Тестовые случаи, включая граничные. Отладочная печать и assert. | Найти и исправить ошибки в пяти готовых программах; придумать тесты к своей. |
# | 29 | Электронные таблицы: сортировка и фильтрация | Диапазоны и именованные диапазоны. Сортировка по нескольким столбцам. Фильтры. Условное форматирование. | Обработать таблицу из 100 строк: отсортировать, отфильтровать, выделить цветом. |
# | 30 | Условные функции и расчёты в таблицах | Функции ЕСЛИ, СУММЕСЛИ, СЧЁТЕСЛИ. Вложенные условия. Абсолютные ссылки в формулах. Проверка результата вычислением на Python. | Рассчитать итоги по таблице условными функциями и сверить с расчётом в коде. |
# | 31 | Компьютерное моделирование | Что такое модель. Материальные и информационные модели. Этапы моделирования. Адекватность модели и границы её применимости. | Описать три модели для заданных объектов и указать, что в них упрощено. |
# | 32 | Модели в таблицах и в коде | Одна модель двумя инструментами: расчёт в таблице и расчёт программой. Пример: движение тела, рост популяции, накопления на счёте. | Построить модель роста вклада в таблице и в коде, сравнить результаты. |
# | 33 | Годовой проект | Постановка задачи, выбор инструмента, реализация, оформление результата. Критерии оценивания проекта. | Доделать и оформить проект в отдельном ноутбуке. |
# | 34 | Итоговая контрольная работа | Годовое повторение: системы счисления, логика, алгоритмы, программирование. Итоговая работа. | Итоговая работа за 8 класс с автопроверкой. |
#
# ---
#
# [🏠 Ко всем классам](https://colab.research.google.com/github/LeksssGray/informatika-7-11/blob/main/index.ipynb)
