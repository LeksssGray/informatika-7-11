# %% [markdown]
# # Урок 9. Контрольная работа № 1: системы счисления
#
# 8 класс · II четверть
#
# [⬆ Все уроки](https://colab.research.google.com/github/LeksssGray/informatika-7-11/blob/main/klass-08/index.ipynb) · [← Урок 8](https://colab.research.google.com/github/LeksssGray/informatika-7-11/blob/main/klass-08/urok-08.ipynb) · [Урок 10 →](https://colab.research.google.com/github/LeksssGray/informatika-7-11/blob/main/klass-08/urok-10.ipynb)
#
# ---
#
# Разбор типовых ошибок. Самостоятельная работа по системам счисления и представлению чисел.

# %%
#@title 🚀 Регистрация { display-mode: "form" }
#@markdown Впиши свои данные и запусти ячейку (Shift+Enter).
#@markdown Если заводил секрет `INFORMATIKA` и включил к нему доступ
#@markdown (🔑 на панели слева) — поля можно оставить пустыми.
#@markdown
#@markdown Colab спросит разрешение на доступ к аккаунту — нажми
#@markdown «Разрешить». Так проверка понимает, чья это работа.
ФИО = "" #@param {type:"string"}
#@markdown Класс — с буквой, например 8А
Класс = "" #@param {type:"string"}
#@markdown
#@markdown Адрес журнала даёт учитель. Пусто — в конце урока
#@markdown получишь квитанцию, её нужно будет отправить ему сам.
Журнал = "" #@param {type:"string"}

import importlib, urllib.request
urllib.request.urlretrieve("https://raw.githubusercontent.com/LeksssGray/informatika-7-11/main/lib/schoolinf.py", "schoolinf.py")
import schoolinf as si
importlib.reload(si)
si.start(lesson="08-09", name=ФИО, klass=Класс,
         journal=Журнал)

# %% [markdown]
# ## Где обычно ошибаются
#
# Первая четверть 8 класса позади. Разберём ошибки, которые стабильно
# встречаются в работах по системам счисления.
#
# ### Ошибка 1. Остатки читают сверху вниз
#
# При переводе делением остатки записываются **снизу вверх**. Если прочитать
# наоборот, получится перевёрнутое число.
#
# **Профилактика:** сразу после перевода сделайте обратный — двадцать секунд
# работы, и ошибка исключена.
#
# ### Ошибка 2. Группировка не с той стороны
#
# При переводе 2 → 8 и 2 → 16 группы отсчитываются **справа**.
# Число `1011100` режется по три так: `1 011 100`, а не `101 110 0`.
# Слева при нехватке дописываются нули: `001 011 100`.
#
# ### Ошибка 3. Цифра, равная основанию
#
# В системе с основанием q цифры идут **от 0 до q−1**. Записи `1082₈`
# не существует: цифры 8 в восьмеричном алфавите нет. Если такая цифра
# появилась в вашем ответе — где-то ошибка в переносе.
#
# ### Ошибка 4. Забыт перенос при сложении
#
# Порог переноса равен основанию: в двоичной перенос возникает уже при 2,
# в восьмеричной — при 8. Привычка к десятичной подводит: `7 + 5` в
# восьмеричной это не 12, а `14₈`.
#
# ### Ошибка 5. Путаница диапазонов
#
# | Что спрашивают | Формула |
# |---|---|
# | сколько чисел помещается в n разрядов | $2^n$ |
# | наибольшее беззнаковое | $2^n - 1$ |
# | диапазон со знаком | от $-2^{n-1}$ до $2^{n-1} - 1$ |
#
# Помните про минус единицу: комбинаций 256, но наибольшее число 255,
# потому что счёт идёт с нуля.
#
# ### Ошибка 6. Сравнение вещественных через ==
#
# `0.1 + 0.2 == 0.3` даёт `False`. Всегда сравнивайте через модуль разности.
#
# ### Чек-лист перед сдачей работы
#
# 1. Проверил перевод обратным переводом?
# 2. Все цифры допустимы в своей системе?
# 3. При сложении учтены все переносы?
# 4. В диапазоне не забыта минус единица?

# %% [markdown]
# ## Разбор сложных случаев
#
# ### Пример 1. Задача на определение основания
#
# > В некоторой системе счисления число 20 записывается как 110.
# > Найдите основание системы.
#
# Запишем условие развёрнутой записью. Пусть основание q:
#
# $$110_q = 1 \cdot q^2 + 1 \cdot q^1 + 0 = q^2 + q = 20$$
#
# Получилось квадратное уравнение $q^2 + q - 20 = 0$. Решать его
# необязательно — достаточно перебрать основания.

# %%
for q in range(2, 17):
    значение = 1 * q ** 2 + 1 * q + 0
    отметка = "  ← подходит!" if значение == 20 else ""
    print(f"  основание {q:>2}: 110 = {значение}{отметка}")

# %% [markdown]
# Ответ: основание 4. Перебор здесь — не «глупый» метод, а совершенно
# законный: вариантов мало, и проверить их быстрее, чем решать уравнение.
# На экзамене этот приём экономит много времени.

# %% [markdown]
# ### Пример 2. Задача на сравнение
#
# > Расположите в порядке возрастания: `1101₂`, `15₁₀`, `E₁₆`, `16₈`.
#
# Приводим всё к десятичной и сортируем.

# %%
числа = [("1101", 2), ("15", 10), ("E", 16), ("16", 8)]

значения = []
for запись, основание in числа:
    значение = int(запись, основание)
    значения.append((значение, запись, основание))
    print(f"  {запись}(осн. {основание}) = {значение}")

значения.sort()
print()
строка = ""
for _, з, о in значения:
    строка += f"{з}({о}), "
print("По возрастанию:", строка)

# %% [markdown]
# Обратите внимание: `13, 14, 14, 15` — два числа оказались равны.
# `E₁₆` и `16₈` — это одно и то же значение 14, записанное по-разному.

# %% [markdown]
# ### Пример 3. Хитрая задача на количество
#
# > Сколько единиц в двоичной записи числа $4^{20} + 2^{15} - 8$?
#
# Такие задачи решаются приведением всех слагаемых к степеням двойки.
#
# $4^{20} = (2^2)^{20} = 2^{40}$, а $8 = 2^3$.
#
# Значит выражение равно $2^{40} + 2^{15} - 2^3$. Проверим программой.

# %%
число = 4 ** 20 + 2 ** 15 - 8
запись = bin(число)[2:]

print(f"Число: {число}")
print(f"Разрядов в записи: {len(запись)}")
print(f"Единиц: {запись.count('1')}")

# %% [markdown]
# Проверять такие задачи кодом — законно и полезно: вы сначала рассуждаете
# на бумаге, а потом убеждаетесь, что рассуждение верное. На экзамене
# компьютера не будет, но привычка проверять себя останется.

# %% [markdown]
# ## Контрольная работа
#
# Семь задач по материалу первой четверти.

# %% [markdown]
# ### Задача 1. Перевод в десятичную
#
# По записи и основанию верните десятичное значение.
# Реализуйте схему Горнера, не пользуясь функцией `int` с двумя аргументами.

# %%
def в_десятичную(запись, основание):
    return ...

# %%
si.check("1", в_десятичную, [
    (("1011", 2), 11),
    (("237", 8), 159),
    (("2F", 16), 47),
    (("110", 4), 20),
])

# %% [markdown]
# ### Задача 2. Перевод из десятичной
#
# Обратное преобразование: число и основание на входе, строка на выходе.

# %%
def из_десятичной(число, основание):
    return ...

# %%
si.check("2", из_десятичной, [
    ((159, 8), "237"),
    ((47, 16), "2F"),
    ((0, 2), "0"),
    ((20, 4), "110"),
])

# %% [markdown]
# ### Задача 3. Двоичное в шестнадцатеричное
#
# Группировкой по четыре разряда, без обращения к десятичной.

# %%
def в_шестнадцатеричное(двоичное):
    return ...

# %%
si.check("3", в_шестнадцатеричное, [
    ("10111100", "BC"),
    ("11111111", "FF"),
    ("1", "1"),
    ("0", "0"),
])

# %% [markdown]
# ### Задача 4. Сложение в системе
#
# Сложите два числа столбиком в системе с заданным основанием.

# %%
def сложить(а, б, основание):
    return ...

# %%
si.check("4", сложить, [
    (("237", "45", 8), "304"),
    (("1011", "110", 2), "10001"),
    (("2F", "13", 16), "42"),
])

# %% [markdown]
# ### Задача 5. Диапазон разрядной сетки
#
# По числу разрядов и признаку «со знаком или без» верните список
# `[минимум, максимум]`.
#
# `диапазон(8, False)` → `[0, 255]`
# `диапазон(8, True)` → `[-128, 127]`

# %%
def диапазон(разрядов, со_знаком):
    return ...

# %%
si.check("5", диапазон, [
    ((8, False), [0, 255]),
    ((8, True), [-128, 127]),
    ((16, False), [0, 65535]),
    ((4, True), [-8, 7]),
])

# %% [markdown]
# ### Задача 6. Найти основание
#
# По десятичному значению и записи числа в неизвестной системе найдите
# основание. Перебирайте от 2 до 16; если не нашли — верните 0.

# %%
def основание(значение, запись):
    return ...

# %%
si.check("6", основание, [
    ((20, "110"), 4),
    ((15, "21"), 7),
    ((47, "2F"), 16),
    ((5, "99"), 0),
])

# %% [markdown]
# ### Задача 7. Теоретический вопрос
#
# Сколько единиц в двоичной записи числа $2^{10} - 1$?
#
# Подумайте: какая запись у числа, на единицу меньшего круглой
# степени двойки?

# %%
единиц = 0

si.check_value("7", единиц, "4a44dc15364204a8",
               hint="2^10 это 10000000000. Что будет на единицу меньше?")

# %% [markdown]
# ## Домашнее задание на каникулы

# %% [markdown]
# ### Домашнее задание. Калькулятор систем счисления
#
# Соберите инструмент, который пригодится вам весь год: функция получает
# два числа с их основаниями, знак операции и основание результата.
#
# Поддержите операции `"+"`, `"-"`, `"*"`.
#
# ```python
# калькулятор("1011", 2, "+", "F", 16, 10)   →  "26"
# ```
#
# Здесь 1011₂ = 11, F₁₆ = 15, сумма 26, результат в десятичной.
#
# Разбейте задачу на три шага: перевести оба числа в десятичную,
# выполнить операцию, перевести результат. Функции из задач 1 и 2
# уже написаны — используйте их.

# %%
def калькулятор(запись1, осн1, знак, запись2, осн2, осн_результата):
    return ...

# %%
si.check("дз", калькулятор, [
    (("1011", 2, "+", "F", 16, 10), "26"),
    (("237", 8, "+", "45", 8, 8), "304"),
    (("FF", 16, "-", "1", 10, 16), "FE"),
    (("101", 2, "*", "11", 2, 2), "1111"),
])

# %% [markdown]
# ---
#
# ### Итоги четверти
#
# Вы научились работать с любой позиционной системой счисления, считать
# в них столбиком и понимаете, как число выглядит внутри памяти —
# включая отрицательные и дробные.
#
# Во второй четверти займёмся **алгеброй логики**. Она отвечает на вопрос,
# который в программировании возникает постоянно: как из набора условий
# строго вывести правильный ответ — и как упростить условие, не изменив
# его смысла.

# %% [markdown]
# ---
#
# ## Отчёт по уроку
#
# Запусти ячейку ниже, когда решишь задачи. Результат уйдёт учителю автоматически.

# %%
si.report()

# %% [markdown]
# ---
#
# [← Урок 8](https://colab.research.google.com/github/LeksssGray/informatika-7-11/blob/main/klass-08/urok-08.ipynb) · [⬆ Все уроки](https://colab.research.google.com/github/LeksssGray/informatika-7-11/blob/main/klass-08/index.ipynb) · [🏠 Ко всем классам](https://colab.research.google.com/github/LeksssGray/informatika-7-11/blob/main/index.ipynb) · [Урок 10 →](https://colab.research.google.com/github/LeksssGray/informatika-7-11/blob/main/klass-08/urok-10.ipynb)
