# %% [markdown]
# # Тренажёр ОГЭ
#
# Необязательный раздел. Здесь собраны уроки курса, в которых разбираются задания ОГЭ, — чтобы готовиться точечно, не перечитывая весь год.
#
# [🏠 Ко всем классам](https://colab.research.google.com/github/LeksssGray/informatika-7-11/blob/main/index.ipynb)
#
# ---
#
# ## 9 класс
#
# | Урок | Тема | Что разбираем |
# |:--:|---|---|
# | 4 | Графы: вершины, рёбра, задачи <sub>(готовится)</sub> | Граф как модель связей. Вершины и рёбра, степень вершины. Ориентированные и взвешенные графы. Задачи на подсчёт путей. |
# | 5 | Табличные модели и матрица смежности <sub>(готовится)</sub> | Представление графа таблицей. Матрица смежности и весовая матрица. Переход от таблицы к рисунку и обратно. |
# | 6 | Кратчайший путь в графе <sub>(готовится)</sub> | Задача о кратчайшем пути. Перебор вариантов и последовательное уточнение. Классическое задание ОГЭ про дороги между пунктами. |
# | 7 | Иерархические модели и деревья <sub>(готовится)</sub> | Дерево как частный случай графа. Корень, узлы, листья, уровни. Файловая система и классификации как деревья. |
# | 8 | Алгоритмы обработки массивов <sub>(готовится)</sub> | Повторение и углубление: обход, накопление, поиск, фильтрация. Работа с индексами. Обработка соседних элементов. |
# | 13 | Строки: сложные алгоритмы <sub>(готовится)</sub> | Разбор текста, поиск и подсчёт подстрок, работа со словами. Проверка формата. Соединение и разбиение строк. |
# | 15 | Файлы: чтение и запись <sub>(готовится)</sub> | Открытие файла, конструкция with. Чтение построчно и целиком. Запись результата. Кодировки. Загрузка файла в Colab. |
# | 16 | Обработка данных из файла <sub>(готовится)</sub> | Разбор строк файла в числа и поля. Накопление статистики. Отбор строк по условию. Вывод отчёта. |
# | 17 | Практикум ОГЭ: обработка текстового файла <sub>(готовится)</sub> | Разбор заданий 12 и 13 ОГЭ. Типовые формулировки и надёжные шаблоны решения. Проверка ответа на тестовых данных. |
# | 20 | Условные функции и статистика в таблицах <sub>(готовится)</sub> | СУММЕСЛИ, СЧЁТЕСЛИ, СРЗНАЧЕСЛИ, вложенные ЕСЛИ. Расчёт долей и процентов. Проверка расчётов программой. |
# | 22 | Практикум ОГЭ: электронные таблицы <sub>(готовится)</sub> | Разбор задания 14 ОГЭ. Работа с большим массивом данных в таблице. Проверка ответа независимым способом. |
# | 25 | Компьютерные сети: устройство <sub>(готовится)</sub> | Локальные и глобальные сети. Топологии. Сервер и клиент. Протоколы и модель передачи данных. Скорость передачи и расчёт времени. |
# | 26 | Адресация в сети и работа с интернетом <sub>(готовится)</sub> | IP-адрес и доменное имя. DNS. Структура URL. Как браузер получает страницу. Поисковые запросы и логические операции в них. |
# | 31 | Практикум ОГЭ: алгоритмы и исполнители <sub>(готовится)</sub> | Разбор заданий 5 и 6 ОГЭ. Формальные исполнители, анализ программ, восстановление недостающих команд. |
# | 32 | Практикум ОГЭ: кодирование и системы счисления <sub>(готовится)</sub> | Разбор заданий 1–4 и 7–11 ОГЭ. Объём информации, кодирование, системы счисления, логика, файлы и пути. |
# | 34 | Повторение перед экзаменом и итоговая работа <sub>(готовится)</sub> | Разбор полного варианта ОГЭ: стратегия, распределение времени, типичные потери баллов. Итоговая работа за курс основной школы. |
#
# ---
#
# ### Совет по подготовке
#
# Разбирайте задания не по порядку номеров, а по темам: сначала то, что даётся тяжелее всего. Каждое решение проверяйте программой — на экзамене этой возможности не будет, зато сейчас она быстрее всего показывает ошибку в рассуждении.
#
# [🏠 Ко всем классам](https://colab.research.google.com/github/LeksssGray/informatika-7-11/blob/main/index.ipynb)
