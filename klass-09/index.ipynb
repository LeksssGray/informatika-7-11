# %% [markdown]
# # 9 класс. Модели, данные, сети — и подготовка к ОГЭ
#
# Выпускной год основной школы. Осваиваем моделирование и графы, учимся работать с файлами, таблицами и базами данных, разбираемся в устройстве сетей. В течение года регулярно разбираем задания ОГЭ — по одному практикуму в четверти.
#
# [🏠 Ко всем классам](https://colab.research.google.com/github/LeksssGray/informatika-7-11/blob/main/index.ipynb)
#
# ---
#
# ### К июню будешь уметь
#
# - строить информационные модели и решать задачи на графах
# - обрабатывать двумерные массивы, словари и данные из файлов
# - анализировать большие таблицы средствами электронных таблиц
# - строить запросы к базе данных
# - уверенно решать задания ОГЭ по информатике
#
# Уроки идут по порядку и опираются друг на друга — перепрыгивать через них не стоит.
#
# ---
#
# ## I четверть · уроки 1–8
#
# | № | Тема | Содержание | Домашнее задание |
# |:--:|---|---|---|
# | 1 | **[Учебник, Colab и моделирование](https://colab.research.google.com/github/LeksssGray/informatika-7-11/blob/main/klass-09/urok-01.ipynb)** | Диагностика за 8 класс. Что такое модель и зачем она нужна. Классификация моделей. Этапы решения задачи с помощью компьютера. | Диагностическая работа и разбор трёх моделей реальных объектов. |
# | 2 | **[Вспоминаем 8 класс: числа и логика](https://colab.research.google.com/github/LeksssGray/informatika-7-11/blob/main/klass-09/urok-02.ipynb)** | Справочник и проверка: системы счисления и переводы, представление чисел в памяти, алгебра логики и таблицы истинности. | Разминочные задачи по системам счисления и логике. |
# | 3 | **[Вспоминаем 8 класс: программирование](https://colab.research.google.com/github/LeksssGray/informatika-7-11/blob/main/klass-09/urok-03.ipynb)** | Справочник и проверка: ветвления, циклы и вложенные циклы, списки, поиск и сортировка, обработка строк. | Разминочные задачи по программированию за 8 класс. |
# | 4 | **[Графы: вершины, рёбра, задачи](https://colab.research.google.com/github/LeksssGray/informatika-7-11/blob/main/klass-09/urok-04.ipynb)** | Граф как модель связей. Вершины и рёбра, степень вершины. Ориентированные и взвешенные графы. Задачи на подсчёт путей. | Подсчитать число путей в графе вручную и проверить программой. |
# | 5 | **[Табличные модели и матрица смежности](https://colab.research.google.com/github/LeksssGray/informatika-7-11/blob/main/klass-09/urok-05.ipynb)** | Представление графа таблицей. Матрица смежности и весовая матрица. Переход от таблицы к рисунку и обратно. | Восстановить граф по таблице и решить задачи на матрицу смежности. |
# | 6 | **[Кратчайший путь в графе](https://colab.research.google.com/github/LeksssGray/informatika-7-11/blob/main/klass-09/urok-06.ipynb)** | Задача о кратчайшем пути. Перебор вариантов и последовательное уточнение. Классическое задание ОГЭ про дороги между пунктами. | Найти кратчайшие пути в трёх схемах дорог и обосновать ответ. |
# | 7 | **[Иерархические модели и деревья](https://colab.research.google.com/github/LeksssGray/informatika-7-11/blob/main/klass-09/urok-07.ipynb)** | Дерево как частный случай графа. Корень, узлы, листья, уровни. Файловая система и классификации как деревья. | Построить дерево по описанию и посчитать число листьев и уровней. |
# | 8 | **[Алгоритмы обработки массивов](https://colab.research.google.com/github/LeksssGray/informatika-7-11/blob/main/klass-09/urok-08.ipynb)** | Повторение и углубление: обход, накопление, поиск, фильтрация. Работа с индексами. Обработка соседних элементов. | Пять задач на обработку одномерного массива, включая соседние пары. |
#
# ## II четверть · уроки 9–16
#
# | № | Тема | Содержание | Домашнее задание |
# |:--:|---|---|---|
# | 9 | **[Двумерные массивы (матрицы)](https://colab.research.google.com/github/LeksssGray/informatika-7-11/blob/main/klass-09/urok-09.ipynb)** | Список списков. Строки и столбцы, обход двойным циклом. Сумма по строке и столбцу. Главная диагональ. Таблица как матрица. | Задачи: сумма по строкам, поиск максимума в матрице, транспонирование. |
# | 10 | **[Контрольная работа № 1](https://colab.research.google.com/github/LeksssGray/informatika-7-11/blob/main/klass-09/urok-10.ipynb)** | Разбор ошибок. Самостоятельная работа: модели, графы, массивы. | Итоговые задачи четверти с автопроверкой. |
# | 11 | Функции и модульность программ | Разбиение задачи на функции. Возврат нескольких значений. Передача списков в функцию. Свой модуль и его импорт. | Разложить одну большую программу на функции и покрыть их тестами. |
# | 12 | Рекурсия | Функция, вызывающая саму себя. Базовый случай и шаг рекурсии. Факториал, числа Фибоначчи, обход дерева. Глубина рекурсии. | Написать три рекурсивные функции и проследить порядок вызовов. |
# | 13 | Строки: сложные алгоритмы | Разбор текста, поиск и подсчёт подстрок, работа со словами. Проверка формата. Соединение и разбиение строк. | Задачи: подсчёт слов, поиск повторов, нормализация текста. |
# | 14 | Словари в Python | Ключ и значение. Создание, добавление, обращение, перебор. Подсчёт частот. Когда словарь удобнее списка. | Задачи: частотный словарь букв и слов, телефонная книга. |
# | 15 | Файлы: чтение и запись | Открытие файла, конструкция with. Чтение построчно и целиком. Запись результата. Кодировки. Загрузка файла в Colab. | Прочитать файл с данными, обработать и записать результат в новый файл. |
# | 16 | Обработка данных из файла | Разбор строк файла в числа и поля. Накопление статистики. Отбор строк по условию. Вывод отчёта. | Посчитать статистику по файлу с оценками и сформировать отчёт. |
#
# ## III четверть · уроки 17–26
#
# | № | Тема | Содержание | Домашнее задание |
# |:--:|---|---|---|
# | 17 | Практикум ОГЭ: обработка текстового файла | Разбор заданий 12 и 13 ОГЭ. Типовые формулировки и надёжные шаблоны решения. Проверка ответа на тестовых данных. | Решить пять задач формата ОГЭ на обработку файла. |
# | 18 | Контрольная работа № 2 | Разбор ошибок. Самостоятельная работа: функции, словари, файлы. | Итоговые задачи четверти с автопроверкой. |
# | 19 | Электронные таблицы: работа с большими таблицами | Навигация и закрепление областей. Диапазоны. Копирование формул на тысячи строк. Проверка данных и типичные ошибки. | Обработать таблицу из 1000 строк и найти в ней ошибки данных. |
# | 20 | Условные функции и статистика в таблицах | СУММЕСЛИ, СЧЁТЕСЛИ, СРЗНАЧЕСЛИ, вложенные ЕСЛИ. Расчёт долей и процентов. Проверка расчётов программой. | Рассчитать статистику по таблице и сверить результат с кодом на Python. |
# | 21 | Диаграммы и анализ данных | Выбор типа диаграммы под задачу. Оформление, подписи, оси. Как диаграмма может вводить в заблуждение. | Построить три диаграммы по одним данным и объяснить, какая честнее. |
# | 22 | Практикум ОГЭ: электронные таблицы | Разбор задания 14 ОГЭ. Работа с большим массивом данных в таблице. Проверка ответа независимым способом. | Решить четыре задачи формата ОГЭ по электронным таблицам. |
# | 23 | Базы данных: таблицы, поля, ключи | Зачем нужны базы данных. Реляционная модель: таблица, запись, поле, тип поля. Первичный ключ и связи между таблицами. | Спроектировать структуру базы данных для школьной библиотеки. |
# | 24 | Запросы, фильтры и сортировка | Выборка данных по условию. Составные условия. Сортировка результата. Знакомство с SQL-запросом SELECT на простых примерах. | Составить восемь запросов к готовой базе данных и проверить результаты. |
# | 25 | Компьютерные сети: устройство | Локальные и глобальные сети. Топологии. Сервер и клиент. Протоколы и модель передачи данных. Скорость передачи и расчёт времени. | Задачи на расчёт времени передачи данных и разбор схем сетей. |
# | 26 | Адресация в сети и работа с интернетом | IP-адрес и доменное имя. DNS. Структура URL. Как браузер получает страницу. Поисковые запросы и логические операции в них. | Разобрать адреса и составить поисковые запросы под точные условия. |
#
# ## IV четверть · уроки 27–34
#
# | № | Тема | Содержание | Домашнее задание |
# |:--:|---|---|---|
# | 27 | Веб-страницы: основы HTML | Что такое разметка. Базовые теги, структура страницы, ссылки и изображения. Создание простой страницы и её просмотр. | Собрать веб-страницу о себе из шести элементов разметки. |
# | 28 | Контрольная работа № 3 | Разбор ошибок. Самостоятельная работа: таблицы, базы данных, сети. | Итоговые задачи четверти с автопроверкой. |
# | 29 | Информационная безопасность | Угрозы и защита. Пароли и двухфакторная аутентификация. Социальная инженерия и фишинг. Персональные данные и цифровой след. | Оценить надёжность паролей программой и разобрать три сценария атаки. |
# | 30 | Эффективность алгоритмов | Почему одна программа быстрая, а другая нет. Подсчёт числа операций. Сравнение линейного и двоичного поиска, разных сортировок на замерах времени. | Замерить время работы четырёх алгоритмов и объяснить разницу. |
# | 31 | Практикум ОГЭ: алгоритмы и исполнители | Разбор заданий 5 и 6 ОГЭ. Формальные исполнители, анализ программ, восстановление недостающих команд. | Решить шесть задач формата ОГЭ на алгоритмы. |
# | 32 | Практикум ОГЭ: кодирование и системы счисления | Разбор заданий 1–4 и 7–11 ОГЭ. Объём информации, кодирование, системы счисления, логика, файлы и пути. | Решить десять задач формата ОГЭ на кодирование и системы счисления. |
# | 33 | Итоговый проект и защита | Проект с обработкой реальных данных: постановка задачи, сбор, обработка, выводы и визуализация. Представление работ и взаимное рецензирование. | Реализовать проект и подготовить выступление на три минуты. |
# | 34 | Повторение перед экзаменом и итоговая работа | Разбор полного варианта ОГЭ: стратегия, распределение времени, типичные потери баллов. Итоговая работа за курс основной школы. | Прорешать полный вариант ОГЭ и итоговую работу с автопроверкой. |
#
# ---
#
# [🏠 Ко всем классам](https://colab.research.google.com/github/LeksssGray/informatika-7-11/blob/main/index.ipynb)
