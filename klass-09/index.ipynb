# %% [markdown]
# # 9 класс. Моделирование, данные, сети и подготовка к ОГЭ
#
# Выпускной год основной школы. Осваиваем моделирование и графы, учимся работать с файлами, таблицами и базами данных, разбираемся в устройстве сетей. В течение года регулярно разбираем задания ОГЭ — по одному практикуму в четверти.
#
# [🏠 Ко всем классам](https://colab.research.google.com/github/LeksssGray/informatika-7-11/blob/main/index.ipynb)
#
# ---
#
# ### К концу года ты сможешь
#
# - строить информационные модели и решать задачи на графах
# - обрабатывать двумерные массивы, словари и данные из файлов
# - анализировать большие таблицы средствами электронных таблиц
# - строить запросы к базе данных
# - уверенно решать задания ОГЭ по информатике
#
# ### Как устроен год
#
# 34 учебные недели, один урок в неделю по 40 минут. Каждый урок — отдельный ноутбук: теория, разобранные примеры, задачи в классе и домашнее задание с автоматической проверкой.
#
# ---
#
# ## I четверть · уроки 1–8
#
# | № | Тема | Содержание | Домашнее задание |
# |:--:|---|---|---|
# | 1 | **[Повторение. Моделирование как метод познания](https://colab.research.google.com/github/LeksssGray/informatika-7-11/blob/main/klass-09/urok-01.ipynb)** | Диагностика за 8 класс. Что такое модель и зачем она нужна. Классификация моделей. Этапы решения задачи с помощью компьютера. | Диагностическая работа и разбор трёх моделей реальных объектов. |
# | 2 | **[Графы: вершины, рёбра, задачи](https://colab.research.google.com/github/LeksssGray/informatika-7-11/blob/main/klass-09/urok-02.ipynb)** | Граф как модель связей. Вершины и рёбра, степень вершины. Ориентированные и взвешенные графы. Задачи на подсчёт путей. | Подсчитать число путей в графе вручную и проверить программой. |
# | 3 | **[Табличные модели и матрица смежности](https://colab.research.google.com/github/LeksssGray/informatika-7-11/blob/main/klass-09/urok-03.ipynb)** | Представление графа таблицей. Матрица смежности и весовая матрица. Переход от таблицы к рисунку и обратно. | Восстановить граф по таблице и решить задачи на матрицу смежности. |
# | 4 | **[Кратчайший путь в графе](https://colab.research.google.com/github/LeksssGray/informatika-7-11/blob/main/klass-09/urok-04.ipynb)** | Задача о кратчайшем пути. Перебор вариантов и последовательное уточнение. Классическое задание ОГЭ про дороги между пунктами. | Найти кратчайшие пути в трёх схемах дорог и обосновать ответ. |
# | 5 | **[Иерархические модели и деревья](https://colab.research.google.com/github/LeksssGray/informatika-7-11/blob/main/klass-09/urok-05.ipynb)** | Дерево как частный случай графа. Корень, узлы, листья, уровни. Файловая система и классификации как деревья. | Построить дерево по описанию и посчитать число листьев и уровней. |
# | 6 | **[Алгоритмы обработки массивов](https://colab.research.google.com/github/LeksssGray/informatika-7-11/blob/main/klass-09/urok-06.ipynb)** | Повторение и углубление: обход, накопление, поиск, фильтрация. Работа с индексами. Обработка соседних элементов. | Пять задач на обработку одномерного массива, включая соседние пары. |
# | 7 | **[Двумерные массивы (матрицы)](https://colab.research.google.com/github/LeksssGray/informatika-7-11/blob/main/klass-09/urok-07.ipynb)** | Список списков. Строки и столбцы, обход двойным циклом. Сумма по строке и столбцу. Главная диагональ. Таблица как матрица. | Задачи: сумма по строкам, поиск максимума в матрице, транспонирование. |
# | 8 | **[Контрольная работа № 1](https://colab.research.google.com/github/LeksssGray/informatika-7-11/blob/main/klass-09/urok-08.ipynb)** | Разбор ошибок. Самостоятельная работа: модели, графы, массивы. | Итоговые задачи четверти с автопроверкой. |
#
# ## II четверть · уроки 9–16
#
# | № | Тема | Содержание | Домашнее задание |
# |:--:|---|---|---|
# | 9 | Функции и модульность программ <br><sub>готовится</sub> | Разбиение задачи на функции. Возврат нескольких значений. Передача списков в функцию. Свой модуль и его импорт. | Разложить одну большую программу на функции и покрыть их тестами. |
# | 10 | Рекурсия <br><sub>готовится</sub> | Функция, вызывающая саму себя. Базовый случай и шаг рекурсии. Факториал, числа Фибоначчи, обход дерева. Глубина рекурсии. | Написать три рекурсивные функции и проследить порядок вызовов. |
# | 11 | Строки: сложные алгоритмы <br><sub>готовится</sub> | Разбор текста, поиск и подсчёт подстрок, работа со словами. Проверка формата. Соединение и разбиение строк. | Задачи: подсчёт слов, поиск повторов, нормализация текста. |
# | 12 | Словари в Python <br><sub>готовится</sub> | Ключ и значение. Создание, добавление, обращение, перебор. Подсчёт частот. Когда словарь удобнее списка. | Задачи: частотный словарь букв и слов, телефонная книга. |
# | 13 | Файлы: чтение и запись <br><sub>готовится</sub> | Открытие файла, конструкция with. Чтение построчно и целиком. Запись результата. Кодировки. Загрузка файла в Colab. | Прочитать файл с данными, обработать и записать результат в новый файл. |
# | 14 | Обработка данных из файла <br><sub>готовится</sub> | Разбор строк файла в числа и поля. Накопление статистики. Отбор строк по условию. Вывод отчёта. | Посчитать статистику по файлу с оценками и сформировать отчёт. |
# | 15 | Практикум ОГЭ: обработка текстового файла <br><sub>готовится</sub> | Разбор заданий 12 и 13 ОГЭ. Типовые формулировки и надёжные шаблоны решения. Проверка ответа на тестовых данных. | Решить пять задач формата ОГЭ на обработку файла. |
# | 16 | Контрольная работа № 2 <br><sub>готовится</sub> | Разбор ошибок. Самостоятельная работа: функции, словари, файлы. | Итоговые задачи четверти с автопроверкой. |
#
# ## III четверть · уроки 17–26
#
# | № | Тема | Содержание | Домашнее задание |
# |:--:|---|---|---|
# | 17 | Электронные таблицы: работа с большими таблицами <br><sub>готовится</sub> | Навигация и закрепление областей. Диапазоны. Копирование формул на тысячи строк. Проверка данных и типичные ошибки. | Обработать таблицу из 1000 строк и найти в ней ошибки данных. |
# | 18 | Условные функции и статистика в таблицах <br><sub>готовится</sub> | СУММЕСЛИ, СЧЁТЕСЛИ, СРЗНАЧЕСЛИ, вложенные ЕСЛИ. Расчёт долей и процентов. Проверка расчётов программой. | Рассчитать статистику по таблице и сверить результат с кодом на Python. |
# | 19 | Диаграммы и анализ данных <br><sub>готовится</sub> | Выбор типа диаграммы под задачу. Оформление, подписи, оси. Как диаграмма может вводить в заблуждение. | Построить три диаграммы по одним данным и объяснить, какая честнее. |
# | 20 | Практикум ОГЭ: электронные таблицы <br><sub>готовится</sub> | Разбор задания 14 ОГЭ. Работа с большим массивом данных в таблице. Проверка ответа независимым способом. | Решить четыре задачи формата ОГЭ по электронным таблицам. |
# | 21 | Базы данных: таблицы, поля, ключи <br><sub>готовится</sub> | Зачем нужны базы данных. Реляционная модель: таблица, запись, поле, тип поля. Первичный ключ и связи между таблицами. | Спроектировать структуру базы данных для школьной библиотеки. |
# | 22 | Запросы, фильтры и сортировка <br><sub>готовится</sub> | Выборка данных по условию. Составные условия. Сортировка результата. Знакомство с SQL-запросом SELECT на простых примерах. | Составить восемь запросов к готовой базе данных и проверить результаты. |
# | 23 | Компьютерные сети: устройство <br><sub>готовится</sub> | Локальные и глобальные сети. Топологии. Сервер и клиент. Протоколы и модель передачи данных. Скорость передачи и расчёт времени. | Задачи на расчёт времени передачи данных и разбор схем сетей. |
# | 24 | Адресация в сети и работа с интернетом <br><sub>готовится</sub> | IP-адрес и доменное имя. DNS. Структура URL. Как браузер получает страницу. Поисковые запросы и логические операции в них. | Разобрать адреса и составить поисковые запросы под точные условия. |
# | 25 | Веб-страницы: основы HTML <br><sub>готовится</sub> | Что такое разметка. Базовые теги, структура страницы, ссылки и изображения. Создание простой страницы и её просмотр. | Собрать веб-страницу о себе из шести элементов разметки. |
# | 26 | Контрольная работа № 3 <br><sub>готовится</sub> | Разбор ошибок. Самостоятельная работа: таблицы, базы данных, сети. | Итоговые задачи четверти с автопроверкой. |
#
# ## IV четверть · уроки 27–34
#
# | № | Тема | Содержание | Домашнее задание |
# |:--:|---|---|---|
# | 27 | Информационная безопасность <br><sub>готовится</sub> | Угрозы и защита. Пароли и двухфакторная аутентификация. Социальная инженерия и фишинг. Персональные данные и цифровой след. | Оценить надёжность паролей программой и разобрать три сценария атаки. |
# | 28 | Эффективность алгоритмов <br><sub>готовится</sub> | Почему одна программа быстрая, а другая нет. Подсчёт числа операций. Сравнение линейного и двоичного поиска, разных сортировок на замерах времени. | Замерить время работы четырёх алгоритмов и объяснить разницу. |
# | 29 | Практикум ОГЭ: алгоритмы и исполнители <br><sub>готовится</sub> | Разбор заданий 5 и 6 ОГЭ. Формальные исполнители, анализ программ, восстановление недостающих команд. | Решить шесть задач формата ОГЭ на алгоритмы. |
# | 30 | Практикум ОГЭ: кодирование и системы счисления <br><sub>готовится</sub> | Разбор заданий 1–4 и 7–11 ОГЭ. Объём информации, кодирование, системы счисления, логика, файлы и пути. | Решить десять задач формата ОГЭ на кодирование и системы счисления. |
# | 31 | Итоговый проект <br><sub>готовится</sub> | Проект с обработкой реальных данных: постановка задачи, сбор данных, обработка, выводы и визуализация. | Реализовать проект в отдельном ноутбуке по критериям. |
# | 32 | Защита проектов <br><sub>готовится</sub> | Представление результата. Как объяснить свой код и выводы. Взаимное рецензирование. | Подготовить выступление на 3 минуты и рецензию на работу товарища. |
# | 33 | Повторение перед экзаменом <br><sub>готовится</sub> | Разбор полного варианта ОГЭ с комментариями. Стратегия на экзамене, распределение времени, типичные потери баллов. | Прорешать полный вариант ОГЭ с самопроверкой. |
# | 34 | Итоговая контрольная работа <br><sub>готовится</sub> | Итоговая работа за курс основной школы. | Итоговая работа за 9 класс с автопроверкой. |
#
# ---
#
# ### Условные обозначения
#
# 📖 — теория  🐍 — Python  🧠 — логика  📊 — электронные таблицы  🗄️ — базы данных  🌐 — сети  📈 — анализ данных  🛠️ — проект  📝 — контрольная  🎓 — ОГЭ  🎓 — ЕГЭ
#
# [🏠 Ко всем классам](https://colab.research.google.com/github/LeksssGray/informatika-7-11/blob/main/index.ipynb)
